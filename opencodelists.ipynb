# %%
import io

import pandas as pd
import requests
import tabula
headers = {'User-Agent': 'Mozilla/5.0 (X11; Windows; Windows x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.114 Safari/537.36'}

url = 'https://www.opencodelists.org/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/#full-list'
s = requests.session()
r = s.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
if r.ok:
    print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" class="h-100">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
#
#
#     <link  rel="stylesheet" href="/static/assets/base-NaYmgtgn.css" />
# <script type="module" crossorigin="" src="/static/assets/base-Bm-06qNG.js"></script>
# <link href="/static/assets/_commonjsHelpers-gnU0ypJ3.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
# <link href="/static/assets/jquery-BQXThELV.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
#
#
#     <script
#       defer
#       data-domain="opencodelists.org"
#       event-is_logged_in="false"
#       event-is_admin="false"
#       src="https://plausible.io/js/script.pageview-props.tagged-events.js"
#     ></script>
#     <script nonce="">
#       window.plausible = window.plausible || function() { (window.plausible.q = window.plausible.q || []).push(arguments) }
#     </script>
#
#
#
#
#
#     <title>OpenCodelists: Haematological cancer codes</title>
#
#     <link rel="icon" href="/static/favicon.ico">
#     <link rel="icon" href="/static/icon.svg" type="image/svg+xml">
#     <link rel="apple-touch-icon" href="/static/apple-touch-icon.png">
#     <link rel="manifest" href="/static/manifest.webmanifest">
#   </head>
#
#   <body class="d-flex flex-column h-100">
#     <nav
#       class="navbar navbar-expand-sm navbar-dark bg-secondary justify-content-between align-items-baseline"
#     >
#       <div class="mr-auto">
#         <a class="navbar-brand" href="/"
#         >OpenCodelists</a
#           >
#
#           <button
#             class="navbar-toggler"
#             type="button"
#             data-toggle="collapse"
#             data-target="#navbarSupportedContent"
#             aria-controls="navbarSupportedContent"
#             aria-expanded="false"
#             aria-label="Toggle navigation">
#             <span class="navbar-toggler-icon"></span>
#           </button>
#         </div>
#
#         <div class="collapse navbar-collapse" id="navbarSupportedContent">
#           <ul class="navbar-nav ml-auto">
#             <li class="navbar-nav nav-item">
#               <a class="nav-link text-white" href="/docs/">Docs</a>
#             </li>
#
#               <li class="navbar-nav nav-item">
#                 <a class="nav-link text-white" href="/accounts/register/">Sign up</a>
#               </li>
#               <li class="navbar-nav nav-item">
#                 <a class="nav-link text-white" href="/accounts/login/">Sign in</a>
#               </li>
#
#           </ul>
#         </div>
#       </nav>
#
#       <main role="main" class="flex-shrink-0 my-4">
#
#
#         <div class="container">
#
#
#         </div>
#
#         <div class="container-fluid max-w-screen-2xl">
#
#   <div class="border-bottom mb-3 pb-3">
#     <div class="d-flex flex-row justify-content-between gap-2 mb-2">
#       <h1 class="h3">
#         Haematological cancer codes
#
#
#       </h1>
#
#     </div>
#
#     <section>
#       <h2 class="sr-only">Codelist metadata</h2>
#       <dl class="list-group list-group-horizontal small">
#         <div class="list-group-item py-1 px-2">
#           <dt>
#             Coding system
#           </dt>
#           <dd class="mb-0">SNOMED CT (UK Clinical Edition)</dd>
#         </div>
#
#         <div class="list-group-item py-1 px-2">
#           <dt>
#             Coding system release
#           </dt>
#           <dd class="mb-0">
#             39.2.0
#           </dd>
#         </div>
#
#
#
#
#           <div class="list-group-item py-1 px-2">
#             <dt>
#               Organisation
#             </dt>
#             <dd class="mb-0">NHSD Primary Care Domain Refsets</dd>
#           </div>
#
#
#         <div class="list-group-item py-1 px-2">
#           <dt>
#             Codelist ID
#           </dt>
#           <dd class="mb-0 break-word">nhsd-primary-care-domain-refsets/c19haemcan_cod</dd>
#         </div>
#
#
#           <div class="list-group-item py-1 px-2">
#             <dt>
#               Version Tag
#             </dt>
#             <dd class="mb-0">20241205</dd>
#           </div>
#
#
#         <div class="list-group-item py-1 px-2">
#           <dt>
#             Version ID
#           </dt>
#           <dd class="mb-0">4d423796</dd>
#         </div>
#       </dl>
#     </section>
#   </div>
#
#   <div class="row">
#     <div class="col-md-3 version__sidebar">
#       <form action="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/dmd-convert" method="POST">
#         <input type="hidden" name="csrfmiddlewaretoken" value="NJimnE7AS4KeCs4XQaVLvVDfjmb1x5Eg84wD6hDuD4FGrGRHPcdEGDBOXm22ACMH">
#         <div class="btn-group-vertical btn-block" role="group">
#
#             <a
#               href="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/download.csv"
#               role="button"
#               class="btn btn-outline-primary btn-block"
#             >
#               Download CSV
#             </a>
#
#
#
#             <a
#               href="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/definition.csv"
#               role="button"
#               class="btn btn-outline-primary btn-block"
#             >
#               Download definition
#             </a>
#
#
#         </div>
#       </form>
#
#
#
#
#       <div class="card">
#         <h2 class="card-header h6 font-weight-bold">Versions</h2>
#         <ol class="list-group list-group-flush sidebar-versions">
#
#             <li
#               class="
#                 list-group-item
#                 list-group-item-secondary
#               "
#             >
#               <div class="d-flex justify-content-between align-items-center">
#                 <span class="d-block text-monospace font-weight-bold">
#
#                     20241205
#
#                 </span>
#
#                 <span class="badge badge-success">Pubished</span>
#
#               </div>
#
#               <span class="created d-block p-0">
#                 <abbr
#                   class="font-weight-bold"
#                   data-placement="right"
#                   data-toggle="tooltip"
#                   title="When this codelist version was added to OpenCodelists"
#                 >Created</abbr>:
#                 24 Dec 2024
#                 at
#                 12:43
#               </span>
#             </li>
#
#             <li
#               class="
#                 list-group-item
#
#               "
#             >
#               <div class="d-flex justify-content-between align-items-center">
#                 <span class="d-block text-monospace font-weight-bold">
#
#                     <a href="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20210127/">
#                       20210127
#                     </a>
#
#                 </span>
#
#                 <span class="badge badge-success">Pubished</span>
#
#               </div>
#
#               <span class="created d-block p-0">
#                 <abbr
#                   class="font-weight-bold"
#                   data-placement="right"
#                   data-toggle="tooltip"
#                   title="When this codelist version was added to OpenCodelists"
#                 >Created</abbr>:
#                 21 Apr 2021
#                 at
#                 16:35
#               </span>
#             </li>
#
#             <li
#               class="
#                 list-group-item
#
#               "
#             >
#               <div class="d-flex justify-content-between align-items-center">
#                 <span class="d-block text-monospace font-weight-bold">
#
#                     <a href="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20200812/">
#                       20200812
#                     </a>
#
#                 </span>
#
#                 <span class="badge badge-success">Pubished</span>
#
#               </div>
#
#               <span class="created d-block p-0">
#                 <abbr
#                   class="font-weight-bold"
#                   data-placement="right"
#                   data-toggle="tooltip"
#                   title="When this codelist version was added to OpenCodelists"
#                 >Created</abbr>:
#                 21 Apr 2021
#                 at
#                 16:24
#               </span>
#             </li>
#
#         </ol>
#       </div>
#     </div>
#
#     <div class="col-md-9">
#       <ul id="tab-list" class="nav nav-tabs" role="tablist">
#         <li class="nav-item">
#   <a
#     class="nav-link active"
#     id="about-tab"
#     data-toggle="tab"
#     href="#about"
#     role="tab"
#     aria-controls="about"
#     aria-selected=true
#     >About</a
#   >
# </li>
#
#
#         <li class="nav-item">
#   <a
#     class="nav-link"
#     id="full-list-tab"
#     data-toggle="tab"
#     href="#full-list"
#     role="tab"
#     aria-controls="full-list"
#     aria-selected=false
#     >Full list</a
#   >
# </li>
#
#
#
#           <li class="nav-item">
#   <a
#     class="nav-link"
#     id="tree-tab"
#     data-toggle="tab"
#     href="#tree"
#     role="tab"
#     aria-controls="tree"
#     aria-selected=false
#     >Tree</a
#   >
# </li>
#
#
#
#
#       </ul>
#
#       <div class="tab-content d-flex flex-column h-100">
#         <div
#       class="tab-pane fade p-4 show active h-100"
#       id="about"
#       role="tabpanel"
#       aria-labelledby="about-tab"
# >
#
#
# <div class="tab-about h-100 d-flex flex-column">
#   <h2 class="sr-only">About</h2>
#
#   <h3 class="h4">Description</h3>
#   <p><p>Taken from the <code>C19HAEMCAN_COD</code> refset published by NHSD.</p>
# </p>
#
#
#
#
#
#   <h3 class="h4">References</h3>
#   <ul>
#
#     <li><a href="https://digital.nhs.uk/data-and-information/data-collections-and-data-sets/data-collections/quality-and-outcomes-framework-qof/quality-and-outcome-framework-qof-business-rules/primary-care-domain-reference-set-portal">Primary Care Domain Reference Set Portal</a></li>
#
#   </ul>
#
#
#
#
#
#
#   <div class="small mt-auto pt-4">
#     <hr>
#     <p>
#       Codelists are developed by a broad community of users for individual study purposes, which
#       may or may not meet the needs of other studies. They should not be thought of as universal
#       definitions of a particular condition.
#     </p>
#     <p>
#       We don't offer any guarantees about what they do or don't identify. Users should carefully
#       check that any codelist meets their needs, and seek clinical input where appropriate.
#     </p>
#
#   </div>
#
# </div>
#
# </div>
#
#
#         <div
#       class="tab-pane fade p-4 "
#       id="full-list"
#       role="tabpanel"
#       aria-labelledby="full-list-tab"
# >
#   <table id="js-codelist-table" class="table table-sm">
#   <thead>
#
#     <th>code</th>
#
#     <th>term</th>
#
#   </thead>
#   <tbody>
#
#       <tr>
#
#         <td>103077004</td>
#
#         <td>Immunodeficiency secondary to neoplasm</td>
#
#       </tr>
#
#       <tr>
#
#         <td>108521000119103</td>
#
#         <td>History of reticulosarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1090241000000107</td>
#
#         <td>Angioimmunoblastic T-cell lymphoma with dysproteinaemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1091861000000100</td>
#
#         <td>Follicular lymphoma, cutaneous follicle centre</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1091891000000106</td>
#
#         <td>B-cell Hodgkin&#x27;s lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1091921000000103</td>
#
#         <td>B-cell non-Hodgkin&#x27;s lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109962001</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109964000</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma, undifferentiated</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109965004</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma, lymphoblastic</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109966003</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma, immunoblastic</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109967007</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma, small cleaved cell</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109968002</td>
#
#         <td>Diffuse non-Hodgkin&#x27;s lymphoma, small cell</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109969005</td>
#
#         <td>Diffuse large B-cell malignant lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109970006</td>
#
#         <td>Follicular non-Hodgkin&#x27;s lymphoma, small cleaved cell</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109971005</td>
#
#         <td>Follicular non-Hodgkin&#x27;s lymphoma, mixed small cleaved cell and large cell</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109972003</td>
#
#         <td>Follicular non-Hodgkin&#x27;s lymphoma, large cell</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109975001</td>
#
#         <td>T-zone lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109976000</td>
#
#         <td>Lymphoepithelioid lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109977009</td>
#
#         <td>Peripheral T-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109978004</td>
#
#         <td>T-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109979007</td>
#
#         <td>B-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109980005</td>
#
#         <td>Malignant immunoproliferative disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109981009</td>
#
#         <td>Waldenström macroglobulinemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109985000</td>
#
#         <td>Immunoproliferative small intestinal disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109988003</td>
#
#         <td>Histiocytic sarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109989006</td>
#
#         <td>Multiple myeloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109991003</td>
#
#         <td>Acute panmyelosis with myelofibrosis</td>
#
#       </tr>
#
#       <tr>
#
#         <td>109992005</td>
#
#         <td>Polycythemia vera</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110000005</td>
#
#         <td>Refractory anemia with excess blasts in transformation</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110002002</td>
#
#         <td>Mast cell leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110004001</td>
#
#         <td>Acute promyelocytic leukemia, FAB M3</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110005000</td>
#
#         <td>Acute myelomonocytic leukemia, FAB M4</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110006004</td>
#
#         <td>Prolymphocytic leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>110007008</td>
#
#         <td>Adult T-cell leukemia/lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1148845007</td>
#
#         <td>Follicular lymphoma grade 3b</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1148851002</td>
#
#         <td>Follicular lymphoma grade 3a</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1148888004</td>
#
#         <td>Nodular glomerulosclerosis due to heavy chain deposition disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1148906001</td>
#
#         <td>Acute myeloid leukemia with t(8;21)(q22;q22) RUNX1-RUNX1T1</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153336009</td>
#
#         <td>Pediatric nodal marginal zone B cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153341001</td>
#
#         <td>Myeloproliferative hypereosinophilic syndrome</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153346006</td>
#
#         <td>Primary non-Hodgkin malignant lymphoma of uveal tract</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153347002</td>
#
#         <td>Primary non-Hodgkin malignant lymphoma of vitreoretinal tract</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153348007</td>
#
#         <td>Primary effusion lymphoma due to human immune deficiency virus infection</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153349004</td>
#
#         <td>Primary familial polycythemia due to erythropoietin receptor mutation</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153354008</td>
#
#         <td>Malignant lymphoma of duodenum</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153355009</td>
#
#         <td>Malignant lymphoma of esophagus</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153356005</td>
#
#         <td>Lymphoma of anus</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153357001</td>
#
#         <td>Lymphoma of appendix</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153377008</td>
#
#         <td>Mixed phenotype acute leukemia with t(9;22) (q34;q11.2); BCR-ABL1</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153379006</td>
#
#         <td>Mixed phenotype acute leukemia with T-cell and myeloid lineage</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153381008</td>
#
#         <td>Mixed phenotype acute leukemia with myeloid and B-cell lymphoid phenotypes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153382001</td>
#
#         <td>Malignant lymphoma of lacrimal gland</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153383006</td>
#
#         <td>Malignant lymphoma of liver</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1153397003</td>
#
#         <td>Hydroa vacciniforme-like cutaneous T-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1156403002</td>
#
#         <td>Composite Hodgkin and non-Hodgkin lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1157157006</td>
#
#         <td>Acute myeloid leukemia with 11q23 abnormality</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1157162007</td>
#
#         <td>Intravascular large B-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1162264008</td>
#
#         <td>Malignant lymphoma of uveal tract</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1162531007</td>
#
#         <td>Acute myeloid leukemia in complete remission</td>
#
#       </tr>
#
#       <tr>
#
#         <td>116691000119101</td>
#
#         <td>Marginal zone lymphoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>116811000119106</td>
#
#         <td>Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>116821000119104</td>
#
#         <td>Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>116841000119105</td>
#
#         <td>Marginal zone lymphoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>116871000119103</td>
#
#         <td>Mantle cell lymphoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>117211000119105</td>
#
#         <td>Peripheral T-cell lymphoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1172516002</td>
#
#         <td>High-dose chemotherapy with stem cell transplant</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1172704005</td>
#
#         <td>High grade B-cell lymphoma with MYC and BCL2 and/or BCL6 rearrangements</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118599009</td>
#
#         <td>Hodgkin&#x27;s disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118600007</td>
#
#         <td>Malignant lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118601006</td>
#
#         <td>Non-Hodgkin&#x27;s lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118602004</td>
#
#         <td>Hodgkin&#x27;s granuloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118605002</td>
#
#         <td>Hodgkin lymphoma, nodular lymphocyte predominance</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118606001</td>
#
#         <td>Hodgkin&#x27;s sarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118607005</td>
#
#         <td>Hodgkin lymphoma, lymphocyte-rich</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118608000</td>
#
#         <td>Hodgkin&#x27;s disease, nodular sclerosis</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118609008</td>
#
#         <td>Hodgkin&#x27;s disease, mixed cellularity</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118610003</td>
#
#         <td>Hodgkin&#x27;s disease, lymphocytic depletion</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118611004</td>
#
#         <td>Sézary&#x27;s disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118612006</td>
#
#         <td>Malignant histiocytosis</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118613001</td>
#
#         <td>Hairy cell leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118614007</td>
#
#         <td>Langerhans cell histiocytosis, disseminated</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118615008</td>
#
#         <td>Malignant mast cell tumor</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118617000</td>
#
#         <td>Burkitt&#x27;s lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>118618005</td>
#
#         <td>Mycosis fungoides</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1187123005</td>
#
#         <td>Mixed phenotype acute leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1196900003</td>
#
#         <td>B cell lymphoma of small intestine</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1197344000</td>
#
#         <td>T-cell lymphoma of small intestine</td>
#
#       </tr>
#
#       <tr>
#
#         <td>120481000119109</td>
#
#         <td>History of multiple myeloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12149006</td>
#
#         <td>Chemotherapy administration, subcutaneous, with local anesthesia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1217301006</td>
#
#         <td>Precursor cell lymphoblastic lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>122571000119106</td>
#
#         <td>History of malignant cutaneous T-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12281000132104</td>
#
#         <td>Relapsing acute myeloid leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1228842003</td>
#
#         <td>Primary cutaneous plasmacytosis</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12291000132102</td>
#
#         <td>Refractory acute myeloid leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1229988003</td>
#
#         <td>Myeloid and/or lymphoid neoplasm with pericentriolar material 1-janus kinase 2</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12301000132103</td>
#
#         <td>Acute lymphoid leukemia relapse</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12311000132101</td>
#
#         <td>Refractory acute lymphoid leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1231732006</td>
#
#         <td>Smoldering systemic mastocytosis</td>
#
#       </tr>
#
#       <tr>
#
#         <td>12341000132100</td>
#
#         <td>B-cell lymphoma, unclassifiable, with features intermediate between diffuse large B-cell lymphoma and Burkitt lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1237368006</td>
#
#         <td>Acute myeloid leukemia with BCR-ABL1</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1237578005</td>
#
#         <td>Primary oculocerebral non-Hodgkin lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1237617004</td>
#
#         <td>Hypereosinophilic syndrome due to disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1254741007</td>
#
#         <td>Intensification antineoplastic therapy regimen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1254742000</td>
#
#         <td>Delayed intensification antineoplastic therapy regimen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255270006</td>
#
#         <td>Lymphoplasmacytic lymphoma without immunoglobulin M production</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255666008</td>
#
#         <td>Hodgkin lymphoma, lymphocyte depletion of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255687003</td>
#
#         <td>Hodgkin lymphoma, lymphocyte depletion of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255726001</td>
#
#         <td>Hodgkin granuloma of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255727005</td>
#
#         <td>Hodgkin granuloma of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255728000</td>
#
#         <td>Hodgkin granuloma of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255729008</td>
#
#         <td>Mast cell malignancy of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255730003</td>
#
#         <td>Mast cell malignancy of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255737000</td>
#
#         <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255738005</td>
#
#         <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255739002</td>
#
#         <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255740000</td>
#
#         <td>Letterer-Siwe disease of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255741001</td>
#
#         <td>Letterer-Siwe disease of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255742008</td>
#
#         <td>Letterer-Siwe disease of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255743003</td>
#
#         <td>Hodgkin sarcoma of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255744009</td>
#
#         <td>Hodgkin sarcoma of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255745005</td>
#
#         <td>Hodgkin sarcoma of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255746006</td>
#
#         <td>Malignant histiocytosis of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255747002</td>
#
#         <td>Malignant histiocytosis of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255748007</td>
#
#         <td>Malignant histiocytosis of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255749004</td>
#
#         <td>Burkitt tumor of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255750004</td>
#
#         <td>Burkitt tumor of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255751000</td>
#
#         <td>Burkitt tumor of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255752007</td>
#
#         <td>Mycosis fungoides of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255753002</td>
#
#         <td>Mycosis fungoides of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255754008</td>
#
#         <td>Mycosis fungoides of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255784000</td>
#
#         <td>Hodgkin paragranuloma of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255785004</td>
#
#         <td>Hodgkin paragranuloma of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255786003</td>
#
#         <td>Hodgkin paragranuloma of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255788002</td>
#
#         <td>Hodgkin disease, mixed cellularity of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255789005</td>
#
#         <td>Hodgkin disease, mixed cellularity of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255790001</td>
#
#         <td>Hodgkin disease, mixed cellularity of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255791002</td>
#
#         <td>Hodgkin disease, nodular sclerosis of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255792009</td>
#
#         <td>Hodgkin disease, nodular sclerosis of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255793004</td>
#
#         <td>Hodgkin disease, nodular sclerosis of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255795006</td>
#
#         <td>Malignant histiocytosis of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255796007</td>
#
#         <td>Burkitt lymphoma of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255797003</td>
#
#         <td>Hodgkin disease, nodular sclerosis of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255798008</td>
#
#         <td>Hodgkin granuloma of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255799000</td>
#
#         <td>Sézary disease of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255800001</td>
#
#         <td>Sézary disease of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255801002</td>
#
#         <td>Sézary disease of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255802009</td>
#
#         <td>Hodgkin disease of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255803004</td>
#
#         <td>Hodgkin disease of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255804005</td>
#
#         <td>Hodgkin disease of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255805006</td>
#
#         <td>Malignant lymphoma of lymph nodes of head</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255806007</td>
#
#         <td>Malignant lymphoma of lymph nodes of neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255807003</td>
#
#         <td>Malignant lymphoma of lymph nodes of head and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255808008</td>
#
#         <td>Hodgkin sarcoma of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255809000</td>
#
#         <td>Malignant mast cell tumor of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255811009</td>
#
#         <td>Hodgkin disease, mixed cellularity of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255812002</td>
#
#         <td>Hodgkin disease, nodular sclerosis of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255813007</td>
#
#         <td>Letterer-Siwe disease of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255814001</td>
#
#         <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255815000</td>
#
#         <td>Malignant histiocytosis of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255831008</td>
#
#         <td>Chemotherapy for malignant neoplastic disease using targeted agent</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255834000</td>
#
#         <td>Administration of antineoplastic chemotherapy into peritoneal cavity</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255883001</td>
#
#         <td>Hodgkin sarcoma of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255885008</td>
#
#         <td>Letterer-Siwe disease of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255886009</td>
#
#         <td>Mycosis fungoides of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255887000</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255888005</td>
#
#         <td>Hodgkin paragranuloma of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255890006</td>
#
#         <td>Hodgkin disease, lymphocytic depletion of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255892003</td>
#
#         <td>Hodgkin disease, lymphocytic depletion of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255894002</td>
#
#         <td>Hodgkin granuloma of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255895001</td>
#
#         <td>Burkitt lymphoma of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255897009</td>
#
#         <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255898004</td>
#
#         <td>Hodgkin disease, mixed cellularity of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255899007</td>
#
#         <td>Malignant mast cell tumor of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255902005</td>
#
#         <td>Hodgkin disease of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255904006</td>
#
#         <td>Administration of palliative antineoplastic agent</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255905007</td>
#
#         <td>Hodgkin disease of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255906008</td>
#
#         <td>Malignant lymphoma of lymph nodes of upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1255907004</td>
#
#         <td>Malignant lymphoma of lymph nodes of lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1258932003</td>
#
#         <td>Natural killer-lymphoblastic leukemia/lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1259200004</td>
#
#         <td>Neoadjuvant antineoplastic chemotherapy</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1260268001</td>
#
#         <td>Myelodysplastic syndrome with low blasts</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1260406003</td>
#
#         <td>Myelodysplastic neoplasm with biallelic TP53 inactivation</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1264416003</td>
#
#         <td>Unclassifiable myelodysplastic syndrome</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1264458000</td>
#
#         <td>Acute undifferentiated leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>127066000</td>
#
#         <td>Familial polycythemia vera</td>
#
#       </tr>
#
#       <tr>
#
#         <td>127070008</td>
#
#         <td>Malignant histiocytic disorder</td>
#
#       </tr>
#
#       <tr>
#
#         <td>127220001</td>
#
#         <td>Malignant lymphoma of lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>127225006</td>
#
#         <td>Chronic myelomonocytic leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>127911000119105</td>
#
#         <td>Light chain nephropathy due to multiple myeloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1286863002</td>
#
#         <td>Metastatic malignant neoplasm to cecum and/or colon and/or rectum</td>
#
#       </tr>
#
#       <tr>
#
#         <td>128874001</td>
#
#         <td>Cutaneous CD30+ lymphoproliferative disorder</td>
#
#       </tr>
#
#       <tr>
#
#         <td>128875000</td>
#
#         <td>Primary cutaneous CD30 antigen positive large T-cell lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>129000002</td>
#
#         <td>Eosinophilic granuloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>13048006</td>
#
#         <td>Orbital lymphoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>133751000119102</td>
#
#         <td>Lymphoma of colon</td>
#
#       </tr>
#
#       <tr>
#
#         <td>152451000119104</td>
#
#         <td>History of lymphosarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>152861000119104</td>
#
#         <td>History of myeloid leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>161436008</td>
#
#         <td>History of leukemia</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1659461000000103</td>
#
#         <td>Janus kinase 2 positive polycythaemia vera</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1659471000000105</td>
#
#         <td>Janus kinase 2 negative polycythaemia vera</td>
#
#       </tr>
#
#       <tr>
#
#         <td>16775311000119107</td>
#
#         <td>Mycosis fungoides of facial lymph node</td>
#
#       </tr>
#
#       <tr>
#
#         <td>16894711000119103</td>
#
#         <td>Immunoglobulin G deficiency due to multiple myeloma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169396008</td>
#
#         <td>Radiomimetic chemotherapy</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169397004</td>
#
#         <td>Radiochemotherapy: local infiltration</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169398009</td>
#
#         <td>Radiochemotherapy: to stop spread</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169399001</td>
#
#         <td>Radiochemotherapy via oral route</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169400008</td>
#
#         <td>Radiochemotherapy via intravenous route</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169401007</td>
#
#         <td>Radiochemotherapy: for immunosuppression</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169402000</td>
#
#         <td>Radiochemotherapy: local artery</td>
#
#       </tr>
#
#       <tr>
#
#         <td>169403005</td>
#
#         <td>Radiochemotherapy: into cavity</td>
#
#       </tr>
#
#       <tr>
#
#         <td>171765004</td>
#
#         <td>Intrathecal injection of chemotherapeutic agent</td>
#
#       </tr>
#
#       <tr>
#
#         <td>1881000119103</td>
#
#         <td>History of plasmacytoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188487008</td>
#
#         <td>Lymphosarcoma and reticulosarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188489006</td>
#
#         <td>Reticulosarcoma of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188492005</td>
#
#         <td>Reticulosarcoma of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188493000</td>
#
#         <td>Reticulosarcoma of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188498009</td>
#
#         <td>Lymphosarcoma</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188500005</td>
#
#         <td>Lymphosarcoma of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188501009</td>
#
#         <td>Lymphosarcoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188502002</td>
#
#         <td>Lymphosarcoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188503007</td>
#
#         <td>Lymphosarcoma of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188504001</td>
#
#         <td>Lymphosarcoma of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188505000</td>
#
#         <td>Lymphosarcoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188506004</td>
#
#         <td>Lymphosarcoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188507008</td>
#
#         <td>Lymphosarcoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188510001</td>
#
#         <td>Burkitt&#x27;s lymphoma of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188511002</td>
#
#         <td>Burkitt&#x27;s lymphoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188512009</td>
#
#         <td>Burkitt&#x27;s lymphoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188513004</td>
#
#         <td>Burkitt lymphoma of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188514005</td>
#
#         <td>Burkitt lymphoma of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188515006</td>
#
#         <td>Burkitt&#x27;s lymphoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188516007</td>
#
#         <td>Burkitt&#x27;s lymphoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188517003</td>
#
#         <td>Burkitt&#x27;s lymphoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188524002</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188526000</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188529007</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188531003</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188534006</td>
#
#         <td>Hodgkin&#x27;s granuloma of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188536008</td>
#
#         <td>Hodgkin&#x27;s granuloma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188537004</td>
#
#         <td>Hodgkin&#x27;s granuloma of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188538009</td>
#
#         <td>Hodgkin&#x27;s granuloma of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188541000</td>
#
#         <td>Hodgkin&#x27;s granuloma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188544008</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188547001</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188548006</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188551004</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188554007</td>
#
#         <td>Hodgkin&#x27;s disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188558005</td>
#
#         <td>Hodgkin&#x27;s disease, lymphocytic-histiocytic predominance of lymph nodes of axilla and upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>188559002</td>
#
#         <td>Hodgkin&#x27;s disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region and lower limb</td>
#
#       </tr>
#
#       <tr>
#
# ...
#
#         <td>93546006</td>
#
#         <td>Hodgkin&#x27;s paragranuloma of extranodal AND/OR solid organ site</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93547002</td>
#
#         <td>Hodgkin&#x27;s sarcoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93548007</td>
#
#         <td>Hodgkin&#x27;s sarcoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93549004</td>
#
#         <td>Hodgkin&#x27;s sarcoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93550004</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of axilla AND/OR upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93551000</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of head, face AND/OR neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93552007</td>
#
#         <td>Hodgkin&#x27;s sarcoma of lymph nodes of inguinal region AND/OR lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93554008</td>
#
#         <td>Hodgkin&#x27;s sarcoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>93555009</td>
#
#         <td>Hodgkin&#x27;s sarcoma of extranodal AND/OR solid organ site</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94686001</td>
#
#         <td>Mixed cell type lymphosarcoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94687005</td>
#
#         <td>Mixed cell type lymphosarcoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94688000</td>
#
#         <td>Mixed cell type lymphosarcoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94690004</td>
#
#         <td>Mixed cell type lymphosarcoma of lymph nodes of head, face, and neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94704006</td>
#
#         <td>Multiple myeloma in remission</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94707004</td>
#
#         <td>Mycosis fungoides of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94708009</td>
#
#         <td>Mycosis fungoides of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94709001</td>
#
#         <td>Mycosis fungoides of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94710006</td>
#
#         <td>Mycosis fungoides of lymph nodes of axilla AND/OR upper limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94711005</td>
#
#         <td>Mycosis fungoides of lymph nodes of head, face AND/OR neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94712003</td>
#
#         <td>Mycosis fungoides of lymph nodes of inguinal region AND/OR lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94714002</td>
#
#         <td>Mycosis fungoides of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94715001</td>
#
#         <td>Mycosis fungoides of extranodal AND/OR solid organ site</td>
#
#       </tr>
#
#       <tr>
#
#         <td>94719007</td>
#
#         <td>Myeloid sarcoma, disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95186006</td>
#
#         <td>Nodular lymphoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95187002</td>
#
#         <td>Nodular lymphoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95188007</td>
#
#         <td>Nodular lymphoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95192000</td>
#
#         <td>Nodular lymphoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95193005</td>
#
#         <td>Nodular lymphoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95194004</td>
#
#         <td>Nodular lymphoma of extranodal AND/OR solid organ site</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95209008</td>
#
#         <td>Plasma cell leukemia in remission</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95210003</td>
#
#         <td>Plasma cell leukemia, disease</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95224004</td>
#
#         <td>Reticulosarcoma of intra-abdominal lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95225003</td>
#
#         <td>Reticulosarcoma of intrapelvic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95226002</td>
#
#         <td>Reticulosarcoma of intrathoracic lymph nodes</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95230004</td>
#
#         <td>Reticulosarcoma of lymph nodes of multiple sites</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95231000</td>
#
#         <td>Reticulosarcoma of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95260009</td>
#
#         <td>Sézary&#x27;s disease of lymph nodes of head, face AND/OR neck</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95261008</td>
#
#         <td>Sézary&#x27;s disease of lymph nodes of inguinal region AND/OR lower limb</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95263006</td>
#
#         <td>Sézary&#x27;s disease of spleen</td>
#
#       </tr>
#
#       <tr>
#
#         <td>95264000</td>
#
#         <td>Sézary&#x27;s disease of extranodal AND/OR solid organ site</td>
#
#       </tr>
#
#   </tbody>
# </table>
#
#
#
# </div>
#
#
#
#           <div
#       class="tab-pane fade p-4 "
#       id="tree"
#       role="tabpanel"
#       aria-labelledby="tree-tab"
# >
#   <div id="tree-data"></div>
#
# </div>
#
#
#
#
#       </div>
#     </div>
#   </div>
#
#   <div
#   class="modal fade"
#   id="js-publish-version-form"
#   tabindex="-1"
#   role="dialog"
#   aria-labelledby="publish-version-label"
#   aria-hidden="true"
# >
#   <div class="modal-dialog" role="document">
#     <div class="modal-content">
#       <div class="modal-header">
#         <h5 class="modal-title" id="publish-version-label">Publish Version</h5>
#         <button
#           type="button"
#           class="close"
#           data-dismiss="modal"
#           aria-label="Close"
#         >
#           <span aria-hidden="true">&times;</span>
#         </button>
#       </div>
#
#       <div class="modal-body">
#         <form method="POST" action="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/publish/">
#           <input type="hidden" name="csrfmiddlewaretoken" value="NJimnE7AS4KeCs4XQaVLvVDfjmb1x5Eg84wD6hDuD4FGrGRHPcdEGDBOXm22ACMH">
#
#           <p>Publishing a version is irreversible, and will delete any other draft versions or versions under review.</p>
#           <p>Are you sure you want to continue?</p>
#
#           <div class="d-flex justify-content-between">
#             <button
#               type="button"
#               class="btn btn-secondary"
#               data-dismiss="modal"
#             >
#               Cancel
#             </button>
#             <button type="submit" class="btn btn-primary">
#               Publish
#             </button>
#           </div>
#         </form>
#       </div>
#     </div>
#   </div>
# </div>
#
#
#   <div
#   class="modal fade"
#   id="js-delete-version-form"
#   tabindex="-1"
#   role="dialog"
#   aria-labelledby="delete-version-label"
#   aria-hidden="true"
# >
#   <div class="modal-dialog" role="document">
#     <div class="modal-content">
#       <div class="modal-header">
#         <h5 class="modal-title" id="delete-version-label">Delete Version</h5>
#         <button
#           type="button"
#           class="close"
#           data-dismiss="modal"
#           aria-label="Close"
#         >
#           <span aria-hidden="true">&times;</span>
#         </button>
#       </div>
#
#       <div class="modal-body">
#         <form method="POST" action="/codelist/nhsd-primary-care-domain-refsets/c19haemcan_cod/20241205/delete/">
#           <input type="hidden" name="csrfmiddlewaretoken" value="NJimnE7AS4KeCs4XQaVLvVDfjmb1x5Eg84wD6hDuD4FGrGRHPcdEGDBOXm22ACMH">
#
#           <p>Deleting a version is irreversible.</p>
#           <p>Are you sure you want to continue?</p>
#
#           <div class="d-flex justify-content-between">
#             <button
#               type="button"
#               class="btn btn-secondary"
#               data-dismiss="modal"
#             >
#               Cancel
#             </button>
#             <button type="submit" class="btn btn-primary">
#               Delete
#             </button>
#           </div>
#         </form>
#       </div>
#     </div>
#   </div>
# </div>
#
#
#
#         </div>
#       </main>
#
#       <footer id="footer" class="border-top bg-light mt-auto py-5">
#         <div class="container">
#           <ul class="list-inline text-center d-flex flex-column flex-md-row justify-content-center mb-0 mb-md-3">
#             <li class="list-inline-item mb-3 mb-md-0 mr-0 mr-md-5">
#               <a href="/docs/">
#                 Documentation
#               </a>
#             </li>
#
#             <li class="list-inline-item mb-3 mb-md-0 mr-0">
#               <a href="https://www.opensafely.org/">
#                 OpenSAFELY
#               </a>
#             </li>
#           </ul>
#
#           <ul class="list-inline text-center d-flex flex-column flex-md-row justify-content-center">
#             <li class="list-inline-item mb-3 mb-md-0 mr-0 mr-md-5">
#               <a href="https://www.bennett.ox.ac.uk/">
#                 Bennett Institute for Applied Data Science
#               </a>
#             </li>
#
#             <li class="list-inline-item mb-3 mb-md-0">
#               <a href="https://www.ox.ac.uk/">
#                 University of Oxford
#               </a>
#             </li>
#           </ul>
#
#           <div class="row">
#             <div class="col-12 offset-md-1 col-md-10 offset-lg-2 col-lg-8 text-center mt-3 mb-0 small">
#               <p>© University of Oxford for the Bennett Institute for Applied Data Science 2025. This work may be copied freely for non-commercial research and study. If you wish to do any of the other acts restricted by the copyright you should apply in writing to <a href="/cdn-cgi/l/email-protection#374352565a7758475259445651525b4e19584550"><span class="__cf_email__" data-cfemail="6c18090d012c031c09021f0d0a09001542031e0b">[email&#160;protected]</span></a>.</p>
#               <p>SNOMED Clinical Terms® content © International Health Terminology Standards Development Organisation.</p>
#               <p>ICD-10 codes, terms and text © World Health Organization, Third Edition. 2007.</p>
#             </div>
#           </div>
#         </div>
#       </footer>
#
#
#   <link  rel="stylesheet" href="/static/assets/codelists-version-BklLYHyO.css" />
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="module" crossorigin="" src="/static/assets/codelists-version-DEmGulSF.js"></script>
# <link href="/static/assets/_commonjsHelpers-gnU0ypJ3.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
# <link href="/static/assets/jquery-BQXThELV.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
#
#   <script id="tree_data" type="application/json">[{"title": "Disorder", "children": [{"id": "445105005", "name": "Blastic plasmacytoid dendritic cell neoplasm", "status": "+", "children": [], "depth": 0}, {"id": "705127009", "name": "Gingivitis due to leukemia", "status": "+", "children": [], "depth": 0}, {"id": "1153397003", "name": "Hydroa vacciniforme-like cutaneous T-cell lymphoma", "status": "+", "children": [], "depth": 0}, {"id": "763719001", "name": "Hydroa vacciniforme-like lymphoma", "status": "+", "children": [], "depth": 0}, {"id": "1237617004", "name": "Hypereosinophilic syndrome due to disease", "status": "+", "children": [], "depth": 0}, {"id": "426202004", "name": "Immune reconstitution syndrome", "status": "+", "children": [], "depth": 0}, {"id": "103077004", "name": "Immunodeficiency secondary to neoplasm", "status": "+", "children": [], "depth": 0}, {"id": "16894711000119103", "name": "Immunoglobulin G deficiency due to multiple myeloma", "status": "+", "children": [], "depth": 0}, {"id": "65399007", "name": "Langerhans cell histiocytosis", "status": "+", "children": [{"id": "129000002", "name": "Eosinophilic granuloma", "status": "+", "children": [{"id": "238476000", "name": "Eosinophilic granuloma of bone", "status": "-", "children": [], "depth": 2}, {"id": "8090002", "name": "Eosinophilic granuloma of oral mucosa", "status": "-", "children": [], "depth": 2}, {"id": "7021009", "name": "Gastrointestinal eosinophilic granuloma", "status": "-", "children": [], "depth": 2}, {"id": "28122003", "name": "Pulmonary eosinophilic granuloma", "status": "+", "children": [], "depth": 2}], "depth": 1}, {"id": "404160007", "name": "Langerhans cell histiocytosis - Hashimoto-Pritzker type", "status": "-", "children": [], "depth": 1}, {"id": "417152008", "name": "Langerhans cell histiocytosis of lung", "status": "-", "children": [{"id": "328611000119105", "name": "Adult pulmonary Langerhans cell histiocytosis", "status": "-", "children": [], "depth": 2}, {"id": "28122003", "name": "Pulmonary eosinophilic granuloma", "status": "+", "children": [], "depth": 2}], "depth": 1}, {"id": "707432004", "name": "Langerhans cell histiocytosis of skin", "status": "-", "children": [{"id": "707431006", "name": "Langerhans cell histiocytosis of diaper area", "status": "-", "children": [], "depth": 2}], "depth": 1}, {"id": "118614007", "name": "Langerhans cell histiocytosis, disseminated", "status": "+", "children": [{"id": "1332431001", "name": "Disseminated Langerhans cell histiocytosis of abdominal lymph nodes", "status": "-", "children": [{"id": "1332430000", "name": "Disseminated Langerhans cell histiocytosis of pelvic lymph nodes", "status": "-", "children": [], "depth": 3}], "depth": 2}, {"id": "1332476001", "name": "Disseminated Langerhans cell histiocytosis of bone", "status": "-", "children": [], "depth": 2}, {"id": "1332426003", "name": "Disseminated Langerhans cell histiocytosis of cervical lymph nodes", "status": "-", "children": [], "depth": 2}, {"id": "1332425004", "name": "Disseminated Langerhans cell histiocytosis of lymph nodes of head", "status": "-", "children": [], "depth": 2}, {"id": "1332422001", "name": "Disseminated Langerhans cell histiocytosis of lymph nodes of lower limb", "status": "-", "children": [], "depth": 2}, {"id": "1332428002", "name": "Disseminated Langerhans cell histiocytosis of lymph nodes of multiple sites", "status": "-", "children": [], "depth": 2}, {"id": "1332429005", "name": "Disseminated Langerhans cell histiocytosis of lymph nodes of thorax", "status": "-", "children": [], "depth": 2}, {"id": "1332423006", "name": "Disseminated Langerhans cell histiocytosis of lymph nodes of upper limb", "status": "-", "children": [], "depth": 2}, {"id": "1332427007", "name": "Disseminated Langerhans cell histiocytosis of spleen", "status": "-", "children": [], "depth": 2}], "depth": 1}, {"id": "697922003", "name": "Pulmonary hypertension in Langerhans cell histiocytosis", "status": "-", "children": [], "dept ...
#
#
#   <script type="module" crossorigin="" src="/static/assets/tree-Cuo8QRH0.js"></script>
# <link href="/static/assets/_utils-BztczeVn.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
# <link href="/static/assets/_commonjsHelpers-gnU0ypJ3.js" type="text/javascript" crossorigin="anonymous" rel="modulepreload" as="script" />
#
#     </body>
#   </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text,'html.parser')

# %%
tabpane = soup.select('div#full-list.tab-pane')
tabpane
# Out:
# [<div aria-labelledby="full-list-tab" class="tab-pane fade p-4" id="full-list" role="tabpanel">
#  <table class="table table-sm" id="js-codelist-table">
#  <thead>
#  <th>code</th>
#  <th>term</th>
#  </thead>
#  <tbody>
#  <tr>
#  <td>103077004</td>
#  <td>Immunodeficiency secondary to neoplasm</td>
#  </tr>
#  <tr>
#  <td>108521000119103</td>
#  <td>History of reticulosarcoma</td>
#  </tr>
#  <tr>
#  <td>1090241000000107</td>
#  <td>Angioimmunoblastic T-cell lymphoma with dysproteinaemia</td>
#  </tr>
#  <tr>
#  <td>1091861000000100</td>
#  <td>Follicular lymphoma, cutaneous follicle centre</td>
#  </tr>
#  <tr>
#  <td>1091891000000106</td>
#  <td>B-cell Hodgkin's lymphoma</td>
#  </tr>
#  <tr>
#  <td>1091921000000103</td>
#  <td>B-cell non-Hodgkin's lymphoma</td>
#  </tr>
#  <tr>
#  <td>109962001</td>
#  <td>Diffuse non-Hodgkin's lymphoma</td>
#  </tr>
#  <tr>
#  <td>109964000</td>
#  <td>Diffuse non-Hodgkin's lymphoma, undifferentiated</td>
#  </tr>
#  <tr>
#  <td>109965004</td>
#  <td>Diffuse non-Hodgkin's lymphoma, lymphoblastic</td>
#  </tr>
#  <tr>
#  <td>109966003</td>
#  <td>Diffuse non-Hodgkin's lymphoma, immunoblastic</td>
#  </tr>
#  <tr>
#  <td>109967007</td>
#  <td>Diffuse non-Hodgkin's lymphoma, small cleaved cell</td>
#  </tr>
#  <tr>
#  <td>109968002</td>
#  <td>Diffuse non-Hodgkin's lymphoma, small cell</td>
#  </tr>
#  <tr>
#  <td>109969005</td>
#  <td>Diffuse large B-cell malignant lymphoma</td>
#  </tr>
#  <tr>
#  <td>109970006</td>
#  <td>Follicular non-Hodgkin's lymphoma, small cleaved cell</td>
#  </tr>
#  <tr>
#  <td>109971005</td>
#  <td>Follicular non-Hodgkin's lymphoma, mixed small cleaved cell and large cell</td>
#  </tr>
#  <tr>
#  <td>109972003</td>
#  <td>Follicular non-Hodgkin's lymphoma, large cell</td>
#  </tr>
#  <tr>
#  <td>109975001</td>
#  <td>T-zone lymphoma</td>
#  </tr>
#  <tr>
#  <td>109976000</td>
#  <td>Lymphoepithelioid lymphoma</td>
#  </tr>
#  <tr>
#  <td>109977009</td>
#  <td>Peripheral T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>109978004</td>
#  <td>T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>109979007</td>
#  <td>B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>109980005</td>
#  <td>Malignant immunoproliferative disease</td>
#  </tr>
#  <tr>
#  <td>109981009</td>
#  <td>Waldenström macroglobulinemia</td>
#  </tr>
#  <tr>
#  <td>109985000</td>
#  <td>Immunoproliferative small intestinal disease</td>
#  </tr>
#  <tr>
#  <td>109988003</td>
#  <td>Histiocytic sarcoma</td>
#  </tr>
#  <tr>
#  <td>109989006</td>
#  <td>Multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>109991003</td>
#  <td>Acute panmyelosis with myelofibrosis</td>
#  </tr>
#  <tr>
#  <td>109992005</td>
#  <td>Polycythemia vera</td>
#  </tr>
#  <tr>
#  <td>110000005</td>
#  <td>Refractory anemia with excess blasts in transformation</td>
#  </tr>
#  <tr>
#  <td>110002002</td>
#  <td>Mast cell leukemia</td>
#  </tr>
#  <tr>
#  <td>110004001</td>
#  <td>Acute promyelocytic leukemia, FAB M3</td>
#  </tr>
#  <tr>
#  <td>110005000</td>
#  <td>Acute myelomonocytic leukemia, FAB M4</td>
#  </tr>
#  <tr>
#  <td>110006004</td>
#  <td>Prolymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>110007008</td>
#  <td>Adult T-cell leukemia/lymphoma</td>
#  </tr>
#  <tr>
#  <td>1148845007</td>
#  <td>Follicular lymphoma grade 3b</td>
#  </tr>
#  <tr>
#  <td>1148851002</td>
#  <td>Follicular lymphoma grade 3a</td>
#  </tr>
#  <tr>
#  <td>1148888004</td>
#  <td>Nodular glomerulosclerosis due to heavy chain deposition disease</td>
#  </tr>
#  <tr>
#  <td>1148906001</td>
#  <td>Acute myeloid leukemia with t(8;21)(q22;q22) RUNX1-RUNX1T1</td>
#  </tr>
#  <tr>
#  <td>1153336009</td>
#  <td>Pediatric nodal marginal zone B cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>1153341001</td>
#  <td>Myeloproliferative hypereosinophilic syndrome</td>
#  </tr>
#  <tr>
#  <td>1153346006</td>
#  <td>Primary non-Hodgkin malignant lymphoma of uveal tract</td>
#  </tr>
#  <tr>
#  <td>1153347002</td>
#  <td>Primary non-Hodgkin malignant lymphoma of vitreoretinal tract</td>
#  </tr>
#  <tr>
#  <td>1153348007</td>
#  <td>Primary effusion lymphoma due to human immune deficiency virus infection</td>
#  </tr>
#  <tr>
#  <td>1153349004</td>
#  <td>Primary familial polycythemia due to erythropoietin receptor mutation</td>
#  </tr>
#  <tr>
#  <td>1153354008</td>
#  <td>Malignant lymphoma of duodenum</td>
#  </tr>
#  <tr>
#  <td>1153355009</td>
#  <td>Malignant lymphoma of esophagus</td>
#  </tr>
#  <tr>
#  <td>1153356005</td>
#  <td>Lymphoma of anus</td>
#  </tr>
#  <tr>
#  <td>1153357001</td>
#  <td>Lymphoma of appendix</td>
#  </tr>
#  <tr>
#  <td>1153377008</td>
#  <td>Mixed phenotype acute leukemia with t(9;22) (q34;q11.2); BCR-ABL1</td>
#  </tr>
#  <tr>
#  <td>1153379006</td>
#  <td>Mixed phenotype acute leukemia with T-cell and myeloid lineage</td>
#  </tr>
#  <tr>
#  <td>1153381008</td>
#  <td>Mixed phenotype acute leukemia with myeloid and B-cell lymphoid phenotypes</td>
#  </tr>
#  <tr>
#  <td>1153382001</td>
#  <td>Malignant lymphoma of lacrimal gland</td>
#  </tr>
#  <tr>
#  <td>1153383006</td>
#  <td>Malignant lymphoma of liver</td>
#  </tr>
#  <tr>
#  <td>1153397003</td>
#  <td>Hydroa vacciniforme-like cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>1156403002</td>
#  <td>Composite Hodgkin and non-Hodgkin lymphoma</td>
#  </tr>
#  <tr>
#  <td>1157157006</td>
#  <td>Acute myeloid leukemia with 11q23 abnormality</td>
#  </tr>
#  <tr>
#  <td>1157162007</td>
#  <td>Intravascular large B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>1162264008</td>
#  <td>Malignant lymphoma of uveal tract</td>
#  </tr>
#  <tr>
#  <td>1162531007</td>
#  <td>Acute myeloid leukemia in complete remission</td>
#  </tr>
#  <tr>
#  <td>116691000119101</td>
#  <td>Marginal zone lymphoma of spleen</td>
#  </tr>
#  <tr>
#  <td>116811000119106</td>
#  <td>Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of lower limb</td>
#  </tr>
#  <tr>
#  <td>116821000119104</td>
#  <td>Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of upper limb</td>
#  </tr>
#  <tr>
#  <td>116841000119105</td>
#  <td>Marginal zone lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>116871000119103</td>
#  <td>Mantle cell lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>117211000119105</td>
#  <td>Peripheral T-cell lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>1172516002</td>
#  <td>High-dose chemotherapy with stem cell transplant</td>
#  </tr>
#  <tr>
#  <td>1172704005</td>
#  <td>High grade B-cell lymphoma with MYC and BCL2 and/or BCL6 rearrangements</td>
#  </tr>
#  <tr>
#  <td>118599009</td>
#  <td>Hodgkin's disease</td>
#  </tr>
#  <tr>
#  <td>118600007</td>
#  <td>Malignant lymphoma</td>
#  </tr>
#  <tr>
#  <td>118601006</td>
#  <td>Non-Hodgkin's lymphoma</td>
#  </tr>
#  <tr>
#  <td>118602004</td>
#  <td>Hodgkin's granuloma</td>
#  </tr>
#  <tr>
#  <td>118605002</td>
#  <td>Hodgkin lymphoma, nodular lymphocyte predominance</td>
#  </tr>
#  <tr>
#  <td>118606001</td>
#  <td>Hodgkin's sarcoma</td>
#  </tr>
#  <tr>
#  <td>118607005</td>
#  <td>Hodgkin lymphoma, lymphocyte-rich</td>
#  </tr>
#  <tr>
#  <td>118608000</td>
#  <td>Hodgkin's disease, nodular sclerosis</td>
#  </tr>
#  <tr>
#  <td>118609008</td>
#  <td>Hodgkin's disease, mixed cellularity</td>
#  </tr>
#  <tr>
#  <td>118610003</td>
#  <td>Hodgkin's disease, lymphocytic depletion</td>
#  </tr>
#  <tr>
#  <td>118611004</td>
#  <td>Sézary's disease</td>
#  </tr>
#  <tr>
#  <td>118612006</td>
#  <td>Malignant histiocytosis</td>
#  </tr>
#  <tr>
#  <td>118613001</td>
#  <td>Hairy cell leukemia</td>
#  </tr>
#  <tr>
#  <td>118614007</td>
#  <td>Langerhans cell histiocytosis, disseminated</td>
#  </tr>
#  <tr>
#  <td>118615008</td>
#  <td>Malignant mast cell tumor</td>
#  </tr>
#  <tr>
#  <td>118617000</td>
#  <td>Burkitt's lymphoma</td>
#  </tr>
#  <tr>
#  <td>118618005</td>
#  <td>Mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>1187123005</td>
#  <td>Mixed phenotype acute leukemia</td>
#  </tr>
#  <tr>
#  <td>1196900003</td>
#  <td>B cell lymphoma of small intestine</td>
#  </tr>
#  <tr>
#  <td>1197344000</td>
#  <td>T-cell lymphoma of small intestine</td>
#  </tr>
#  <tr>
#  <td>120481000119109</td>
#  <td>History of multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>12149006</td>
#  <td>Chemotherapy administration, subcutaneous, with local anesthesia</td>
#  </tr>
#  <tr>
#  <td>1217301006</td>
#  <td>Precursor cell lymphoblastic lymphoma</td>
#  </tr>
#  <tr>
#  <td>122571000119106</td>
#  <td>History of malignant cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>12281000132104</td>
#  <td>Relapsing acute myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>1228842003</td>
#  <td>Primary cutaneous plasmacytosis</td>
#  </tr>
#  <tr>
#  <td>12291000132102</td>
#  <td>Refractory acute myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>1229988003</td>
#  <td>Myeloid and/or lymphoid neoplasm with pericentriolar material 1-janus kinase 2</td>
#  </tr>
#  <tr>
#  <td>12301000132103</td>
#  <td>Acute lymphoid leukemia relapse</td>
#  </tr>
#  <tr>
#  <td>12311000132101</td>
#  <td>Refractory acute lymphoid leukemia</td>
#  </tr>
#  <tr>
#  <td>1231732006</td>
#  <td>Smoldering systemic mastocytosis</td>
#  </tr>
#  <tr>
#  <td>12341000132100</td>
#  <td>B-cell lymphoma, unclassifiable, with features intermediate between diffuse large B-cell lymphoma and Burkitt lymphoma</td>
#  </tr>
#  <tr>
#  <td>1237368006</td>
#  <td>Acute myeloid leukemia with BCR-ABL1</td>
#  </tr>
#  <tr>
#  <td>1237578005</td>
#  <td>Primary oculocerebral non-Hodgkin lymphoma</td>
#  </tr>
#  <tr>
#  <td>1237617004</td>
#  <td>Hypereosinophilic syndrome due to disease</td>
#  </tr>
#  <tr>
#  <td>1254741007</td>
#  <td>Intensification antineoplastic therapy regimen</td>
#  </tr>
#  <tr>
#  <td>1254742000</td>
#  <td>Delayed intensification antineoplastic therapy regimen</td>
#  </tr>
#  <tr>
#  <td>1255270006</td>
#  <td>Lymphoplasmacytic lymphoma without immunoglobulin M production</td>
#  </tr>
#  <tr>
#  <td>1255666008</td>
#  <td>Hodgkin lymphoma, lymphocyte depletion of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255687003</td>
#  <td>Hodgkin lymphoma, lymphocyte depletion of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255726001</td>
#  <td>Hodgkin granuloma of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255727005</td>
#  <td>Hodgkin granuloma of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255728000</td>
#  <td>Hodgkin granuloma of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255729008</td>
#  <td>Mast cell malignancy of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255730003</td>
#  <td>Mast cell malignancy of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255737000</td>
#  <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255738005</td>
#  <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255739002</td>
#  <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255740000</td>
#  <td>Letterer-Siwe disease of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255741001</td>
#  <td>Letterer-Siwe disease of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255742008</td>
#  <td>Letterer-Siwe disease of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255743003</td>
#  <td>Hodgkin sarcoma of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255744009</td>
#  <td>Hodgkin sarcoma of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255745005</td>
#  <td>Hodgkin sarcoma of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255746006</td>
#  <td>Malignant histiocytosis of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255747002</td>
#  <td>Malignant histiocytosis of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255748007</td>
#  <td>Malignant histiocytosis of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255749004</td>
#  <td>Burkitt tumor of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255750004</td>
#  <td>Burkitt tumor of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255751000</td>
#  <td>Burkitt tumor of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255752007</td>
#  <td>Mycosis fungoides of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255753002</td>
#  <td>Mycosis fungoides of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255754008</td>
#  <td>Mycosis fungoides of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255784000</td>
#  <td>Hodgkin paragranuloma of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255785004</td>
#  <td>Hodgkin paragranuloma of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255786003</td>
#  <td>Hodgkin paragranuloma of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255788002</td>
#  <td>Hodgkin disease, mixed cellularity of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255789005</td>
#  <td>Hodgkin disease, mixed cellularity of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255790001</td>
#  <td>Hodgkin disease, mixed cellularity of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255791002</td>
#  <td>Hodgkin disease, nodular sclerosis of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255792009</td>
#  <td>Hodgkin disease, nodular sclerosis of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255793004</td>
#  <td>Hodgkin disease, nodular sclerosis of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255795006</td>
#  <td>Malignant histiocytosis of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255796007</td>
#  <td>Burkitt lymphoma of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255797003</td>
#  <td>Hodgkin disease, nodular sclerosis of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255798008</td>
#  <td>Hodgkin granuloma of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255799000</td>
#  <td>Sézary disease of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255800001</td>
#  <td>Sézary disease of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255801002</td>
#  <td>Sézary disease of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255802009</td>
#  <td>Hodgkin disease of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255803004</td>
#  <td>Hodgkin disease of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255804005</td>
#  <td>Hodgkin disease of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255805006</td>
#  <td>Malignant lymphoma of lymph nodes of head</td>
#  </tr>
#  <tr>
#  <td>1255806007</td>
#  <td>Malignant lymphoma of lymph nodes of neck</td>
#  </tr>
#  <tr>
#  <td>1255807003</td>
#  <td>Malignant lymphoma of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>1255808008</td>
#  <td>Hodgkin sarcoma of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255809000</td>
#  <td>Malignant mast cell tumor of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255811009</td>
#  <td>Hodgkin disease, mixed cellularity of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255812002</td>
#  <td>Hodgkin disease, nodular sclerosis of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255813007</td>
#  <td>Letterer-Siwe disease of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255814001</td>
#  <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255815000</td>
#  <td>Malignant histiocytosis of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255831008</td>
#  <td>Chemotherapy for malignant neoplastic disease using targeted agent</td>
#  </tr>
#  <tr>
#  <td>1255834000</td>
#  <td>Administration of antineoplastic chemotherapy into peritoneal cavity</td>
#  </tr>
#  <tr>
#  <td>1255883001</td>
#  <td>Hodgkin sarcoma of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255885008</td>
#  <td>Letterer-Siwe disease of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255886009</td>
#  <td>Mycosis fungoides of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255887000</td>
#  <td>Hodgkin's paragranuloma of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255888005</td>
#  <td>Hodgkin paragranuloma of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255890006</td>
#  <td>Hodgkin disease, lymphocytic depletion of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255892003</td>
#  <td>Hodgkin disease, lymphocytic depletion of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255894002</td>
#  <td>Hodgkin granuloma of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255895001</td>
#  <td>Burkitt lymphoma of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255897009</td>
#  <td>Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255898004</td>
#  <td>Hodgkin disease, mixed cellularity of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255899007</td>
#  <td>Malignant mast cell tumor of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255902005</td>
#  <td>Hodgkin disease of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1255904006</td>
#  <td>Administration of palliative antineoplastic agent</td>
#  </tr>
#  <tr>
#  <td>1255905007</td>
#  <td>Hodgkin disease of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255906008</td>
#  <td>Malignant lymphoma of lymph nodes of upper limb</td>
#  </tr>
#  <tr>
#  <td>1255907004</td>
#  <td>Malignant lymphoma of lymph nodes of lower limb</td>
#  </tr>
#  <tr>
#  <td>1258932003</td>
#  <td>Natural killer-lymphoblastic leukemia/lymphoma</td>
#  </tr>
#  <tr>
#  <td>1259200004</td>
#  <td>Neoadjuvant antineoplastic chemotherapy</td>
#  </tr>
#  <tr>
#  <td>1260268001</td>
#  <td>Myelodysplastic syndrome with low blasts</td>
#  </tr>
#  <tr>
#  <td>1260406003</td>
#  <td>Myelodysplastic neoplasm with biallelic TP53 inactivation</td>
#  </tr>
#  <tr>
#  <td>1264416003</td>
#  <td>Unclassifiable myelodysplastic syndrome</td>
#  </tr>
#  <tr>
#  <td>1264458000</td>
#  <td>Acute undifferentiated leukemia</td>
#  </tr>
#  <tr>
#  <td>127066000</td>
#  <td>Familial polycythemia vera</td>
#  </tr>
#  <tr>
#  <td>127070008</td>
#  <td>Malignant histiocytic disorder</td>
#  </tr>
#  <tr>
#  <td>127220001</td>
#  <td>Malignant lymphoma of lymph nodes</td>
#  </tr>
#  <tr>
#  <td>127225006</td>
#  <td>Chronic myelomonocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>127911000119105</td>
#  <td>Light chain nephropathy due to multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>1286863002</td>
#  <td>Metastatic malignant neoplasm to cecum and/or colon and/or rectum</td>
#  </tr>
#  <tr>
#  <td>128874001</td>
#  <td>Cutaneous CD30+ lymphoproliferative disorder</td>
#  </tr>
#  <tr>
#  <td>128875000</td>
#  <td>Primary cutaneous CD30 antigen positive large T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>129000002</td>
#  <td>Eosinophilic granuloma</td>
#  </tr>
#  <tr>
#  <td>13048006</td>
#  <td>Orbital lymphoma</td>
#  </tr>
#  <tr>
#  <td>133751000119102</td>
#  <td>Lymphoma of colon</td>
#  </tr>
#  <tr>
#  <td>152451000119104</td>
#  <td>History of lymphosarcoma</td>
#  </tr>
#  <tr>
#  <td>152861000119104</td>
#  <td>History of myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>161436008</td>
#  <td>History of leukemia</td>
#  </tr>
#  <tr>
#  <td>1659461000000103</td>
#  <td>Janus kinase 2 positive polycythaemia vera</td>
#  </tr>
#  <tr>
#  <td>1659471000000105</td>
#  <td>Janus kinase 2 negative polycythaemia vera</td>
#  </tr>
#  <tr>
#  <td>16775311000119107</td>
#  <td>Mycosis fungoides of facial lymph node</td>
#  </tr>
#  <tr>
#  <td>16894711000119103</td>
#  <td>Immunoglobulin G deficiency due to multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>169396008</td>
#  <td>Radiomimetic chemotherapy</td>
#  </tr>
#  <tr>
#  <td>169397004</td>
#  <td>Radiochemotherapy: local infiltration</td>
#  </tr>
#  <tr>
#  <td>169398009</td>
#  <td>Radiochemotherapy: to stop spread</td>
#  </tr>
#  <tr>
#  <td>169399001</td>
#  <td>Radiochemotherapy via oral route</td>
#  </tr>
#  <tr>
#  <td>169400008</td>
#  <td>Radiochemotherapy via intravenous route</td>
#  </tr>
#  <tr>
#  <td>169401007</td>
#  <td>Radiochemotherapy: for immunosuppression</td>
#  </tr>
#  <tr>
#  <td>169402000</td>
#  <td>Radiochemotherapy: local artery</td>
#  </tr>
#  <tr>
#  <td>169403005</td>
#  <td>Radiochemotherapy: into cavity</td>
#  </tr>
#  <tr>
#  <td>171765004</td>
#  <td>Intrathecal injection of chemotherapeutic agent</td>
#  </tr>
#  <tr>
#  <td>1881000119103</td>
#  <td>History of plasmacytoma</td>
#  </tr>
#  <tr>
#  <td>188487008</td>
#  <td>Lymphosarcoma and reticulosarcoma</td>
#  </tr>
#  <tr>
#  <td>188489006</td>
#  <td>Reticulosarcoma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188492005</td>
#  <td>Reticulosarcoma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188493000</td>
#  <td>Reticulosarcoma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188498009</td>
#  <td>Lymphosarcoma</td>
#  </tr>
#  <tr>
#  <td>188500005</td>
#  <td>Lymphosarcoma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188501009</td>
#  <td>Lymphosarcoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188502002</td>
#  <td>Lymphosarcoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188503007</td>
#  <td>Lymphosarcoma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188504001</td>
#  <td>Lymphosarcoma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188505000</td>
#  <td>Lymphosarcoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188506004</td>
#  <td>Lymphosarcoma of spleen</td>
#  </tr>
#  <tr>
#  <td>188507008</td>
#  <td>Lymphosarcoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188510001</td>
#  <td>Burkitt's lymphoma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188511002</td>
#  <td>Burkitt's lymphoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188512009</td>
#  <td>Burkitt's lymphoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188513004</td>
#  <td>Burkitt lymphoma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188514005</td>
#  <td>Burkitt lymphoma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188515006</td>
#  <td>Burkitt's lymphoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188516007</td>
#  <td>Burkitt's lymphoma of spleen</td>
#  </tr>
#  <tr>
#  <td>188517003</td>
#  <td>Burkitt's lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188524002</td>
#  <td>Hodgkin's paragranuloma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188526000</td>
#  <td>Hodgkin's paragranuloma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188529007</td>
#  <td>Hodgkin's paragranuloma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188531003</td>
#  <td>Hodgkin's paragranuloma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188534006</td>
#  <td>Hodgkin's granuloma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188536008</td>
#  <td>Hodgkin's granuloma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188537004</td>
#  <td>Hodgkin's granuloma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188538009</td>
#  <td>Hodgkin's granuloma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188541000</td>
#  <td>Hodgkin's granuloma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188544008</td>
#  <td>Hodgkin's sarcoma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188547001</td>
#  <td>Hodgkin's sarcoma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188548006</td>
#  <td>Hodgkin's sarcoma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188551004</td>
#  <td>Hodgkin's sarcoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188554007</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188558005</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188559002</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188562004</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188565002</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188566001</td>
#  <td>Hodgkin's disease, nodular sclerosis of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188567005</td>
#  <td>Hodgkin's disease, nodular sclerosis of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188568000</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188569008</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188570009</td>
#  <td>Hodgkin's disease, nodular sclerosis of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188572001</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188575004</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188576003</td>
#  <td>Hodgkin's disease, mixed cellularity of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188577007</td>
#  <td>Hodgkin's disease, mixed cellularity of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188578002</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188579005</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188580008</td>
#  <td>Hodgkin's disease, mixed cellularity of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188582000</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188585003</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188586002</td>
#  <td>Hodgkin's disease, lymphocytic depletion of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188587006</td>
#  <td>Hodgkin's disease, lymphocytic depletion of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188589009</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188590000</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188591001</td>
#  <td>Hodgkin's disease, lymphocytic depletion of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188592008</td>
#  <td>Hodgkin's disease, lymphocytic depletion of spleen</td>
#  </tr>
#  <tr>
#  <td>188593003</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188609000</td>
#  <td>Nodular lymphoma of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188612002</td>
#  <td>Nodular lymphoma of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188613007</td>
#  <td>Nodular lymphoma of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188627002</td>
#  <td>Mycosis fungoides of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188630009</td>
#  <td>Sézary's disease of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188631008</td>
#  <td>Sézary's disease of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188632001</td>
#  <td>Sézary's disease of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188633006</td>
#  <td>Sézary's disease of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188634000</td>
#  <td>Sézary's disease of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188635004</td>
#  <td>Sézary's disease of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188637007</td>
#  <td>Sézary's disease of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188640007</td>
#  <td>Malignant histiocytosis of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188641006</td>
#  <td>Malignant histiocytosis of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188642004</td>
#  <td>Malignant histiocytosis of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188645002</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of head, face and neck</td>
#  </tr>
#  <tr>
#  <td>188648000</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188649008</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188660004</td>
#  <td>Malignant mast cell tumors</td>
#  </tr>
#  <tr>
#  <td>188662007</td>
#  <td>Mast cell malignancy of lymph nodes of head and neck</td>
#  </tr>
#  <tr>
#  <td>188663002</td>
#  <td>Mast cell malignancy of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188664008</td>
#  <td>Mast cell malignancy of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188665009</td>
#  <td>Mast cell malignancy of lymph nodes of axilla and upper limb</td>
#  </tr>
#  <tr>
#  <td>188666005</td>
#  <td>Mast cell malignancy of lymph nodes of inguinal region and lower limb</td>
#  </tr>
#  <tr>
#  <td>188667001</td>
#  <td>Mast cell malignancy of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>188668006</td>
#  <td>Malignant mast cell sarcoma of spleen</td>
#  </tr>
#  <tr>
#  <td>188669003</td>
#  <td>Mast cell malignancy of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>188672005</td>
#  <td>Follicular non-Hodgkin's mixed small cleaved and large cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>188674006</td>
#  <td>Diffuse malignant lymphoma - small non-cleaved cell</td>
#  </tr>
#  <tr>
#  <td>188675007</td>
#  <td>Malignant lymphoma - small cleaved cell</td>
#  </tr>
#  <tr>
#  <td>188676008</td>
#  <td>Malignant lymphoma - mixed small and large cell</td>
#  </tr>
#  <tr>
#  <td>188679001</td>
#  <td>Diffuse non-Hodgkin's lymphoma undifferentiated (diffuse)</td>
#  </tr>
#  <tr>
#  <td>188691005</td>
#  <td>Malignant immunoproliferative small intestinal disease</td>
#  </tr>
#  <tr>
#  <td>188718006</td>
#  <td>Malignant plasma cell neoplasm, extramedullary plasmacytoma</td>
#  </tr>
#  <tr>
#  <td>188725004</td>
#  <td>Lymphoid leukemia</td>
#  </tr>
#  <tr>
#  <td>188726003</td>
#  <td>Subacute lymphoid leukemia</td>
#  </tr>
#  <tr>
#  <td>188728002</td>
#  <td>Aleukemic lymphoid leukemia</td>
#  </tr>
#  <tr>
#  <td>188729005</td>
#  <td>Adult T-cell leukemia</td>
#  </tr>
#  <tr>
#  <td>188732008</td>
#  <td>Myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>188733003</td>
#  <td>Chronic eosinophilic leukemia</td>
#  </tr>
#  <tr>
#  <td>188734009</td>
#  <td>Chronic neutrophilic leukemia</td>
#  </tr>
#  <tr>
#  <td>188736006</td>
#  <td>Subacute myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>188737002</td>
#  <td>Chloroma</td>
#  </tr>
#  <tr>
#  <td>188738007</td>
#  <td>Granulocytic sarcoma</td>
#  </tr>
#  <tr>
#  <td>188741003</td>
#  <td>Aleukemic myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>188744006</td>
#  <td>Monocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188745007</td>
#  <td>Chronic monocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188746008</td>
#  <td>Subacute monocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188748009</td>
#  <td>Aleukemic monocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188754005</td>
#  <td>Megakaryocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188768003</td>
#  <td>Myelomonocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>188770007</td>
#  <td>Subacute myelomonocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>190030009</td>
#  <td>Compound leukemias</td>
#  </tr>
#  <tr>
#  <td>190955000</td>
#  <td>Histiocytosis X syndrome</td>
#  </tr>
#  <tr>
#  <td>203436008</td>
#  <td>Osteoporosis in multiple myelomatosis</td>
#  </tr>
#  <tr>
#  <td>209962000</td>
#  <td>Myeloma-associated amyloidosis</td>
#  </tr>
#  <tr>
#  <td>22733003</td>
#  <td>Chemotherapy for non-malignant neoplasm</td>
#  </tr>
#  <tr>
#  <td>230586003</td>
#  <td>Neuropathy due to multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>230857009</td>
#  <td>Injection of chemotherapeutic substance into subcutaneous reservoir</td>
#  </tr>
#  <tr>
#  <td>232075002</td>
#  <td>Lymphoma of retina</td>
#  </tr>
#  <tr>
#  <td>232681000000103</td>
#  <td>Chemotherapy delivery</td>
#  </tr>
#  <tr>
#  <td>235331000000103</td>
#  <td>Delivery of oral chemotherapy for neoplasm</td>
#  </tr>
#  <tr>
#  <td>235391000000102</td>
#  <td>Delivery of chemotherapy for neoplasm</td>
#  </tr>
#  <tr>
#  <td>236512004</td>
#  <td>Leukemic infiltrate of kidney</td>
#  </tr>
#  <tr>
#  <td>236513009</td>
#  <td>Lymphoma of kidney</td>
#  </tr>
#  <tr>
#  <td>238831000000103</td>
#  <td>Delivery of exclusively oral chemotherapy for neoplasm</td>
#  </tr>
#  <tr>
#  <td>238841000000107</td>
#  <td>Delivery of complex chemotherapy for neoplasm including prolonged infusional treatment at first attendance</td>
#  </tr>
#  <tr>
#  <td>238851000000105</td>
#  <td>Delivery of complex parenteral chemotherapy for neoplasm at first attendance</td>
#  </tr>
#  <tr>
#  <td>238861000000108</td>
#  <td>Delivery of simple parenteral chemotherapy for neoplasm at first attendance</td>
#  </tr>
#  <tr>
#  <td>239071000000100</td>
#  <td>Delivery of subsequent element of cycle of chemotherapy for neoplasm</td>
#  </tr>
#  <tr>
#  <td>240531002</td>
#  <td>African Burkitt's lymphoma</td>
#  </tr>
#  <tr>
#  <td>240794006</td>
#  <td>Splenic schistosomal giant cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>254792006</td>
#  <td>Proliferating angioendotheliomatosis</td>
#  </tr>
#  <tr>
#  <td>255101006</td>
#  <td>Sézary disease of skin</td>
#  </tr>
#  <tr>
#  <td>255102004</td>
#  <td>Angioendotheliomatosis</td>
#  </tr>
#  <tr>
#  <td>255191003</td>
#  <td>Localized malignant reticulohistiocytoma</td>
#  </tr>
#  <tr>
#  <td>265760000</td>
#  <td>Intravenous chemotherapy</td>
#  </tr>
#  <tr>
#  <td>265761001</td>
#  <td>Intramuscular chemotherapy</td>
#  </tr>
#  <tr>
#  <td>265762008</td>
#  <td>Subcutaneous chemotherapy</td>
#  </tr>
#  <tr>
#  <td>266719004</td>
#  <td>Oral chemotherapy</td>
#  </tr>
#  <tr>
#  <td>267540007</td>
#  <td>Neutropenia caused by ionizing radiation</td>
#  </tr>
#  <tr>
#  <td>268500004</td>
#  <td>Administration of prophylactic chemotherapy</td>
#  </tr>
#  <tr>
#  <td>269475001</td>
#  <td>Malignant tumor of lymphoid, hemopoietic AND/OR related tissue</td>
#  </tr>
#  <tr>
#  <td>269476000</td>
#  <td>Nodular lymphoma</td>
#  </tr>
#  <tr>
#  <td>274905008</td>
#  <td>Malignant lymphoma - lymphocytic, intermediate differentiation</td>
#  </tr>
#  <tr>
#  <td>276811008</td>
#  <td>Gastric lymphoma</td>
#  </tr>
#  <tr>
#  <td>276815004</td>
#  <td>Lymphoma of intestine</td>
#  </tr>
#  <tr>
#  <td>276836002</td>
#  <td>Primary cerebral lymphoma</td>
#  </tr>
#  <tr>
#  <td>277473004</td>
#  <td>B-cell chronic lymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>277474005</td>
#  <td>B-cell chronic lymphocytic leukemia variant</td>
#  </tr>
#  <tr>
#  <td>277543005</td>
#  <td>Malignant white blood cell disorder</td>
#  </tr>
#  <tr>
#  <td>277545003</td>
#  <td>T-cell chronic lymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>277549009</td>
#  <td>Chronic lymphocytic prolymphocytic leukemia syndrome</td>
#  </tr>
#  <tr>
#  <td>277550009</td>
#  <td>Richter's syndrome</td>
#  </tr>
#  <tr>
#  <td>277551008</td>
#  <td>Splenic lymphoma with villous lymphocytes</td>
#  </tr>
#  <tr>
#  <td>277567002</td>
#  <td>T-cell prolymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>277568007</td>
#  <td>Hairy cell leukemia variant</td>
#  </tr>
#  <tr>
#  <td>277569004</td>
#  <td>Large granular lymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>277570003</td>
#  <td>Lymphoma with spill</td>
#  </tr>
#  <tr>
#  <td>277571004</td>
#  <td>B-cell acute lymphoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277572006</td>
#  <td>Precursor B-cell acute lymphoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277573001</td>
#  <td>Common acute lymphoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277574007</td>
#  <td>Null cell acute lymphoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277575008</td>
#  <td>T-lymphoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277579002</td>
#  <td>Light chain myeloma</td>
#  </tr>
#  <tr>
#  <td>277580004</td>
#  <td>Non-secretory myeloma</td>
#  </tr>
#  <tr>
#  <td>277587001</td>
#  <td>Juvenile chronic myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>277589003</td>
#  <td>Myelodysplastic-myeloproliferative neoplasm with neutrophilia</td>
#  </tr>
#  <tr>
#  <td>277601005</td>
#  <td>Acute monoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277602003</td>
#  <td>Acute megakaryoblastic leukemia</td>
#  </tr>
#  <tr>
#  <td>277604002</td>
#  <td>Malignant myeloid-lymphoid neoplasm</td>
#  </tr>
#  <tr>
#  <td>277609007</td>
#  <td>Hodgkin's disease, lymphocytic predominance - diffuse</td>
#  </tr>
#  <tr>
#  <td>277610002</td>
#  <td>Hodgkin's disease, nodular sclerosis - lymphocytic predominance</td>
#  </tr>
#  <tr>
#  <td>277611003</td>
#  <td>Hodgkin's disease, nodular sclerosis - mixed cellularity</td>
#  </tr>
#  <tr>
#  <td>277612005</td>
#  <td>Hodgkin's disease, nodular sclerosis - lymphocytic depletion</td>
#  </tr>
#  <tr>
#  <td>277613000</td>
#  <td>Cutaneous/peripheral T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277614006</td>
#  <td>Prethymic and thymic T-cell lymphoma/leukemia</td>
#  </tr>
#  <tr>
#  <td>277615007</td>
#  <td>Low grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277616008</td>
#  <td>Diffuse low grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277617004</td>
#  <td>High grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277618009</td>
#  <td>Follicular low grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277619001</td>
#  <td>B-cell prolymphocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>277622004</td>
#  <td>Mucosa-associated lymphoma</td>
#  </tr>
#  <tr>
#  <td>277623009</td>
#  <td>Monocytoid B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277624003</td>
#  <td>Follicular malignant lymphoma - mixed cell type</td>
#  </tr>
#  <tr>
#  <td>277625002</td>
#  <td>Follicular malignant lymphoma - small cleaved cell</td>
#  </tr>
#  <tr>
#  <td>277626001</td>
#  <td>Diffuse high grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277627005</td>
#  <td>Nodular high grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277628000</td>
#  <td>Diffuse malignant lymphoma - large cleaved cell</td>
#  </tr>
#  <tr>
#  <td>277629008</td>
#  <td>Diffuse malignant lymphoma - large non-cleaved cell</td>
#  </tr>
#  <tr>
#  <td>277632006</td>
#  <td>Diffuse malignant lymphoma - centroblastic polymorphic</td>
#  </tr>
#  <tr>
#  <td>277637000</td>
#  <td>Large cell anaplastic lymphoma</td>
#  </tr>
#  <tr>
#  <td>277641001</td>
#  <td>Follicular malignant lymphoma - large cell</td>
#  </tr>
#  <tr>
#  <td>277642008</td>
#  <td>Low grade T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277643003</td>
#  <td>High grade T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277651000</td>
#  <td>Peripheral T-cell lymphoma - pleomorphic small cell</td>
#  </tr>
#  <tr>
#  <td>277653002</td>
#  <td>Peripheral T-cell lymphoma - pleomorphic medium and large cell</td>
#  </tr>
#  <tr>
#  <td>277654008</td>
#  <td>Enteropathy-associated T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>277664004</td>
#  <td>Malignant lymphoma of testis</td>
#  </tr>
#  <tr>
#  <td>278051002</td>
#  <td>Malignant lymphoma of thyroid gland</td>
#  </tr>
#  <tr>
#  <td>278052009</td>
#  <td>Malignant lymphoma of breast</td>
#  </tr>
#  <tr>
#  <td>278189009</td>
#  <td>Hypergranular promyelocytic leukemia</td>
#  </tr>
#  <tr>
#  <td>278453007</td>
#  <td>Acute biphenotypic leukemia</td>
#  </tr>
#  <tr>
#  <td>28122003</td>
#  <td>Pulmonary eosinophilic granuloma</td>
#  </tr>
#  <tr>
#  <td>285420006</td>
#  <td>Immunoglobulin A myeloma</td>
#  </tr>
#  <tr>
#  <td>285421005</td>
#  <td>Immunoglobulin G myeloma</td>
#  </tr>
#  <tr>
#  <td>285422003</td>
#  <td>Immunoglobulin D myeloma</td>
#  </tr>
#  <tr>
#  <td>285769009</td>
#  <td>Acute promyelocytic leukemia - hypogranular variant</td>
#  </tr>
#  <tr>
#  <td>285776004</td>
#  <td>Intermediate grade B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>285839005</td>
#  <td>Acute myelomonocytic leukemia - eosinophilic variant</td>
#  </tr>
#  <tr>
#  <td>29391003</td>
#  <td>Chemotherapy administration into peritoneal cavity requiring paracentesis</td>
#  </tr>
#  <tr>
#  <td>302841002</td>
#  <td>Malignant lymphoma - small lymphocytic</td>
#  </tr>
#  <tr>
#  <td>302842009</td>
#  <td>Diffuse malignant lymphoma - centroblastic</td>
#  </tr>
#  <tr>
#  <td>302845006</td>
#  <td>Nodular malignant lymphoma, lymphocytic - well differentiated</td>
#  </tr>
#  <tr>
#  <td>302848008</td>
#  <td>Nodular malignant lymphoma, lymphocytic - intermediate differentiation</td>
#  </tr>
#  <tr>
#  <td>302855005</td>
#  <td>Subacute leukemia</td>
#  </tr>
#  <tr>
#  <td>302856006</td>
#  <td>Aleukemic leukemia</td>
#  </tr>
#  <tr>
#  <td>303017006</td>
#  <td>Malignant lymphoma, convoluted cell type</td>
#  </tr>
#  <tr>
#  <td>303055001</td>
#  <td>Malignant lymphoma, follicular center cell</td>
#  </tr>
#  <tr>
#  <td>303056000</td>
#  <td>Malignant lymphoma, follicular center cell, cleaved</td>
#  </tr>
#  <tr>
#  <td>303057009</td>
#  <td>Malignant lymphoma, follicular center cell, non-cleaved</td>
#  </tr>
#  <tr>
#  <td>307341004</td>
#  <td>Atypical hairy cell leukemia</td>
#  </tr>
#  <tr>
#  <td>307591004</td>
#  <td>Malignant mastocytosis</td>
#  </tr>
#  <tr>
#  <td>307592006</td>
#  <td>Basophilic leukemia</td>
#  </tr>
#  <tr>
#  <td>307617006</td>
#  <td>Neutrophilic leukemia</td>
#  </tr>
#  <tr>
#  <td>307622006</td>
#  <td>Prolymphocytic lymphosarcoma</td>
#  </tr>
#  <tr>
#  <td>307623001</td>
#  <td>Malignant lymphoma - lymphoplasmacytic</td>
#  </tr>
#  <tr>
#  <td>307624007</td>
#  <td>Diffuse malignant lymphoma - centroblastic-centrocytic</td>
#  </tr>
#  <tr>
#  <td>307625008</td>
#  <td>Malignant lymphoma - centrocytic</td>
#  </tr>
#  <tr>
#  <td>307633009</td>
#  <td>Hodgkin's disease, lymphocytic depletion, diffuse fibrosis</td>
#  </tr>
#  <tr>
#  <td>307634003</td>
#  <td>Hodgkin's disease, lymphocytic depletion, reticular type</td>
#  </tr>
#  <tr>
#  <td>307635002</td>
#  <td>Hodgkin's disease, nodular sclerosis - cellular phase</td>
#  </tr>
#  <tr>
#  <td>307636001</td>
#  <td>Malignant lymphoma, mixed lymphocytic-histiocytic, nodular</td>
#  </tr>
#  <tr>
#  <td>307637005</td>
#  <td>Malignant lymphoma, centroblastic-centrocytic, follicular</td>
#  </tr>
#  <tr>
#  <td>307646004</td>
#  <td>Malignant lymphoma, lymphocytic, poorly differentiated, nodular</td>
#  </tr>
#  <tr>
#  <td>307647008</td>
#  <td>Malignant lymphoma, centroblastic type, follicular</td>
#  </tr>
#  <tr>
#  <td>307649006</td>
#  <td>Microglioma</td>
#  </tr>
#  <tr>
#  <td>307650006</td>
#  <td>Histiocytic medullary reticulosis</td>
#  </tr>
#  <tr>
#  <td>307651005</td>
#  <td>Primary myelofibrosis</td>
#  </tr>
#  <tr>
#  <td>308121000</td>
#  <td>Follicular lymphoma</td>
#  </tr>
#  <tr>
#  <td>31047003</td>
#  <td>Lymphomatoid papulosis</td>
#  </tr>
#  <tr>
#  <td>313427003</td>
#  <td>Lambda light chain myeloma</td>
#  </tr>
#  <tr>
#  <td>314408000</td>
#  <td>Leukemic infiltrate of choroid</td>
#  </tr>
#  <tr>
#  <td>314418005</td>
#  <td>Leukemic infiltrate of retina</td>
#  </tr>
#  <tr>
#  <td>315601005</td>
#  <td>Ambulatory chemotherapy</td>
#  </tr>
#  <tr>
#  <td>31652009</td>
#  <td>Intracavitary chemotherapy for malignant neoplasm</td>
#  </tr>
#  <tr>
#  <td>32278006</td>
#  <td>Myeloma kidney</td>
#  </tr>
#  <tr>
#  <td>328301000119102</td>
#  <td>Pancytopenia due to antineoplastic chemotherapy</td>
#  </tr>
#  <tr>
#  <td>350951000119101</td>
#  <td>B-cell lymphoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>351211000119104</td>
#  <td>B-cell lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>352251000119109</td>
#  <td>Small lymphocytic B-cell lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>352411000119109</td>
#  <td>Small lymphocytic B-cell lymphoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>352791000119108</td>
#  <td>Non-Hodgkin's lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>353211000119103</td>
#  <td>Extramedullary plasmacytoma in remission</td>
#  </tr>
#  <tr>
#  <td>354851000119101</td>
#  <td>Follicular non-Hodgkin's lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>359631009</td>
#  <td>Acute myeloid leukemia, minimal differentiation, FAB M0</td>
#  </tr>
#  <tr>
#  <td>359640008</td>
#  <td>Acute myeloid leukemia without maturation, FAB M1</td>
#  </tr>
#  <tr>
#  <td>359648001</td>
#  <td>Acute myeloid leukemia with maturation, FAB M2</td>
#  </tr>
#  <tr>
#  <td>367336001</td>
#  <td>Chemotherapy</td>
#  </tr>
#  <tr>
#  <td>371012000</td>
#  <td>Acute lymphoblastic leukemia, transitional pre-B-cell</td>
#  </tr>
#  <tr>
#  <td>371134001</td>
#  <td>Malignant lymphoma, large cell, polymorphous, immunoblastic</td>
#  </tr>
#  <tr>
#  <td>373168002</td>
#  <td>Reticulosarcoma</td>
#  </tr>
#  <tr>
#  <td>38216008</td>
#  <td>Infusion chemotherapy for malignant neoplasm</td>
#  </tr>
#  <tr>
#  <td>394894008</td>
#  <td>Pre-operative chemotherapy</td>
#  </tr>
#  <tr>
#  <td>394895009</td>
#  <td>Postoperative chemotherapy</td>
#  </tr>
#  <tr>
#  <td>394934009</td>
#  <td>Combined preoperative chemotherapy and radiotherapy</td>
#  </tr>
#  <tr>
#  <td>397008008</td>
#  <td>Aggressive lymphadenopathic mastocytosis with eosinophilia</td>
#  </tr>
#  <tr>
#  <td>397009000</td>
#  <td>Mast cell malignancy</td>
#  </tr>
#  <tr>
#  <td>397011009</td>
#  <td>Mast cell malignancy of lymph nodes</td>
#  </tr>
#  <tr>
#  <td>397015000</td>
#  <td>Systemic mastocytosis with associated clonal hematological non-mast cell lineage disease</td>
#  </tr>
#  <tr>
#  <td>39795003</td>
#  <td>Hand-Schüller-Christian disease</td>
#  </tr>
#  <tr>
#  <td>398623004</td>
#  <td>Myelodysplastic syndrome with excess blasts</td>
#  </tr>
#  <tr>
#  <td>399042005</td>
#  <td>Chemotherapy cycle</td>
#  </tr>
#  <tr>
#  <td>400001003</td>
#  <td>Primary cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>400122007</td>
#  <td>Primary cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>400347211000119102</td>
#  <td>History of acute leukemia</td>
#  </tr>
#  <tr>
#  <td>402453006</td>
#  <td>Amyloid light chain amyloidosis due to multiple myeloma</td>
#  </tr>
#  <tr>
#  <td>402879006</td>
#  <td>T-cell leukemic infiltration of skin</td>
#  </tr>
#  <tr>
#  <td>402880009</td>
#  <td>Primary cutaneous large T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>402881008</td>
#  <td>Primary cutaneous B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>402882001</td>
#  <td>Hodgkin's disease affecting skin</td>
#  </tr>
#  <tr>
#  <td>404103007</td>
#  <td>Lymphomatoid papulosis type A (CD-30 positive type)</td>
#  </tr>
#  <tr>
#  <td>404104001</td>
#  <td>Lymphomatoid papulosis type B - mycosis fungoides-like</td>
#  </tr>
#  <tr>
#  <td>404105000</td>
#  <td>Lymphomatoid papulosis type C (anaplastic large-cell lymphoma-like)</td>
#  </tr>
#  <tr>
#  <td>404106004</td>
#  <td>Lymphomatoid papulosis with Hodgkin's disease</td>
#  </tr>
#  <tr>
#  <td>404107008</td>
#  <td>Patch/plaque stage mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404108003</td>
#  <td>Poikilodermatous mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404109006</td>
#  <td>Follicular mucinosis type mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404110001</td>
#  <td>Hypomelanotic mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404111002</td>
#  <td>Lymphomatoid papulosis-associated mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404112009</td>
#  <td>Granulomatous mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404113004</td>
#  <td>Tumor stage mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404114005</td>
#  <td>Erythrodermic mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404115006</td>
#  <td>Bullous mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404116007</td>
#  <td>Mycosis fungoides with systemic infiltration</td>
#  </tr>
#  <tr>
#  <td>404117003</td>
#  <td>Spongiotic mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404118008</td>
#  <td>Syringotropic mycosis fungoides</td>
#  </tr>
#  <tr>
#  <td>404119000</td>
#  <td>Pagetoid reticulosis</td>
#  </tr>
#  <tr>
#  <td>404120006</td>
#  <td>Localized pagetoid reticulosis</td>
#  </tr>
#  <tr>
#  <td>404121005</td>
#  <td>Generalized pagetoid reticulosis</td>
#  </tr>
#  <tr>
#  <td>404122003</td>
#  <td>Leukemic infiltration of skin (chronic T-cell lymphocytic leukemia)</td>
#  </tr>
#  <tr>
#  <td>404123008</td>
#  <td>Leukemic infiltration of skin (T-cell prolymphocytic leukemia)</td>
#  </tr>
#  <tr>
#  <td>404124002</td>
#  <td>Leukemic infiltration of skin (T-cell lymphoblastic leukemia)</td>
#  </tr>
#  <tr>
#  <td>404125001</td>
#  <td>CD-30 positive anaplastic large T-cell cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404126000</td>
#  <td>CD-30 positive pleomorphic large T-cell cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404127009</td>
#  <td>CD-30 positive T-immunoblastic cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404128004</td>
#  <td>CD-30 negative cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404129007</td>
#  <td>CD-30 negative anaplastic large T-cell cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404130002</td>
#  <td>CD-30 negative pleomorphic large T-cell cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404131003</td>
#  <td>CD-30 negative T-immunoblastic cutaneous lymphoma</td>
#  </tr>
#  <tr>
#  <td>404132005</td>
#  <td>Pleomorphic small/medium-sized cell cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404133000</td>
#  <td>Subcutaneous panniculitic cutaneous T-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404134006</td>
#  <td>Anaplastic large T-cell systemic malignant lymphoma</td>
#  </tr>
#  <tr>
#  <td>404135007</td>
#  <td>Angiocentric natural killer/T-cell malignant lymphoma involving skin</td>
#  </tr>
#  <tr>
#  <td>404136008</td>
#  <td>Aggressive natural killer-cell leukemia involving skin</td>
#  </tr>
#  <tr>
#  <td>404137004</td>
#  <td>Precursor B-cell lymphoblastic lymphoma involving skin</td>
#  </tr>
#  <tr>
#  <td>404138009</td>
#  <td>Small lymphocytic B-cell lymphoma involving skin</td>
#  </tr>
#  <tr>
#  <td>404139001</td>
#  <td>Leukemic infiltration of skin in hairy-cell leukemia</td>
#  </tr>
#  <tr>
#  <td>404140004</td>
#  <td>Primary cutaneous marginal zone B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404141000</td>
#  <td>Primary cutaneous immunocytoma</td>
#  </tr>
#  <tr>
#  <td>404142007</td>
#  <td>Primary cutaneous plasmacytoma</td>
#  </tr>
#  <tr>
#  <td>404143002</td>
#  <td>Primary cutaneous follicular center B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404144008</td>
#  <td>Primary cutaneous diffuse large cell B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404145009</td>
#  <td>Primary cutaneous anaplastic large cell B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>404146005</td>
#  <td>Primary cutaneous diffuse large cell B-cell lymphoma of the leg</td>
#  </tr>
#  <tr>
#  <td>404147001</td>
#  <td>Follicular center B-cell lymphoma (nodal/systemic with skin involvement)</td>
#  </tr>
#  <tr>
#  <td>404148006</td>
#  <td>Diffuse large B-cell lymphoma (nodal/systemic with skin involvement)</td>
# ...
#  </tr>
#  <tr>
#  <td>847691000000108</td>
#  <td>Follicular lymphoma grade 3a</td>
#  </tr>
#  <tr>
#  <td>847701000000108</td>
#  <td>Follicular lymphoma grade 3b</td>
#  </tr>
#  <tr>
#  <td>847741000000106</td>
#  <td>Diffuse large B-cell lymphoma</td>
#  </tr>
#  <tr>
#  <td>84821000119100</td>
#  <td>Primary follicular dendritic cell sarcoma of spleen</td>
#  </tr>
#  <tr>
#  <td>862921000000106</td>
#  <td>Intravesical electrochemotherapy</td>
#  </tr>
#  <tr>
#  <td>863741000000108</td>
#  <td>Clinical stage A chronic lymphocytic leukaemia</td>
#  </tr>
#  <tr>
#  <td>863761000000109</td>
#  <td>Clinical stage B chronic lymphocytic leukaemia</td>
#  </tr>
#  <tr>
#  <td>863781000000100</td>
#  <td>Clinical stage C chronic lymphocytic leukaemia</td>
#  </tr>
#  <tr>
#  <td>866098005</td>
#  <td>Large B-cell lymphoma arising in HHV8-associated multicentric Castleman disease</td>
#  </tr>
#  <tr>
#  <td>866109006</td>
#  <td>Lymphocytic hypereosinophilic syndrome</td>
#  </tr>
#  <tr>
#  <td>870249004</td>
#  <td>Folinic acid, fluorouracil and irinotecan antineoplastic chemotherapy regimen</td>
#  </tr>
#  <tr>
#  <td>870250004</td>
#  <td>Fluorouracil, leucovorin, irinotecan and oxaliplatin antineoplastic chemotherapy regimen</td>
#  </tr>
#  <tr>
#  <td>87776000</td>
#  <td>Intra-arterial infusion of antineoplastic agent</td>
#  </tr>
#  <tr>
#  <td>878857009</td>
#  <td>Malignant lymphomatoid granulomatosis grade 3</td>
#  </tr>
#  <tr>
#  <td>878858004</td>
#  <td>Malignant lymphomatoid granulomatosis grade 3 of lung</td>
#  </tr>
#  <tr>
#  <td>890093004</td>
#  <td>Administration of multiple antineoplastic agents</td>
#  </tr>
#  <tr>
#  <td>896745008</td>
#  <td>Primary cutaneous CD30 antigen positive T-cell lymphoproliferative disorder</td>
#  </tr>
#  <tr>
#  <td>897713009</td>
#  <td>Antineoplastic chemoimmunotherapy</td>
#  </tr>
#  <tr>
#  <td>91855006</td>
#  <td>Acute leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>91857003</td>
#  <td>Acute lymphoid leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>91861009</td>
#  <td>Acute myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>92508006</td>
#  <td>Burkitt's tumor of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>92509003</td>
#  <td>Burkitt's tumor of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>92510008</td>
#  <td>Burkitt's tumor of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>92511007</td>
#  <td>Burkitt's tumor of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>92512000</td>
#  <td>Burkitt's tumor of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>92513005</td>
#  <td>Burkitt's tumor of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>92514004</td>
#  <td>Burkitt's tumor of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>92515003</td>
#  <td>Burkitt's tumor of spleen</td>
#  </tr>
#  <tr>
#  <td>92516002</td>
#  <td>Burkitt's tumor of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>927778271000119101</td>
#  <td>History of langerhans cell histiocytosis</td>
#  </tr>
#  <tr>
#  <td>92812005</td>
#  <td>Chronic leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>92814006</td>
#  <td>Chronic lymphoid leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>92818009</td>
#  <td>Chronic myeloid leukemia</td>
#  </tr>
#  <tr>
#  <td>93133006</td>
#  <td>Letterer-Siwe disease of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93134000</td>
#  <td>Letterer-Siwe disease of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93135004</td>
#  <td>Letterer-Siwe disease of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93136003</td>
#  <td>Letterer-Siwe disease of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93137007</td>
#  <td>Letterer-Siwe disease of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93138002</td>
#  <td>Letterer-Siwe disease of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93139005</td>
#  <td>Letterer-Siwe disease of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93140007</td>
#  <td>Letterer-Siwe disease of spleen</td>
#  </tr>
#  <tr>
#  <td>93141006</td>
#  <td>Letterer-Siwe disease of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93143009</td>
#  <td>Leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>93144003</td>
#  <td>Leukemic reticuloendotheliosis of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93145002</td>
#  <td>Leukemic reticuloendotheliosis of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93146001</td>
#  <td>Leukemic reticuloendotheliosis of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93147005</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93148000</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93149008</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93150008</td>
#  <td>Leukemic reticuloendotheliosis of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93151007</td>
#  <td>Hairy cell leukemia of spleen</td>
#  </tr>
#  <tr>
#  <td>93152000</td>
#  <td>Leukemic reticuloendotheliosis of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93182006</td>
#  <td>Malignant histiocytosis of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93183001</td>
#  <td>Malignant histiocytosis of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93184007</td>
#  <td>Malignant histiocytosis of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93185008</td>
#  <td>Malignant histiocytosis of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93186009</td>
#  <td>Malignant histiocytosis of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93187000</td>
#  <td>Malignant histiocytosis of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93188005</td>
#  <td>Malignant histiocytosis of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93189002</td>
#  <td>Malignant histiocytosis of spleen</td>
#  </tr>
#  <tr>
#  <td>93190006</td>
#  <td>Malignant histiocytosis of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93191005</td>
#  <td>Malignant lymphoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93192003</td>
#  <td>Malignant lymphoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93193008</td>
#  <td>Malignant lymphoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93194002</td>
#  <td>Malignant lymphoma of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93195001</td>
#  <td>Malignant lymphoma of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93196000</td>
#  <td>Malignant lymphoma of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93197009</td>
#  <td>Malignant lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93198004</td>
#  <td>Malignant lymphoma of spleen</td>
#  </tr>
#  <tr>
#  <td>93199007</td>
#  <td>Malignant lymphoma of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93200005</td>
#  <td>Malignant mast cell tumor of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93201009</td>
#  <td>Malignant mast cell tumor of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93202002</td>
#  <td>Malignant mast cell tumor of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93203007</td>
#  <td>Malignant mast cell tumor of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93204001</td>
#  <td>Malignant mast cell tumor of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93205000</td>
#  <td>Malignant mast cell tumor of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93206004</td>
#  <td>Malignant mast cell tumor of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93207008</td>
#  <td>Malignant mast cell tumor of spleen</td>
#  </tr>
#  <tr>
#  <td>93208003</td>
#  <td>Malignant mast cell tumor of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93451002</td>
#  <td>Erythroleukemia, FAB M6</td>
#  </tr>
#  <tr>
#  <td>93487009</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93488004</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93489007</td>
#  <td>Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93492006</td>
#  <td>Hodgkin's disease, lymphocytic depletion of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93493001</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93494007</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93495008</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93496009</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93497000</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93498005</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93500006</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of spleen</td>
#  </tr>
#  <tr>
#  <td>93501005</td>
#  <td>Hodgkin's disease, lymphocytic-histiocytic predominance of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93505001</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93506000</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93507009</td>
#  <td>Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93509007</td>
#  <td>Hodgkin's disease, mixed cellularity of spleen</td>
#  </tr>
#  <tr>
#  <td>93510002</td>
#  <td>Hodgkin's disease, mixed cellularity of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93514006</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93515007</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93516008</td>
#  <td>Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93518009</td>
#  <td>Hodgkin's disease, nodular sclerosis of spleen</td>
#  </tr>
#  <tr>
#  <td>93519001</td>
#  <td>Hodgkin's disease, nodular sclerosis of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93520007</td>
#  <td>Hodgkin's disease of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93521006</td>
#  <td>Hodgkin's disease of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93522004</td>
#  <td>Hodgkin's disease of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93523009</td>
#  <td>Hodgkin's disease of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93524003</td>
#  <td>Hodgkin's disease of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93525002</td>
#  <td>Hodgkin's disease of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93526001</td>
#  <td>Hodgkin's disease of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>93527005</td>
#  <td>Hodgkin's disease of spleen</td>
#  </tr>
#  <tr>
#  <td>93528000</td>
#  <td>Hodgkin's disease of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93530003</td>
#  <td>Hodgkin's granuloma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93531004</td>
#  <td>Hodgkin's granuloma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93532006</td>
#  <td>Hodgkin's granuloma of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93533001</td>
#  <td>Hodgkin's granuloma of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93534007</td>
#  <td>Hodgkin's granuloma of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93536009</td>
#  <td>Hodgkin's granuloma of spleen</td>
#  </tr>
#  <tr>
#  <td>93537000</td>
#  <td>Hodgkin's granuloma of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93541001</td>
#  <td>Hodgkin's paragranuloma of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93542008</td>
#  <td>Hodgkin's paragranuloma of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93543003</td>
#  <td>Hodgkin's paragranuloma of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93545005</td>
#  <td>Hodgkin's paragranuloma of spleen</td>
#  </tr>
#  <tr>
#  <td>93546006</td>
#  <td>Hodgkin's paragranuloma of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>93547002</td>
#  <td>Hodgkin's sarcoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93548007</td>
#  <td>Hodgkin's sarcoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93549004</td>
#  <td>Hodgkin's sarcoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>93550004</td>
#  <td>Hodgkin's sarcoma of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>93551000</td>
#  <td>Hodgkin's sarcoma of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>93552007</td>
#  <td>Hodgkin's sarcoma of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>93554008</td>
#  <td>Hodgkin's sarcoma of spleen</td>
#  </tr>
#  <tr>
#  <td>93555009</td>
#  <td>Hodgkin's sarcoma of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>94686001</td>
#  <td>Mixed cell type lymphosarcoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94687005</td>
#  <td>Mixed cell type lymphosarcoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94688000</td>
#  <td>Mixed cell type lymphosarcoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94690004</td>
#  <td>Mixed cell type lymphosarcoma of lymph nodes of head, face, and neck</td>
#  </tr>
#  <tr>
#  <td>94704006</td>
#  <td>Multiple myeloma in remission</td>
#  </tr>
#  <tr>
#  <td>94707004</td>
#  <td>Mycosis fungoides of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94708009</td>
#  <td>Mycosis fungoides of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94709001</td>
#  <td>Mycosis fungoides of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>94710006</td>
#  <td>Mycosis fungoides of lymph nodes of axilla AND/OR upper limb</td>
#  </tr>
#  <tr>
#  <td>94711005</td>
#  <td>Mycosis fungoides of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>94712003</td>
#  <td>Mycosis fungoides of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>94714002</td>
#  <td>Mycosis fungoides of spleen</td>
#  </tr>
#  <tr>
#  <td>94715001</td>
#  <td>Mycosis fungoides of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>94719007</td>
#  <td>Myeloid sarcoma, disease</td>
#  </tr>
#  <tr>
#  <td>95186006</td>
#  <td>Nodular lymphoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95187002</td>
#  <td>Nodular lymphoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95188007</td>
#  <td>Nodular lymphoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95192000</td>
#  <td>Nodular lymphoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>95193005</td>
#  <td>Nodular lymphoma of spleen</td>
#  </tr>
#  <tr>
#  <td>95194004</td>
#  <td>Nodular lymphoma of extranodal AND/OR solid organ site</td>
#  </tr>
#  <tr>
#  <td>95209008</td>
#  <td>Plasma cell leukemia in remission</td>
#  </tr>
#  <tr>
#  <td>95210003</td>
#  <td>Plasma cell leukemia, disease</td>
#  </tr>
#  <tr>
#  <td>95224004</td>
#  <td>Reticulosarcoma of intra-abdominal lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95225003</td>
#  <td>Reticulosarcoma of intrapelvic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95226002</td>
#  <td>Reticulosarcoma of intrathoracic lymph nodes</td>
#  </tr>
#  <tr>
#  <td>95230004</td>
#  <td>Reticulosarcoma of lymph nodes of multiple sites</td>
#  </tr>
#  <tr>
#  <td>95231000</td>
#  <td>Reticulosarcoma of spleen</td>
#  </tr>
#  <tr>
#  <td>95260009</td>
#  <td>Sézary's disease of lymph nodes of head, face AND/OR neck</td>
#  </tr>
#  <tr>
#  <td>95261008</td>
#  <td>Sézary's disease of lymph nodes of inguinal region AND/OR lower limb</td>
#  </tr>
#  <tr>
#  <td>95263006</td>
#  <td>Sézary's disease of spleen</td>
#  </tr>
#  <tr>
#  <td>95264000</td>
#  <td>Sézary's disease of extranodal AND/OR solid organ site</td>
#  </tr>
#  </tbody>
#  </table>
#  </div>]

# %%
import pandas as pd

table = soup.find_all('table')
df = pd.read_html(str(table))[0]
# Out:
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_41548/139855918.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
df
# Out:
#                  code                                               term
# 0           103077004             Immunodeficiency secondary to neoplasm
# 1     108521000119103                         History of reticulosarcoma
# 2    1090241000000107  Angioimmunoblastic T-cell lymphoma with dyspro...
# 3    1091861000000100     Follicular lymphoma, cutaneous follicle centre
# 4    1091891000000106                          B-cell Hodgkin's lymphoma
# ..                ...                                                ...
# 966          95231000                          Reticulosarcoma of spleen
# 967          95260009  Sézary's disease of lymph nodes of head, face ...
# 968          95261008  Sézary's disease of lymph nodes of inguinal re...
# 969          95263006                         Sézary's disease of spleen
# 970          95264000  Sézary's disease of extranodal AND/OR solid or...
#
# [971 rows x 2 columns]

# %%
import json

valueSetJson = {
    "resourceType": "ValueSet",
    "status": "active",
}
print(json.dumps(valueSetJson, indent=2))
# Out:
# {
#   "resourceType": "ValueSet",
#   "status": "active"
# }

# %%
from fhir.resources.valueset import ValueSet
valueSet = ValueSet(**valueSetJson)

print(valueSet)
# Out:
# fhir_comments=None id=None implicitRules=None implicitRules__ext=None language=None language__ext=None meta=None contained=None extension=None modifierExtension=None text=None approvalDate=None approvalDate__ext=None author=None compose=None contact=None copyright=None copyright__ext=None copyrightLabel=None copyrightLabel__ext=None date=None date__ext=None description=None description__ext=None editor=None effectivePeriod=None endorser=None expansion=None experimental=None experimental__ext=None identifier=None immutable=None immutable__ext=None jurisdiction=None lastReviewDate=None lastReviewDate__ext=None name=None name__ext=None publisher=None publisher__ext=None purpose=None purpose__ext=None relatedArtifact=None reviewer=None scope=None status='active' status__ext=None title=None title__ext=None topic=None url=None url__ext=None useContext=None version=None version__ext=None versionAlgorithmCoding=None versionAlgorithmString=None versionAlgorithmString__ext=None

# %%
valueSetJson['compose'] = { 'include': [{ "system" : "http://snomed.info/sct","concept" : []}]}
print(json.dumps(valueSetJson, indent=2))
# Out:
# {
#   "resourceType": "ValueSet",
#   "status": "active",
#   "compose": {
#     "include": [
#       {
#         "system": "http://snomed.info/sct",
#         "concept": []
#       }
#     ]
#   }
# }

# %%
for index, row in df.iterrows():
    valueSetJson['compose']['include'][0]['concept'].append({
        "code" : str(row[0]),
        "display" : row[1]
    })
print(json.dumps(valueSetJson, indent=2))
# Out:
# {
#   "resourceType": "ValueSet",
#   "status": "active",
#   "compose": {
#     "include": [
#       {
#         "system": "http://snomed.info/sct",
#         "concept": [
#           {
#             "code": "103077004",
#             "display": "Immunodeficiency secondary to neoplasm"
#           },
#           {
#             "code": "108521000119103",
#             "display": "History of reticulosarcoma"
#           },
#           {
#             "code": "1090241000000107",
#             "display": "Angioimmunoblastic T-cell lymphoma with dysproteinaemia"
#           },
#           {
#             "code": "1091861000000100",
#             "display": "Follicular lymphoma, cutaneous follicle centre"
#           },
#           {
#             "code": "1091891000000106",
#             "display": "B-cell Hodgkin's lymphoma"
#           },
#           {
#             "code": "1091921000000103",
#             "display": "B-cell non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109962001",
#             "display": "Diffuse non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109964000",
#             "display": "Diffuse non-Hodgkin's lymphoma, undifferentiated"
#           },
#           {
#             "code": "109965004",
#             "display": "Diffuse non-Hodgkin's lymphoma, lymphoblastic"
#           },
#           {
#             "code": "109966003",
#             "display": "Diffuse non-Hodgkin's lymphoma, immunoblastic"
#           },
#           {
#             "code": "109967007",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109968002",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cell"
#           },
#           {
#             "code": "109969005",
#             "display": "Diffuse large B-cell malignant lymphoma"
#           },
#           {
#             "code": "109970006",
#             "display": "Follicular non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109971005",
#             "display": "Follicular non-Hodgkin's lymphoma, mixed small cleaved cell and large cell"
#           },
#           {
#             "code": "109972003",
#             "display": "Follicular non-Hodgkin's lymphoma, large cell"
#           },
#           {
#             "code": "109975001",
#             "display": "T-zone lymphoma"
#           },
#           {
#             "code": "109976000",
#             "display": "Lymphoepithelioid lymphoma"
#           },
#           {
#             "code": "109977009",
#             "display": "Peripheral T-cell lymphoma"
#           },
#           {
#             "code": "109978004",
#             "display": "T-cell lymphoma"
#           },
#           {
#             "code": "109979007",
#             "display": "B-cell lymphoma"
#           },
#           {
#             "code": "109980005",
#             "display": "Malignant immunoproliferative disease"
#           },
#           {
#             "code": "109981009",
#             "display": "Waldenstr\u00f6m macroglobulinemia"
#           },
#           {
#             "code": "109985000",
#             "display": "Immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "109988003",
#             "display": "Histiocytic sarcoma"
#           },
#           {
#             "code": "109989006",
#             "display": "Multiple myeloma"
#           },
#           {
#             "code": "109991003",
#             "display": "Acute panmyelosis with myelofibrosis"
#           },
#           {
#             "code": "109992005",
#             "display": "Polycythemia vera"
#           },
#           {
#             "code": "110000005",
#             "display": "Refractory anemia with excess blasts in transformation"
#           },
#           {
#             "code": "110002002",
#             "display": "Mast cell leukemia"
#           },
#           {
#             "code": "110004001",
#             "display": "Acute promyelocytic leukemia, FAB M3"
#           },
#           {
#             "code": "110005000",
#             "display": "Acute myelomonocytic leukemia, FAB M4"
#           },
#           {
#             "code": "110006004",
#             "display": "Prolymphocytic leukemia"
#           },
#           {
#             "code": "110007008",
#             "display": "Adult T-cell leukemia/lymphoma"
#           },
#           {
#             "code": "1148845007",
#             "display": "Follicular lymphoma grade 3b"
#           },
#           {
#             "code": "1148851002",
#             "display": "Follicular lymphoma grade 3a"
#           },
#           {
#             "code": "1148888004",
#             "display": "Nodular glomerulosclerosis due to heavy chain deposition disease"
#           },
#           {
#             "code": "1148906001",
#             "display": "Acute myeloid leukemia with t(8;21)(q22;q22) RUNX1-RUNX1T1"
#           },
#           {
#             "code": "1153336009",
#             "display": "Pediatric nodal marginal zone B cell lymphoma"
#           },
#           {
#             "code": "1153341001",
#             "display": "Myeloproliferative hypereosinophilic syndrome"
#           },
#           {
#             "code": "1153346006",
#             "display": "Primary non-Hodgkin malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1153347002",
#             "display": "Primary non-Hodgkin malignant lymphoma of vitreoretinal tract"
#           },
#           {
#             "code": "1153348007",
#             "display": "Primary effusion lymphoma due to human immune deficiency virus infection"
#           },
#           {
#             "code": "1153349004",
#             "display": "Primary familial polycythemia due to erythropoietin receptor mutation"
#           },
#           {
#             "code": "1153354008",
#             "display": "Malignant lymphoma of duodenum"
#           },
#           {
#             "code": "1153355009",
#             "display": "Malignant lymphoma of esophagus"
#           },
#           {
#             "code": "1153356005",
#             "display": "Lymphoma of anus"
#           },
#           {
#             "code": "1153357001",
#             "display": "Lymphoma of appendix"
#           },
#           {
#             "code": "1153377008",
#             "display": "Mixed phenotype acute leukemia with t(9;22) (q34;q11.2); BCR-ABL1"
#           },
#           {
#             "code": "1153379006",
#             "display": "Mixed phenotype acute leukemia with T-cell and myeloid lineage"
#           },
#           {
#             "code": "1153381008",
#             "display": "Mixed phenotype acute leukemia with myeloid and B-cell lymphoid phenotypes"
#           },
#           {
#             "code": "1153382001",
#             "display": "Malignant lymphoma of lacrimal gland"
#           },
#           {
#             "code": "1153383006",
#             "display": "Malignant lymphoma of liver"
#           },
#           {
#             "code": "1153397003",
#             "display": "Hydroa vacciniforme-like cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "1156403002",
#             "display": "Composite Hodgkin and non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1157157006",
#             "display": "Acute myeloid leukemia with 11q23 abnormality"
#           },
#           {
#             "code": "1157162007",
#             "display": "Intravascular large B-cell lymphoma"
#           },
#           {
#             "code": "1162264008",
#             "display": "Malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1162531007",
#             "display": "Acute myeloid leukemia in complete remission"
#           },
#           {
#             "code": "116691000119101",
#             "display": "Marginal zone lymphoma of spleen"
#           },
#           {
#             "code": "116811000119106",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of lower limb"
#           },
#           {
#             "code": "116821000119104",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of upper limb"
#           },
#           {
#             "code": "116841000119105",
#             "display": "Marginal zone lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "116871000119103",
#             "display": "Mantle cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "117211000119105",
#             "display": "Peripheral T-cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "1172516002",
#             "display": "High-dose chemotherapy with stem cell transplant"
#           },
#           {
#             "code": "1172704005",
#             "display": "High grade B-cell lymphoma with MYC and BCL2 and/or BCL6 rearrangements"
#           },
#           {
#             "code": "118599009",
#             "display": "Hodgkin's disease"
#           },
#           {
#             "code": "118600007",
#             "display": "Malignant lymphoma"
#           },
#           {
#             "code": "118601006",
#             "display": "Non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "118602004",
#             "display": "Hodgkin's granuloma"
#           },
#           {
#             "code": "118605002",
#             "display": "Hodgkin lymphoma, nodular lymphocyte predominance"
#           },
#           {
#             "code": "118606001",
#             "display": "Hodgkin's sarcoma"
#           },
#           {
#             "code": "118607005",
#             "display": "Hodgkin lymphoma, lymphocyte-rich"
#           },
#           {
#             "code": "118608000",
#             "display": "Hodgkin's disease, nodular sclerosis"
#           },
#           {
#             "code": "118609008",
#             "display": "Hodgkin's disease, mixed cellularity"
#           },
#           {
#             "code": "118610003",
#             "display": "Hodgkin's disease, lymphocytic depletion"
#           },
#           {
#             "code": "118611004",
#             "display": "S\u00e9zary's disease"
#           },
#           {
#             "code": "118612006",
#             "display": "Malignant histiocytosis"
#           },
#           {
#             "code": "118613001",
#             "display": "Hairy cell leukemia"
#           },
#           {
#             "code": "118614007",
#             "display": "Langerhans cell histiocytosis, disseminated"
#           },
#           {
#             "code": "118615008",
#             "display": "Malignant mast cell tumor"
#           },
#           {
#             "code": "118617000",
#             "display": "Burkitt's lymphoma"
#           },
#           {
#             "code": "118618005",
#             "display": "Mycosis fungoides"
#           },
#           {
#             "code": "1187123005",
#             "display": "Mixed phenotype acute leukemia"
#           },
#           {
#             "code": "1196900003",
#             "display": "B cell lymphoma of small intestine"
#           },
#           {
#             "code": "1197344000",
#             "display": "T-cell lymphoma of small intestine"
#           },
#           {
#             "code": "120481000119109",
#             "display": "History of multiple myeloma"
#           },
#           {
#             "code": "12149006",
#             "display": "Chemotherapy administration, subcutaneous, with local anesthesia"
#           },
#           {
#             "code": "1217301006",
#             "display": "Precursor cell lymphoblastic lymphoma"
#           },
#           {
#             "code": "122571000119106",
#             "display": "History of malignant cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "12281000132104",
#             "display": "Relapsing acute myeloid leukemia"
#           },
#           {
#             "code": "1228842003",
#             "display": "Primary cutaneous plasmacytosis"
#           },
#           {
#             "code": "12291000132102",
#             "display": "Refractory acute myeloid leukemia"
#           },
#           {
#             "code": "1229988003",
#             "display": "Myeloid and/or lymphoid neoplasm with pericentriolar material 1-janus kinase 2"
#           },
#           {
#             "code": "12301000132103",
#             "display": "Acute lymphoid leukemia relapse"
#           },
#           {
#             "code": "12311000132101",
#             "display": "Refractory acute lymphoid leukemia"
#           },
#           {
#             "code": "1231732006",
#             "display": "Smoldering systemic mastocytosis"
#           },
#           {
#             "code": "12341000132100",
#             "display": "B-cell lymphoma, unclassifiable, with features intermediate between diffuse large B-cell lymphoma and Burkitt lymphoma"
#           },
#           {
#             "code": "1237368006",
#             "display": "Acute myeloid leukemia with BCR-ABL1"
#           },
#           {
#             "code": "1237578005",
#             "display": "Primary oculocerebral non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1237617004",
#             "display": "Hypereosinophilic syndrome due to disease"
#           },
#           {
#             "code": "1254741007",
#             "display": "Intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1254742000",
#             "display": "Delayed intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1255270006",
#             "display": "Lymphoplasmacytic lymphoma without immunoglobulin M production"
#           },
#           {
#             "code": "1255666008",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of neck"
#           },
#           {
#             "code": "1255687003",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255726001",
#             "display": "Hodgkin granuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255727005",
#             "display": "Hodgkin granuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255728000",
#             "display": "Hodgkin granuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255729008",
#             "display": "Mast cell malignancy of lymph nodes of head"
#           },
#           {
#             "code": "1255730003",
#             "display": "Mast cell malignancy of lymph nodes of neck"
#           },
#           {
#             "code": "1255737000",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head"
#           },
#           {
#             "code": "1255738005",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of neck"
#           },
#           {
#             "code": "1255739002",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255740000",
#             "display": "Letterer-Siwe disease of lymph nodes of head"
#           },
#           {
#             "code": "1255741001",
#             "display": "Letterer-Siwe disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255742008",
#             "display": "Letterer-Siwe disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255743003",
#             "display": "Hodgkin sarcoma of lymph nodes of head"
#           },
#           {
#             "code": "1255744009",
#             "display": "Hodgkin sarcoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255745005",
#             "display": "Hodgkin sarcoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255746006",
#             "display": "Malignant histiocytosis of lymph nodes of head"
#           },
#           {
#             "code": "1255747002",
#             "display": "Malignant histiocytosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255748007",
#             "display": "Malignant histiocytosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255749004",
#             "display": "Burkitt tumor of lymph nodes of head"
#           },
#           {
#             "code": "1255750004",
#             "display": "Burkitt tumor of lymph nodes of neck"
#           },
#           {
#             "code": "1255751000",
#             "display": "Burkitt tumor of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255752007",
#             "display": "Mycosis fungoides of lymph nodes of head"
#           },
#           {
#             "code": "1255753002",
#             "display": "Mycosis fungoides of lymph nodes of neck"
#           },
#           {
#             "code": "1255754008",
#             "display": "Mycosis fungoides of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255784000",
#             "display": "Hodgkin paragranuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255785004",
#             "display": "Hodgkin paragranuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255786003",
#             "display": "Hodgkin paragranuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255788002",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head"
#           },
#           {
#             "code": "1255789005",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of neck"
#           },
#           {
#             "code": "1255790001",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255791002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255792009",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head"
#           },
#           {
#             "code": "1255793004",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255795006",
#             "display": "Malignant histiocytosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255796007",
#             "display": "Burkitt lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255797003",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255798008",
#             "display": "Hodgkin granuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255799000",
#             "display": "S\u00e9zary disease of lymph nodes of head"
#           },
#           {
#             "code": "1255800001",
#             "display": "S\u00e9zary disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255801002",
#             "display": "S\u00e9zary disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255802009",
#             "display": "Hodgkin disease of lymph nodes of head"
#           },
#           {
#             "code": "1255803004",
#             "display": "Hodgkin disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255804005",
#             "display": "Hodgkin disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255805006",
#             "display": "Malignant lymphoma of lymph nodes of head"
#           },
#           {
#             "code": "1255806007",
#             "display": "Malignant lymphoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255807003",
#             "display": "Malignant lymphoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255808008",
#             "display": "Hodgkin sarcoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255809000",
#             "display": "Malignant mast cell tumor of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255811009",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255812002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255813007",
#             "display": "Letterer-Siwe disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255814001",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255815000",
#             "display": "Malignant histiocytosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255831008",
#             "display": "Chemotherapy for malignant neoplastic disease using targeted agent"
#           },
#           {
#             "code": "1255834000",
#             "display": "Administration of antineoplastic chemotherapy into peritoneal cavity"
#           },
#           {
#             "code": "1255883001",
#             "display": "Hodgkin sarcoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255885008",
#             "display": "Letterer-Siwe disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255886009",
#             "display": "Mycosis fungoides of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255887000",
#             "display": "Hodgkin's paragranuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255888005",
#             "display": "Hodgkin paragranuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255890006",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255892003",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255894002",
#             "display": "Hodgkin granuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255895001",
#             "display": "Burkitt lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255897009",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255898004",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255899007",
#             "display": "Malignant mast cell tumor of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255902005",
#             "display": "Hodgkin disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255904006",
#             "display": "Administration of palliative antineoplastic agent"
#           },
#           {
#             "code": "1255905007",
#             "display": "Hodgkin disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255906008",
#             "display": "Malignant lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255907004",
#             "display": "Malignant lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1258932003",
#             "display": "Natural killer-lymphoblastic leukemia/lymphoma"
#           },
#           {
#             "code": "1259200004",
#             "display": "Neoadjuvant antineoplastic chemotherapy"
#           },
#           {
#             "code": "1260268001",
#             "display": "Myelodysplastic syndrome with low blasts"
#           },
#           {
#             "code": "1260406003",
#             "display": "Myelodysplastic neoplasm with biallelic TP53 inactivation"
#           },
#           {
#             "code": "1264416003",
#             "display": "Unclassifiable myelodysplastic syndrome"
#           },
#           {
#             "code": "1264458000",
#             "display": "Acute undifferentiated leukemia"
#           },
#           {
#             "code": "127066000",
#             "display": "Familial polycythemia vera"
#           },
#           {
#             "code": "127070008",
#             "display": "Malignant histiocytic disorder"
#           },
#           {
#             "code": "127220001",
#             "display": "Malignant lymphoma of lymph nodes"
#           },
#           {
#             "code": "127225006",
#             "display": "Chronic myelomonocytic leukemia"
#           },
#           {
#             "code": "127911000119105",
#             "display": "Light chain nephropathy due to multiple myeloma"
#           },
#           {
#             "code": "1286863002",
#             "display": "Metastatic malignant neoplasm to cecum and/or colon and/or rectum"
#           },
#           {
#             "code": "128874001",
#             "display": "Cutaneous CD30+ lymphoproliferative disorder"
#           },
#           {
#             "code": "128875000",
#             "display": "Primary cutaneous CD30 antigen positive large T-cell lymphoma"
#           },
#           {
#             "code": "129000002",
#             "display": "Eosinophilic granuloma"
#           },
#           {
#             "code": "13048006",
#             "display": "Orbital lymphoma"
#           },
#           {
#             "code": "133751000119102",
#             "display": "Lymphoma of colon"
#           },
#           {
#             "code": "152451000119104",
#             "display": "History of lymphosarcoma"
#           },
#           {
#             "code": "152861000119104",
#             "display": "History of myeloid leukemia"
#           },
#           {
#             "code": "161436008",
#             "display": "History of leukemia"
#           },
#           {
#             "code": "1659461000000103",
#             "display": "Janus kinase 2 positive polycythaemia vera"
#           },
#           {
#             "code": "1659471000000105",
#             "display": "Janus kinase 2 negative polycythaemia vera"
#           },
#           {
#             "code": "16775311000119107",
#             "display": "Mycosis fungoides of facial lymph node"
#           },
#           {
#             "code": "16894711000119103",
#             "display": "Immunoglobulin G deficiency due to multiple myeloma"
#           },
#           {
#             "code": "169396008",
#             "display": "Radiomimetic chemotherapy"
#           },
#           {
#             "code": "169397004",
#             "display": "Radiochemotherapy: local infiltration"
#           },
#           {
#             "code": "169398009",
#             "display": "Radiochemotherapy: to stop spread"
#           },
#           {
#             "code": "169399001",
#             "display": "Radiochemotherapy via oral route"
#           },
#           {
#             "code": "169400008",
#             "display": "Radiochemotherapy via intravenous route"
#           },
#           {
#             "code": "169401007",
#             "display": "Radiochemotherapy: for immunosuppression"
#           },
#           {
#             "code": "169402000",
#             "display": "Radiochemotherapy: local artery"
#           },
#           {
#             "code": "169403005",
#             "display": "Radiochemotherapy: into cavity"
#           },
#           {
#             "code": "171765004",
#             "display": "Intrathecal injection of chemotherapeutic agent"
#           },
#           {
#             "code": "1881000119103",
#             "display": "History of plasmacytoma"
#           },
#           {
#             "code": "188487008",
#             "display": "Lymphosarcoma and reticulosarcoma"
#           },
#           {
#             "code": "188489006",
#             "display": "Reticulosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188492005",
#             "display": "Reticulosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188493000",
#             "display": "Reticulosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188498009",
#             "display": "Lymphosarcoma"
#           },
#           {
#             "code": "188500005",
#             "display": "Lymphosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188501009",
#             "display": "Lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188502002",
#             "display": "Lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188503007",
#             "display": "Lymphosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188504001",
#             "display": "Lymphosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188505000",
#             "display": "Lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188506004",
#             "display": "Lymphosarcoma of spleen"
#           },
#           {
#             "code": "188507008",
#             "display": "Lymphosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188510001",
#             "display": "Burkitt's lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188511002",
#             "display": "Burkitt's lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188512009",
#             "display": "Burkitt's lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188513004",
#             "display": "Burkitt lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188514005",
#             "display": "Burkitt lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188515006",
#             "display": "Burkitt's lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188516007",
#             "display": "Burkitt's lymphoma of spleen"
#           },
#           {
#             "code": "188517003",
#             "display": "Burkitt's lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188524002",
#             "display": "Hodgkin's paragranuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188526000",
#             "display": "Hodgkin's paragranuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188529007",
#             "display": "Hodgkin's paragranuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188531003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188534006",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188536008",
#             "display": "Hodgkin's granuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188537004",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188538009",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188541000",
#             "display": "Hodgkin's granuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188544008",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188547001",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188548006",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188551004",
#             "display": "Hodgkin's sarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188554007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188558005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188559002",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188562004",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188565002",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188566001",
#             "display": "Hodgkin's disease, nodular sclerosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188567005",
#             "display": "Hodgkin's disease, nodular sclerosis of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188568000",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188569008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188570009",
#             "display": "Hodgkin's disease, nodular sclerosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188572001",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188575004",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188576003",
#             "display": "Hodgkin's disease, mixed cellularity of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188577007",
#             "display": "Hodgkin's disease, mixed cellularity of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188578002",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188579005",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188580008",
#             "display": "Hodgkin's disease, mixed cellularity of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188582000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188585003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188586002",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188587006",
#             "display": "Hodgkin's disease, lymphocytic depletion of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188589009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188590000",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188591001",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188592008",
#             "display": "Hodgkin's disease, lymphocytic depletion of spleen"
#           },
#           {
#             "code": "188593003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188609000",
#             "display": "Nodular lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188612002",
#             "display": "Nodular lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188613007",
#             "display": "Nodular lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188627002",
#             "display": "Mycosis fungoides of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188630009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188631008",
#             "display": "S\u00e9zary's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188632001",
#             "display": "S\u00e9zary's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188633006",
#             "display": "S\u00e9zary's disease of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188634000",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188635004",
#             "display": "S\u00e9zary's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188637007",
#             "display": "S\u00e9zary's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188640007",
#             "display": "Malignant histiocytosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188641006",
#             "display": "Malignant histiocytosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188642004",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188645002",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188648000",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188649008",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188660004",
#             "display": "Malignant mast cell tumors"
#           },
#           {
#             "code": "188662007",
#             "display": "Mast cell malignancy of lymph nodes of head and neck"
#           },
#           {
#             "code": "188663002",
#             "display": "Mast cell malignancy of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188664008",
#             "display": "Mast cell malignancy of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188665009",
#             "display": "Mast cell malignancy of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188666005",
#             "display": "Mast cell malignancy of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188667001",
#             "display": "Mast cell malignancy of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188668006",
#             "display": "Malignant mast cell sarcoma of spleen"
#           },
#           {
#             "code": "188669003",
#             "display": "Mast cell malignancy of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188672005",
#             "display": "Follicular non-Hodgkin's mixed small cleaved and large cell lymphoma"
#           },
#           {
#             "code": "188674006",
#             "display": "Diffuse malignant lymphoma - small non-cleaved cell"
#           },
#           {
#             "code": "188675007",
#             "display": "Malignant lymphoma - small cleaved cell"
#           },
#           {
#             "code": "188676008",
#             "display": "Malignant lymphoma - mixed small and large cell"
#           },
#           {
#             "code": "188679001",
#             "display": "Diffuse non-Hodgkin's lymphoma undifferentiated (diffuse)"
#           },
#           {
#             "code": "188691005",
#             "display": "Malignant immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "188718006",
#             "display": "Malignant plasma cell neoplasm, extramedullary plasmacytoma"
#           },
#           {
#             "code": "188725004",
#             "display": "Lymphoid leukemia"
#           },
#           {
#             "code": "188726003",
#             "display": "Subacute lymphoid leukemia"
#           },
#           {
#             "code": "188728002",
#             "display": "Aleukemic lymphoid leukemia"
#           },
#           {
#             "code": "188729005",
#             "display": "Adult T-cell leukemia"
#           },
#           {
#             "code": "188732008",
#             "display": "Myeloid leukemia"
#           },
#           {
#             "code": "188733003",
#             "display": "Chronic eosinophilic leukemia"
#           },
#           {
#             "code": "188734009",
#             "display": "Chronic neutrophilic leukemia"
#           },
#           {
#             "code": "188736006",
#             "display": "Subacute myeloid leukemia"
#           },
#           {
#             "code": "188737002",
#             "display": "Chloroma"
#           },
#           {
#             "code": "188738007",
#             "display": "Granulocytic sarcoma"
#           },
#           {
#             "code": "188741003",
#             "display": "Aleukemic myeloid leukemia"
#           },
#           {
#             "code": "188744006",
#             "display": "Monocytic leukemia"
#           },
#           {
#             "code": "188745007",
#             "display": "Chronic monocytic leukemia"
#           },
#           {
#             "code": "188746008",
#             "display": "Subacute monocytic leukemia"
#           },
#           {
#             "code": "188748009",
#             "display": "Aleukemic monocytic leukemia"
#           },
#           {
#             "code": "188754005",
#             "display": "Megakaryocytic leukemia"
#           },
#           {
#             "code": "188768003",
#             "display": "Myelomonocytic leukemia"
#           },
#           {
#             "code": "188770007",
#             "display": "Subacute myelomonocytic leukemia"
#           },
#           {
#             "code": "190030009",
#             "display": "Compound leukemias"
#           },
#           {
#             "code": "190955000",
#             "display": "Histiocytosis X syndrome"
#           },
#           {
#             "code": "203436008",
#             "display": "Osteoporosis in multiple myelomatosis"
#           },
#           {
#             "code": "209962000",
#             "display": "Myeloma-associated amyloidosis"
#           },
#           {
#             "code": "22733003",
#             "display": "Chemotherapy for non-malignant neoplasm"
#           },
#           {
#             "code": "230586003",
#             "display": "Neuropathy due to multiple myeloma"
#           },
#           {
#             "code": "230857009",
#             "display": "Injection of chemotherapeutic substance into subcutaneous reservoir"
#           },
#           {
#             "code": "232075002",
#             "display": "Lymphoma of retina"
#           },
#           {
#             "code": "232681000000103",
#             "display": "Chemotherapy delivery"
#           },
#           {
#             "code": "235331000000103",
#             "display": "Delivery of oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "235391000000102",
#             "display": "Delivery of chemotherapy for neoplasm"
#           },
#           {
#             "code": "236512004",
#             "display": "Leukemic infiltrate of kidney"
#           },
#           {
#             "code": "236513009",
#             "display": "Lymphoma of kidney"
#           },
#           {
#             "code": "238831000000103",
#             "display": "Delivery of exclusively oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "238841000000107",
#             "display": "Delivery of complex chemotherapy for neoplasm including prolonged infusional treatment at first attendance"
#           },
#           {
#             "code": "238851000000105",
#             "display": "Delivery of complex parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "238861000000108",
#             "display": "Delivery of simple parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "239071000000100",
#             "display": "Delivery of subsequent element of cycle of chemotherapy for neoplasm"
#           },
#           {
#             "code": "240531002",
#             "display": "African Burkitt's lymphoma"
#           },
#           {
#             "code": "240794006",
#             "display": "Splenic schistosomal giant cell lymphoma"
#           },
#           {
#             "code": "254792006",
#             "display": "Proliferating angioendotheliomatosis"
#           },
#           {
#             "code": "255101006",
#             "display": "S\u00e9zary disease of skin"
#           },
#           {
#             "code": "255102004",
#             "display": "Angioendotheliomatosis"
#           },
#           {
#             "code": "255191003",
#             "display": "Localized malignant reticulohistiocytoma"
#           },
#           {
#             "code": "265760000",
#             "display": "Intravenous chemotherapy"
#           },
#           {
#             "code": "265761001",
#             "display": "Intramuscular chemotherapy"
#           },
#           {
#             "code": "265762008",
#             "display": "Subcutaneous chemotherapy"
#           },
#           {
#             "code": "266719004",
#             "display": "Oral chemotherapy"
#           },
#           {
#             "code": "267540007",
#             "display": "Neutropenia caused by ionizing radiation"
#           },
#           {
#             "code": "268500004",
#             "display": "Administration of prophylactic chemotherapy"
#           },
#           {
#             "code": "269475001",
#             "display": "Malignant tumor of lymphoid, hemopoietic AND/OR related tissue"
#           },
#           {
#             "code": "269476000",
#             "display": "Nodular lymphoma"
#           },
#           {
#             "code": "274905008",
#             "display": "Malignant lymphoma - lymphocytic, intermediate differentiation"
#           },
#           {
#             "code": "276811008",
#             "display": "Gastric lymphoma"
#           },
#           {
#             "code": "276815004",
#             "display": "Lymphoma of intestine"
#           },
#           {
#             "code": "276836002",
#             "display": "Primary cerebral lymphoma"
#           },
#           {
#             "code": "277473004",
#             "display": "B-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277474005",
#             "display": "B-cell chronic lymphocytic leukemia variant"
#           },
#           {
#             "code": "277543005",
#             "display": "Malignant white blood cell disorder"
#           },
#           {
#             "code": "277545003",
#             "display": "T-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277549009",
#             "display": "Chronic lymphocytic prolymphocytic leukemia syndrome"
#           },
#           {
#             "code": "277550009",
#             "display": "Richter's syndrome"
#           },
#           {
#             "code": "277551008",
#             "display": "Splenic lymphoma with villous lymphocytes"
#           },
#           {
# ...
#           {
#             "code": "93183001",
#             "display": "Malignant histiocytosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93184007",
#             "display": "Malignant histiocytosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93185008",
#             "display": "Malignant histiocytosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93186009",
#             "display": "Malignant histiocytosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93187000",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93188005",
#             "display": "Malignant histiocytosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93189002",
#             "display": "Malignant histiocytosis of spleen"
#           },
#           {
#             "code": "93190006",
#             "display": "Malignant histiocytosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93191005",
#             "display": "Malignant lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93192003",
#             "display": "Malignant lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93193008",
#             "display": "Malignant lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93194002",
#             "display": "Malignant lymphoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93195001",
#             "display": "Malignant lymphoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93196000",
#             "display": "Malignant lymphoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93197009",
#             "display": "Malignant lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93198004",
#             "display": "Malignant lymphoma of spleen"
#           },
#           {
#             "code": "93199007",
#             "display": "Malignant lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93200005",
#             "display": "Malignant mast cell tumor of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93201009",
#             "display": "Malignant mast cell tumor of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93202002",
#             "display": "Malignant mast cell tumor of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93203007",
#             "display": "Malignant mast cell tumor of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93204001",
#             "display": "Malignant mast cell tumor of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93205000",
#             "display": "Malignant mast cell tumor of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93206004",
#             "display": "Malignant mast cell tumor of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93207008",
#             "display": "Malignant mast cell tumor of spleen"
#           },
#           {
#             "code": "93208003",
#             "display": "Malignant mast cell tumor of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93451002",
#             "display": "Erythroleukemia, FAB M6"
#           },
#           {
#             "code": "93487009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93488004",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93489007",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93492006",
#             "display": "Hodgkin's disease, lymphocytic depletion of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93493001",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93494007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93495008",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93496009",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93497000",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93498005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93500006",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of spleen"
#           },
#           {
#             "code": "93501005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93505001",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93506000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93507009",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93509007",
#             "display": "Hodgkin's disease, mixed cellularity of spleen"
#           },
#           {
#             "code": "93510002",
#             "display": "Hodgkin's disease, mixed cellularity of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93514006",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93515007",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93516008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93518009",
#             "display": "Hodgkin's disease, nodular sclerosis of spleen"
#           },
#           {
#             "code": "93519001",
#             "display": "Hodgkin's disease, nodular sclerosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93520007",
#             "display": "Hodgkin's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93521006",
#             "display": "Hodgkin's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93522004",
#             "display": "Hodgkin's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93523009",
#             "display": "Hodgkin's disease of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93524003",
#             "display": "Hodgkin's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93525002",
#             "display": "Hodgkin's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93526001",
#             "display": "Hodgkin's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93527005",
#             "display": "Hodgkin's disease of spleen"
#           },
#           {
#             "code": "93528000",
#             "display": "Hodgkin's disease of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93530003",
#             "display": "Hodgkin's granuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93531004",
#             "display": "Hodgkin's granuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93532006",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93533001",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93534007",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93536009",
#             "display": "Hodgkin's granuloma of spleen"
#           },
#           {
#             "code": "93537000",
#             "display": "Hodgkin's granuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93541001",
#             "display": "Hodgkin's paragranuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93542008",
#             "display": "Hodgkin's paragranuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93543003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93545005",
#             "display": "Hodgkin's paragranuloma of spleen"
#           },
#           {
#             "code": "93546006",
#             "display": "Hodgkin's paragranuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93547002",
#             "display": "Hodgkin's sarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93548007",
#             "display": "Hodgkin's sarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93549004",
#             "display": "Hodgkin's sarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93550004",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93551000",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93552007",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93554008",
#             "display": "Hodgkin's sarcoma of spleen"
#           },
#           {
#             "code": "93555009",
#             "display": "Hodgkin's sarcoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94686001",
#             "display": "Mixed cell type lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94687005",
#             "display": "Mixed cell type lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94688000",
#             "display": "Mixed cell type lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94690004",
#             "display": "Mixed cell type lymphosarcoma of lymph nodes of head, face, and neck"
#           },
#           {
#             "code": "94704006",
#             "display": "Multiple myeloma in remission"
#           },
#           {
#             "code": "94707004",
#             "display": "Mycosis fungoides of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94708009",
#             "display": "Mycosis fungoides of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94709001",
#             "display": "Mycosis fungoides of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94710006",
#             "display": "Mycosis fungoides of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "94711005",
#             "display": "Mycosis fungoides of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "94712003",
#             "display": "Mycosis fungoides of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "94714002",
#             "display": "Mycosis fungoides of spleen"
#           },
#           {
#             "code": "94715001",
#             "display": "Mycosis fungoides of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94719007",
#             "display": "Myeloid sarcoma, disease"
#           },
#           {
#             "code": "95186006",
#             "display": "Nodular lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95187002",
#             "display": "Nodular lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95188007",
#             "display": "Nodular lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95192000",
#             "display": "Nodular lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95193005",
#             "display": "Nodular lymphoma of spleen"
#           },
#           {
#             "code": "95194004",
#             "display": "Nodular lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "95209008",
#             "display": "Plasma cell leukemia in remission"
#           },
#           {
#             "code": "95210003",
#             "display": "Plasma cell leukemia, disease"
#           },
#           {
#             "code": "95224004",
#             "display": "Reticulosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95225003",
#             "display": "Reticulosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95226002",
#             "display": "Reticulosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95230004",
#             "display": "Reticulosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95231000",
#             "display": "Reticulosarcoma of spleen"
#           },
#           {
#             "code": "95260009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "95261008",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "95263006",
#             "display": "S\u00e9zary's disease of spleen"
#           },
#           {
#             "code": "95264000",
#             "display": "S\u00e9zary's disease of extranodal AND/OR solid organ site"
#           }
#         ]
#       }
#     ]
#   }
# }
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_41548/241539053.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "code" : str(row[0]),
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_41548/241539053.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "display" : row[1]

# %%
valueSet = ValueSet(**valueSetJson)

print(valueSet)
# Out:
# fhir_comments=None id=None implicitRules=None implicitRules__ext=None language=None language__ext=None meta=None contained=None extension=None modifierExtension=None text=None approvalDate=None approvalDate__ext=None author=None compose=ValueSetCompose(fhir_comments=None, extension=None, id=None, modifierExtension=None, exclude=None, inactive=None, inactive__ext=None, include=[ValueSetComposeInclude(fhir_comments=None, extension=None, id=None, modifierExtension=None, concept=[ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='103077004', code__ext=None, designation=None, display='Immunodeficiency secondary to neoplasm', display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='108521000119103', code__ext=None, designation=None, display='History of reticulosarcoma', display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='1090241000000107', code__ext=None, designation=None, display='Angioimmunoblastic T-cell lymphoma with dysproteinaemia', display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='1091861000000100', code__ext=None, designation=None, display='Follicular lymphoma, cutaneous follicle centre', display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='1091891000000106', code__ext=None, designation=None, display="B-cell Hodgkin's lymphoma", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='1091921000000103', code__ext=None, designation=None, display="B-cell non-Hodgkin's lymphoma", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109962001', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109964000', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma, undifferentiated", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109965004', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma, lymphoblastic", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109966003', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma, immunoblastic", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109967007', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma, small cleaved cell", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109968002', code__ext=None, designation=None, display="Diffuse non-Hodgkin's lymphoma, small cell", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109969005', code__ext=None, designation=None, display='Diffuse large B-cell malignant lymphoma', display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109970006', code__ext=None, designation=None, display="Follicular non-Hodgkin's lymphoma, small cleaved cell", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=None, code='109971005', code__ext=None, designation=None, display="Follicular non-Hodgkin's lymphoma, mixed small cleaved cell and large cell", display__ext=None), ValueSetComposeIncludeConcept(fhir_comments=None, extension=None, id=None, modifierExtension=No ...

# %%
section = soup.select('section')
section
# Out:
# [<section>
#  <h2 class="sr-only">Codelist metadata</h2>
#  <dl class="list-group list-group-horizontal small">
#  <div class="list-group-item py-1 px-2">
#  <dt>
#              Coding system
#            </dt>
#  <dd class="mb-0">SNOMED CT (UK Clinical Edition)</dd>
#  </div>
#  <div class="list-group-item py-1 px-2">
#  <dt>
#              Coding system release
#            </dt>
#  <dd class="mb-0">
#              39.2.0
#            </dd>
#  </div>
#  <div class="list-group-item py-1 px-2">
#  <dt>
#                Organisation
#              </dt>
#  <dd class="mb-0">NHSD Primary Care Domain Refsets</dd>
#  </div>
#  <div class="list-group-item py-1 px-2">
#  <dt>
#              Codelist ID
#            </dt>
#  <dd class="mb-0 break-word">nhsd-primary-care-domain-refsets/c19haemcan_cod</dd>
#  </div>
#  <div class="list-group-item py-1 px-2">
#  <dt>
#                Version Tag
#              </dt>
#  <dd class="mb-0">20241205</dd>
#  </div>
#  <div class="list-group-item py-1 px-2">
#  <dt>
#              Version ID
#            </dt>
#  <dd class="mb-0">4d423796</dd>
#  </div>
#  </dl>
#  </section>]

# %%
soup = BeautifulSoup(r.text, "lxml")
table = soup.find_all('div', 'list-group-item py-1 px-2')
table[0]
# Out:
# <div class="list-group-item py-1 px-2">
# <dt>
#             Coding system
#           </dt>
# <dd class="mb-0">SNOMED CT (UK Clinical Edition)</dd>
# </div>

# %%
df = pd.read_xml(str(table[3]))
id = df.loc[df.index[1], 'dd']
valueSetJson['id']=id.replace('/','-').replace('_','-')
#df.loc[1]
print(json.dumps(valueSetJson, indent=2))
# Out:
# {
#   "resourceType": "ValueSet",
#   "status": "active",
#   "compose": {
#     "include": [
#       {
#         "system": "http://snomed.info/sct",
#         "concept": [
#           {
#             "code": "103077004",
#             "display": "Immunodeficiency secondary to neoplasm"
#           },
#           {
#             "code": "108521000119103",
#             "display": "History of reticulosarcoma"
#           },
#           {
#             "code": "1090241000000107",
#             "display": "Angioimmunoblastic T-cell lymphoma with dysproteinaemia"
#           },
#           {
#             "code": "1091861000000100",
#             "display": "Follicular lymphoma, cutaneous follicle centre"
#           },
#           {
#             "code": "1091891000000106",
#             "display": "B-cell Hodgkin's lymphoma"
#           },
#           {
#             "code": "1091921000000103",
#             "display": "B-cell non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109962001",
#             "display": "Diffuse non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109964000",
#             "display": "Diffuse non-Hodgkin's lymphoma, undifferentiated"
#           },
#           {
#             "code": "109965004",
#             "display": "Diffuse non-Hodgkin's lymphoma, lymphoblastic"
#           },
#           {
#             "code": "109966003",
#             "display": "Diffuse non-Hodgkin's lymphoma, immunoblastic"
#           },
#           {
#             "code": "109967007",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109968002",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cell"
#           },
#           {
#             "code": "109969005",
#             "display": "Diffuse large B-cell malignant lymphoma"
#           },
#           {
#             "code": "109970006",
#             "display": "Follicular non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109971005",
#             "display": "Follicular non-Hodgkin's lymphoma, mixed small cleaved cell and large cell"
#           },
#           {
#             "code": "109972003",
#             "display": "Follicular non-Hodgkin's lymphoma, large cell"
#           },
#           {
#             "code": "109975001",
#             "display": "T-zone lymphoma"
#           },
#           {
#             "code": "109976000",
#             "display": "Lymphoepithelioid lymphoma"
#           },
#           {
#             "code": "109977009",
#             "display": "Peripheral T-cell lymphoma"
#           },
#           {
#             "code": "109978004",
#             "display": "T-cell lymphoma"
#           },
#           {
#             "code": "109979007",
#             "display": "B-cell lymphoma"
#           },
#           {
#             "code": "109980005",
#             "display": "Malignant immunoproliferative disease"
#           },
#           {
#             "code": "109981009",
#             "display": "Waldenstr\u00f6m macroglobulinemia"
#           },
#           {
#             "code": "109985000",
#             "display": "Immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "109988003",
#             "display": "Histiocytic sarcoma"
#           },
#           {
#             "code": "109989006",
#             "display": "Multiple myeloma"
#           },
#           {
#             "code": "109991003",
#             "display": "Acute panmyelosis with myelofibrosis"
#           },
#           {
#             "code": "109992005",
#             "display": "Polycythemia vera"
#           },
#           {
#             "code": "110000005",
#             "display": "Refractory anemia with excess blasts in transformation"
#           },
#           {
#             "code": "110002002",
#             "display": "Mast cell leukemia"
#           },
#           {
#             "code": "110004001",
#             "display": "Acute promyelocytic leukemia, FAB M3"
#           },
#           {
#             "code": "110005000",
#             "display": "Acute myelomonocytic leukemia, FAB M4"
#           },
#           {
#             "code": "110006004",
#             "display": "Prolymphocytic leukemia"
#           },
#           {
#             "code": "110007008",
#             "display": "Adult T-cell leukemia/lymphoma"
#           },
#           {
#             "code": "1148845007",
#             "display": "Follicular lymphoma grade 3b"
#           },
#           {
#             "code": "1148851002",
#             "display": "Follicular lymphoma grade 3a"
#           },
#           {
#             "code": "1148888004",
#             "display": "Nodular glomerulosclerosis due to heavy chain deposition disease"
#           },
#           {
#             "code": "1148906001",
#             "display": "Acute myeloid leukemia with t(8;21)(q22;q22) RUNX1-RUNX1T1"
#           },
#           {
#             "code": "1153336009",
#             "display": "Pediatric nodal marginal zone B cell lymphoma"
#           },
#           {
#             "code": "1153341001",
#             "display": "Myeloproliferative hypereosinophilic syndrome"
#           },
#           {
#             "code": "1153346006",
#             "display": "Primary non-Hodgkin malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1153347002",
#             "display": "Primary non-Hodgkin malignant lymphoma of vitreoretinal tract"
#           },
#           {
#             "code": "1153348007",
#             "display": "Primary effusion lymphoma due to human immune deficiency virus infection"
#           },
#           {
#             "code": "1153349004",
#             "display": "Primary familial polycythemia due to erythropoietin receptor mutation"
#           },
#           {
#             "code": "1153354008",
#             "display": "Malignant lymphoma of duodenum"
#           },
#           {
#             "code": "1153355009",
#             "display": "Malignant lymphoma of esophagus"
#           },
#           {
#             "code": "1153356005",
#             "display": "Lymphoma of anus"
#           },
#           {
#             "code": "1153357001",
#             "display": "Lymphoma of appendix"
#           },
#           {
#             "code": "1153377008",
#             "display": "Mixed phenotype acute leukemia with t(9;22) (q34;q11.2); BCR-ABL1"
#           },
#           {
#             "code": "1153379006",
#             "display": "Mixed phenotype acute leukemia with T-cell and myeloid lineage"
#           },
#           {
#             "code": "1153381008",
#             "display": "Mixed phenotype acute leukemia with myeloid and B-cell lymphoid phenotypes"
#           },
#           {
#             "code": "1153382001",
#             "display": "Malignant lymphoma of lacrimal gland"
#           },
#           {
#             "code": "1153383006",
#             "display": "Malignant lymphoma of liver"
#           },
#           {
#             "code": "1153397003",
#             "display": "Hydroa vacciniforme-like cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "1156403002",
#             "display": "Composite Hodgkin and non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1157157006",
#             "display": "Acute myeloid leukemia with 11q23 abnormality"
#           },
#           {
#             "code": "1157162007",
#             "display": "Intravascular large B-cell lymphoma"
#           },
#           {
#             "code": "1162264008",
#             "display": "Malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1162531007",
#             "display": "Acute myeloid leukemia in complete remission"
#           },
#           {
#             "code": "116691000119101",
#             "display": "Marginal zone lymphoma of spleen"
#           },
#           {
#             "code": "116811000119106",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of lower limb"
#           },
#           {
#             "code": "116821000119104",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of upper limb"
#           },
#           {
#             "code": "116841000119105",
#             "display": "Marginal zone lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "116871000119103",
#             "display": "Mantle cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "117211000119105",
#             "display": "Peripheral T-cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "1172516002",
#             "display": "High-dose chemotherapy with stem cell transplant"
#           },
#           {
#             "code": "1172704005",
#             "display": "High grade B-cell lymphoma with MYC and BCL2 and/or BCL6 rearrangements"
#           },
#           {
#             "code": "118599009",
#             "display": "Hodgkin's disease"
#           },
#           {
#             "code": "118600007",
#             "display": "Malignant lymphoma"
#           },
#           {
#             "code": "118601006",
#             "display": "Non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "118602004",
#             "display": "Hodgkin's granuloma"
#           },
#           {
#             "code": "118605002",
#             "display": "Hodgkin lymphoma, nodular lymphocyte predominance"
#           },
#           {
#             "code": "118606001",
#             "display": "Hodgkin's sarcoma"
#           },
#           {
#             "code": "118607005",
#             "display": "Hodgkin lymphoma, lymphocyte-rich"
#           },
#           {
#             "code": "118608000",
#             "display": "Hodgkin's disease, nodular sclerosis"
#           },
#           {
#             "code": "118609008",
#             "display": "Hodgkin's disease, mixed cellularity"
#           },
#           {
#             "code": "118610003",
#             "display": "Hodgkin's disease, lymphocytic depletion"
#           },
#           {
#             "code": "118611004",
#             "display": "S\u00e9zary's disease"
#           },
#           {
#             "code": "118612006",
#             "display": "Malignant histiocytosis"
#           },
#           {
#             "code": "118613001",
#             "display": "Hairy cell leukemia"
#           },
#           {
#             "code": "118614007",
#             "display": "Langerhans cell histiocytosis, disseminated"
#           },
#           {
#             "code": "118615008",
#             "display": "Malignant mast cell tumor"
#           },
#           {
#             "code": "118617000",
#             "display": "Burkitt's lymphoma"
#           },
#           {
#             "code": "118618005",
#             "display": "Mycosis fungoides"
#           },
#           {
#             "code": "1187123005",
#             "display": "Mixed phenotype acute leukemia"
#           },
#           {
#             "code": "1196900003",
#             "display": "B cell lymphoma of small intestine"
#           },
#           {
#             "code": "1197344000",
#             "display": "T-cell lymphoma of small intestine"
#           },
#           {
#             "code": "120481000119109",
#             "display": "History of multiple myeloma"
#           },
#           {
#             "code": "12149006",
#             "display": "Chemotherapy administration, subcutaneous, with local anesthesia"
#           },
#           {
#             "code": "1217301006",
#             "display": "Precursor cell lymphoblastic lymphoma"
#           },
#           {
#             "code": "122571000119106",
#             "display": "History of malignant cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "12281000132104",
#             "display": "Relapsing acute myeloid leukemia"
#           },
#           {
#             "code": "1228842003",
#             "display": "Primary cutaneous plasmacytosis"
#           },
#           {
#             "code": "12291000132102",
#             "display": "Refractory acute myeloid leukemia"
#           },
#           {
#             "code": "1229988003",
#             "display": "Myeloid and/or lymphoid neoplasm with pericentriolar material 1-janus kinase 2"
#           },
#           {
#             "code": "12301000132103",
#             "display": "Acute lymphoid leukemia relapse"
#           },
#           {
#             "code": "12311000132101",
#             "display": "Refractory acute lymphoid leukemia"
#           },
#           {
#             "code": "1231732006",
#             "display": "Smoldering systemic mastocytosis"
#           },
#           {
#             "code": "12341000132100",
#             "display": "B-cell lymphoma, unclassifiable, with features intermediate between diffuse large B-cell lymphoma and Burkitt lymphoma"
#           },
#           {
#             "code": "1237368006",
#             "display": "Acute myeloid leukemia with BCR-ABL1"
#           },
#           {
#             "code": "1237578005",
#             "display": "Primary oculocerebral non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1237617004",
#             "display": "Hypereosinophilic syndrome due to disease"
#           },
#           {
#             "code": "1254741007",
#             "display": "Intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1254742000",
#             "display": "Delayed intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1255270006",
#             "display": "Lymphoplasmacytic lymphoma without immunoglobulin M production"
#           },
#           {
#             "code": "1255666008",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of neck"
#           },
#           {
#             "code": "1255687003",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255726001",
#             "display": "Hodgkin granuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255727005",
#             "display": "Hodgkin granuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255728000",
#             "display": "Hodgkin granuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255729008",
#             "display": "Mast cell malignancy of lymph nodes of head"
#           },
#           {
#             "code": "1255730003",
#             "display": "Mast cell malignancy of lymph nodes of neck"
#           },
#           {
#             "code": "1255737000",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head"
#           },
#           {
#             "code": "1255738005",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of neck"
#           },
#           {
#             "code": "1255739002",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255740000",
#             "display": "Letterer-Siwe disease of lymph nodes of head"
#           },
#           {
#             "code": "1255741001",
#             "display": "Letterer-Siwe disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255742008",
#             "display": "Letterer-Siwe disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255743003",
#             "display": "Hodgkin sarcoma of lymph nodes of head"
#           },
#           {
#             "code": "1255744009",
#             "display": "Hodgkin sarcoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255745005",
#             "display": "Hodgkin sarcoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255746006",
#             "display": "Malignant histiocytosis of lymph nodes of head"
#           },
#           {
#             "code": "1255747002",
#             "display": "Malignant histiocytosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255748007",
#             "display": "Malignant histiocytosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255749004",
#             "display": "Burkitt tumor of lymph nodes of head"
#           },
#           {
#             "code": "1255750004",
#             "display": "Burkitt tumor of lymph nodes of neck"
#           },
#           {
#             "code": "1255751000",
#             "display": "Burkitt tumor of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255752007",
#             "display": "Mycosis fungoides of lymph nodes of head"
#           },
#           {
#             "code": "1255753002",
#             "display": "Mycosis fungoides of lymph nodes of neck"
#           },
#           {
#             "code": "1255754008",
#             "display": "Mycosis fungoides of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255784000",
#             "display": "Hodgkin paragranuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255785004",
#             "display": "Hodgkin paragranuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255786003",
#             "display": "Hodgkin paragranuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255788002",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head"
#           },
#           {
#             "code": "1255789005",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of neck"
#           },
#           {
#             "code": "1255790001",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255791002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255792009",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head"
#           },
#           {
#             "code": "1255793004",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255795006",
#             "display": "Malignant histiocytosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255796007",
#             "display": "Burkitt lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255797003",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255798008",
#             "display": "Hodgkin granuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255799000",
#             "display": "S\u00e9zary disease of lymph nodes of head"
#           },
#           {
#             "code": "1255800001",
#             "display": "S\u00e9zary disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255801002",
#             "display": "S\u00e9zary disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255802009",
#             "display": "Hodgkin disease of lymph nodes of head"
#           },
#           {
#             "code": "1255803004",
#             "display": "Hodgkin disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255804005",
#             "display": "Hodgkin disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255805006",
#             "display": "Malignant lymphoma of lymph nodes of head"
#           },
#           {
#             "code": "1255806007",
#             "display": "Malignant lymphoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255807003",
#             "display": "Malignant lymphoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255808008",
#             "display": "Hodgkin sarcoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255809000",
#             "display": "Malignant mast cell tumor of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255811009",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255812002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255813007",
#             "display": "Letterer-Siwe disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255814001",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255815000",
#             "display": "Malignant histiocytosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255831008",
#             "display": "Chemotherapy for malignant neoplastic disease using targeted agent"
#           },
#           {
#             "code": "1255834000",
#             "display": "Administration of antineoplastic chemotherapy into peritoneal cavity"
#           },
#           {
#             "code": "1255883001",
#             "display": "Hodgkin sarcoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255885008",
#             "display": "Letterer-Siwe disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255886009",
#             "display": "Mycosis fungoides of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255887000",
#             "display": "Hodgkin's paragranuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255888005",
#             "display": "Hodgkin paragranuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255890006",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255892003",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255894002",
#             "display": "Hodgkin granuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255895001",
#             "display": "Burkitt lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255897009",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255898004",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255899007",
#             "display": "Malignant mast cell tumor of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255902005",
#             "display": "Hodgkin disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255904006",
#             "display": "Administration of palliative antineoplastic agent"
#           },
#           {
#             "code": "1255905007",
#             "display": "Hodgkin disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255906008",
#             "display": "Malignant lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255907004",
#             "display": "Malignant lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1258932003",
#             "display": "Natural killer-lymphoblastic leukemia/lymphoma"
#           },
#           {
#             "code": "1259200004",
#             "display": "Neoadjuvant antineoplastic chemotherapy"
#           },
#           {
#             "code": "1260268001",
#             "display": "Myelodysplastic syndrome with low blasts"
#           },
#           {
#             "code": "1260406003",
#             "display": "Myelodysplastic neoplasm with biallelic TP53 inactivation"
#           },
#           {
#             "code": "1264416003",
#             "display": "Unclassifiable myelodysplastic syndrome"
#           },
#           {
#             "code": "1264458000",
#             "display": "Acute undifferentiated leukemia"
#           },
#           {
#             "code": "127066000",
#             "display": "Familial polycythemia vera"
#           },
#           {
#             "code": "127070008",
#             "display": "Malignant histiocytic disorder"
#           },
#           {
#             "code": "127220001",
#             "display": "Malignant lymphoma of lymph nodes"
#           },
#           {
#             "code": "127225006",
#             "display": "Chronic myelomonocytic leukemia"
#           },
#           {
#             "code": "127911000119105",
#             "display": "Light chain nephropathy due to multiple myeloma"
#           },
#           {
#             "code": "1286863002",
#             "display": "Metastatic malignant neoplasm to cecum and/or colon and/or rectum"
#           },
#           {
#             "code": "128874001",
#             "display": "Cutaneous CD30+ lymphoproliferative disorder"
#           },
#           {
#             "code": "128875000",
#             "display": "Primary cutaneous CD30 antigen positive large T-cell lymphoma"
#           },
#           {
#             "code": "129000002",
#             "display": "Eosinophilic granuloma"
#           },
#           {
#             "code": "13048006",
#             "display": "Orbital lymphoma"
#           },
#           {
#             "code": "133751000119102",
#             "display": "Lymphoma of colon"
#           },
#           {
#             "code": "152451000119104",
#             "display": "History of lymphosarcoma"
#           },
#           {
#             "code": "152861000119104",
#             "display": "History of myeloid leukemia"
#           },
#           {
#             "code": "161436008",
#             "display": "History of leukemia"
#           },
#           {
#             "code": "1659461000000103",
#             "display": "Janus kinase 2 positive polycythaemia vera"
#           },
#           {
#             "code": "1659471000000105",
#             "display": "Janus kinase 2 negative polycythaemia vera"
#           },
#           {
#             "code": "16775311000119107",
#             "display": "Mycosis fungoides of facial lymph node"
#           },
#           {
#             "code": "16894711000119103",
#             "display": "Immunoglobulin G deficiency due to multiple myeloma"
#           },
#           {
#             "code": "169396008",
#             "display": "Radiomimetic chemotherapy"
#           },
#           {
#             "code": "169397004",
#             "display": "Radiochemotherapy: local infiltration"
#           },
#           {
#             "code": "169398009",
#             "display": "Radiochemotherapy: to stop spread"
#           },
#           {
#             "code": "169399001",
#             "display": "Radiochemotherapy via oral route"
#           },
#           {
#             "code": "169400008",
#             "display": "Radiochemotherapy via intravenous route"
#           },
#           {
#             "code": "169401007",
#             "display": "Radiochemotherapy: for immunosuppression"
#           },
#           {
#             "code": "169402000",
#             "display": "Radiochemotherapy: local artery"
#           },
#           {
#             "code": "169403005",
#             "display": "Radiochemotherapy: into cavity"
#           },
#           {
#             "code": "171765004",
#             "display": "Intrathecal injection of chemotherapeutic agent"
#           },
#           {
#             "code": "1881000119103",
#             "display": "History of plasmacytoma"
#           },
#           {
#             "code": "188487008",
#             "display": "Lymphosarcoma and reticulosarcoma"
#           },
#           {
#             "code": "188489006",
#             "display": "Reticulosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188492005",
#             "display": "Reticulosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188493000",
#             "display": "Reticulosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188498009",
#             "display": "Lymphosarcoma"
#           },
#           {
#             "code": "188500005",
#             "display": "Lymphosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188501009",
#             "display": "Lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188502002",
#             "display": "Lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188503007",
#             "display": "Lymphosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188504001",
#             "display": "Lymphosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188505000",
#             "display": "Lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188506004",
#             "display": "Lymphosarcoma of spleen"
#           },
#           {
#             "code": "188507008",
#             "display": "Lymphosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188510001",
#             "display": "Burkitt's lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188511002",
#             "display": "Burkitt's lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188512009",
#             "display": "Burkitt's lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188513004",
#             "display": "Burkitt lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188514005",
#             "display": "Burkitt lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188515006",
#             "display": "Burkitt's lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188516007",
#             "display": "Burkitt's lymphoma of spleen"
#           },
#           {
#             "code": "188517003",
#             "display": "Burkitt's lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188524002",
#             "display": "Hodgkin's paragranuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188526000",
#             "display": "Hodgkin's paragranuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188529007",
#             "display": "Hodgkin's paragranuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188531003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188534006",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188536008",
#             "display": "Hodgkin's granuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188537004",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188538009",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188541000",
#             "display": "Hodgkin's granuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188544008",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188547001",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188548006",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188551004",
#             "display": "Hodgkin's sarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188554007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188558005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188559002",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188562004",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188565002",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188566001",
#             "display": "Hodgkin's disease, nodular sclerosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188567005",
#             "display": "Hodgkin's disease, nodular sclerosis of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188568000",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188569008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188570009",
#             "display": "Hodgkin's disease, nodular sclerosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188572001",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188575004",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188576003",
#             "display": "Hodgkin's disease, mixed cellularity of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188577007",
#             "display": "Hodgkin's disease, mixed cellularity of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188578002",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188579005",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188580008",
#             "display": "Hodgkin's disease, mixed cellularity of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188582000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188585003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188586002",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188587006",
#             "display": "Hodgkin's disease, lymphocytic depletion of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188589009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188590000",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188591001",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188592008",
#             "display": "Hodgkin's disease, lymphocytic depletion of spleen"
#           },
#           {
#             "code": "188593003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188609000",
#             "display": "Nodular lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188612002",
#             "display": "Nodular lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188613007",
#             "display": "Nodular lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188627002",
#             "display": "Mycosis fungoides of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188630009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188631008",
#             "display": "S\u00e9zary's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188632001",
#             "display": "S\u00e9zary's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188633006",
#             "display": "S\u00e9zary's disease of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188634000",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188635004",
#             "display": "S\u00e9zary's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188637007",
#             "display": "S\u00e9zary's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188640007",
#             "display": "Malignant histiocytosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188641006",
#             "display": "Malignant histiocytosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188642004",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188645002",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188648000",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188649008",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188660004",
#             "display": "Malignant mast cell tumors"
#           },
#           {
#             "code": "188662007",
#             "display": "Mast cell malignancy of lymph nodes of head and neck"
#           },
#           {
#             "code": "188663002",
#             "display": "Mast cell malignancy of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188664008",
#             "display": "Mast cell malignancy of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188665009",
#             "display": "Mast cell malignancy of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188666005",
#             "display": "Mast cell malignancy of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188667001",
#             "display": "Mast cell malignancy of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188668006",
#             "display": "Malignant mast cell sarcoma of spleen"
#           },
#           {
#             "code": "188669003",
#             "display": "Mast cell malignancy of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188672005",
#             "display": "Follicular non-Hodgkin's mixed small cleaved and large cell lymphoma"
#           },
#           {
#             "code": "188674006",
#             "display": "Diffuse malignant lymphoma - small non-cleaved cell"
#           },
#           {
#             "code": "188675007",
#             "display": "Malignant lymphoma - small cleaved cell"
#           },
#           {
#             "code": "188676008",
#             "display": "Malignant lymphoma - mixed small and large cell"
#           },
#           {
#             "code": "188679001",
#             "display": "Diffuse non-Hodgkin's lymphoma undifferentiated (diffuse)"
#           },
#           {
#             "code": "188691005",
#             "display": "Malignant immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "188718006",
#             "display": "Malignant plasma cell neoplasm, extramedullary plasmacytoma"
#           },
#           {
#             "code": "188725004",
#             "display": "Lymphoid leukemia"
#           },
#           {
#             "code": "188726003",
#             "display": "Subacute lymphoid leukemia"
#           },
#           {
#             "code": "188728002",
#             "display": "Aleukemic lymphoid leukemia"
#           },
#           {
#             "code": "188729005",
#             "display": "Adult T-cell leukemia"
#           },
#           {
#             "code": "188732008",
#             "display": "Myeloid leukemia"
#           },
#           {
#             "code": "188733003",
#             "display": "Chronic eosinophilic leukemia"
#           },
#           {
#             "code": "188734009",
#             "display": "Chronic neutrophilic leukemia"
#           },
#           {
#             "code": "188736006",
#             "display": "Subacute myeloid leukemia"
#           },
#           {
#             "code": "188737002",
#             "display": "Chloroma"
#           },
#           {
#             "code": "188738007",
#             "display": "Granulocytic sarcoma"
#           },
#           {
#             "code": "188741003",
#             "display": "Aleukemic myeloid leukemia"
#           },
#           {
#             "code": "188744006",
#             "display": "Monocytic leukemia"
#           },
#           {
#             "code": "188745007",
#             "display": "Chronic monocytic leukemia"
#           },
#           {
#             "code": "188746008",
#             "display": "Subacute monocytic leukemia"
#           },
#           {
#             "code": "188748009",
#             "display": "Aleukemic monocytic leukemia"
#           },
#           {
#             "code": "188754005",
#             "display": "Megakaryocytic leukemia"
#           },
#           {
#             "code": "188768003",
#             "display": "Myelomonocytic leukemia"
#           },
#           {
#             "code": "188770007",
#             "display": "Subacute myelomonocytic leukemia"
#           },
#           {
#             "code": "190030009",
#             "display": "Compound leukemias"
#           },
#           {
#             "code": "190955000",
#             "display": "Histiocytosis X syndrome"
#           },
#           {
#             "code": "203436008",
#             "display": "Osteoporosis in multiple myelomatosis"
#           },
#           {
#             "code": "209962000",
#             "display": "Myeloma-associated amyloidosis"
#           },
#           {
#             "code": "22733003",
#             "display": "Chemotherapy for non-malignant neoplasm"
#           },
#           {
#             "code": "230586003",
#             "display": "Neuropathy due to multiple myeloma"
#           },
#           {
#             "code": "230857009",
#             "display": "Injection of chemotherapeutic substance into subcutaneous reservoir"
#           },
#           {
#             "code": "232075002",
#             "display": "Lymphoma of retina"
#           },
#           {
#             "code": "232681000000103",
#             "display": "Chemotherapy delivery"
#           },
#           {
#             "code": "235331000000103",
#             "display": "Delivery of oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "235391000000102",
#             "display": "Delivery of chemotherapy for neoplasm"
#           },
#           {
#             "code": "236512004",
#             "display": "Leukemic infiltrate of kidney"
#           },
#           {
#             "code": "236513009",
#             "display": "Lymphoma of kidney"
#           },
#           {
#             "code": "238831000000103",
#             "display": "Delivery of exclusively oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "238841000000107",
#             "display": "Delivery of complex chemotherapy for neoplasm including prolonged infusional treatment at first attendance"
#           },
#           {
#             "code": "238851000000105",
#             "display": "Delivery of complex parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "238861000000108",
#             "display": "Delivery of simple parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "239071000000100",
#             "display": "Delivery of subsequent element of cycle of chemotherapy for neoplasm"
#           },
#           {
#             "code": "240531002",
#             "display": "African Burkitt's lymphoma"
#           },
#           {
#             "code": "240794006",
#             "display": "Splenic schistosomal giant cell lymphoma"
#           },
#           {
#             "code": "254792006",
#             "display": "Proliferating angioendotheliomatosis"
#           },
#           {
#             "code": "255101006",
#             "display": "S\u00e9zary disease of skin"
#           },
#           {
#             "code": "255102004",
#             "display": "Angioendotheliomatosis"
#           },
#           {
#             "code": "255191003",
#             "display": "Localized malignant reticulohistiocytoma"
#           },
#           {
#             "code": "265760000",
#             "display": "Intravenous chemotherapy"
#           },
#           {
#             "code": "265761001",
#             "display": "Intramuscular chemotherapy"
#           },
#           {
#             "code": "265762008",
#             "display": "Subcutaneous chemotherapy"
#           },
#           {
#             "code": "266719004",
#             "display": "Oral chemotherapy"
#           },
#           {
#             "code": "267540007",
#             "display": "Neutropenia caused by ionizing radiation"
#           },
#           {
#             "code": "268500004",
#             "display": "Administration of prophylactic chemotherapy"
#           },
#           {
#             "code": "269475001",
#             "display": "Malignant tumor of lymphoid, hemopoietic AND/OR related tissue"
#           },
#           {
#             "code": "269476000",
#             "display": "Nodular lymphoma"
#           },
#           {
#             "code": "274905008",
#             "display": "Malignant lymphoma - lymphocytic, intermediate differentiation"
#           },
#           {
#             "code": "276811008",
#             "display": "Gastric lymphoma"
#           },
#           {
#             "code": "276815004",
#             "display": "Lymphoma of intestine"
#           },
#           {
#             "code": "276836002",
#             "display": "Primary cerebral lymphoma"
#           },
#           {
#             "code": "277473004",
#             "display": "B-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277474005",
#             "display": "B-cell chronic lymphocytic leukemia variant"
#           },
#           {
#             "code": "277543005",
#             "display": "Malignant white blood cell disorder"
#           },
#           {
#             "code": "277545003",
#             "display": "T-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277549009",
#             "display": "Chronic lymphocytic prolymphocytic leukemia syndrome"
#           },
#           {
#             "code": "277550009",
#             "display": "Richter's syndrome"
#           },
#           {
#             "code": "277551008",
#             "display": "Splenic lymphoma with villous lymphocytes"
#           },
#           {
# ...
#           },
#           {
#             "code": "93152000",
#             "display": "Leukemic reticuloendotheliosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93182006",
#             "display": "Malignant histiocytosis of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93183001",
#             "display": "Malignant histiocytosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93184007",
#             "display": "Malignant histiocytosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93185008",
#             "display": "Malignant histiocytosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93186009",
#             "display": "Malignant histiocytosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93187000",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93188005",
#             "display": "Malignant histiocytosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93189002",
#             "display": "Malignant histiocytosis of spleen"
#           },
#           {
#             "code": "93190006",
#             "display": "Malignant histiocytosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93191005",
#             "display": "Malignant lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93192003",
#             "display": "Malignant lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93193008",
#             "display": "Malignant lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93194002",
#             "display": "Malignant lymphoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93195001",
#             "display": "Malignant lymphoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93196000",
#             "display": "Malignant lymphoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93197009",
#             "display": "Malignant lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93198004",
#             "display": "Malignant lymphoma of spleen"
#           },
#           {
#             "code": "93199007",
#             "display": "Malignant lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93200005",
#             "display": "Malignant mast cell tumor of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93201009",
#             "display": "Malignant mast cell tumor of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93202002",
#             "display": "Malignant mast cell tumor of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93203007",
#             "display": "Malignant mast cell tumor of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93204001",
#             "display": "Malignant mast cell tumor of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93205000",
#             "display": "Malignant mast cell tumor of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93206004",
#             "display": "Malignant mast cell tumor of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93207008",
#             "display": "Malignant mast cell tumor of spleen"
#           },
#           {
#             "code": "93208003",
#             "display": "Malignant mast cell tumor of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93451002",
#             "display": "Erythroleukemia, FAB M6"
#           },
#           {
#             "code": "93487009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93488004",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93489007",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93492006",
#             "display": "Hodgkin's disease, lymphocytic depletion of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93493001",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93494007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93495008",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93496009",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93497000",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93498005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93500006",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of spleen"
#           },
#           {
#             "code": "93501005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93505001",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93506000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93507009",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93509007",
#             "display": "Hodgkin's disease, mixed cellularity of spleen"
#           },
#           {
#             "code": "93510002",
#             "display": "Hodgkin's disease, mixed cellularity of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93514006",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93515007",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93516008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93518009",
#             "display": "Hodgkin's disease, nodular sclerosis of spleen"
#           },
#           {
#             "code": "93519001",
#             "display": "Hodgkin's disease, nodular sclerosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93520007",
#             "display": "Hodgkin's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93521006",
#             "display": "Hodgkin's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93522004",
#             "display": "Hodgkin's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93523009",
#             "display": "Hodgkin's disease of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93524003",
#             "display": "Hodgkin's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93525002",
#             "display": "Hodgkin's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93526001",
#             "display": "Hodgkin's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93527005",
#             "display": "Hodgkin's disease of spleen"
#           },
#           {
#             "code": "93528000",
#             "display": "Hodgkin's disease of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93530003",
#             "display": "Hodgkin's granuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93531004",
#             "display": "Hodgkin's granuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93532006",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93533001",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93534007",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93536009",
#             "display": "Hodgkin's granuloma of spleen"
#           },
#           {
#             "code": "93537000",
#             "display": "Hodgkin's granuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93541001",
#             "display": "Hodgkin's paragranuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93542008",
#             "display": "Hodgkin's paragranuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93543003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93545005",
#             "display": "Hodgkin's paragranuloma of spleen"
#           },
#           {
#             "code": "93546006",
#             "display": "Hodgkin's paragranuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93547002",
#             "display": "Hodgkin's sarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93548007",
#             "display": "Hodgkin's sarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93549004",
#             "display": "Hodgkin's sarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93550004",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93551000",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93552007",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93554008",
#             "display": "Hodgkin's sarcoma of spleen"
#           },
#           {
#             "code": "93555009",
#             "display": "Hodgkin's sarcoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94686001",
#             "display": "Mixed cell type lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94687005",
#             "display": "Mixed cell type lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94688000",
#             "display": "Mixed cell type lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94690004",
#             "display": "Mixed cell type lymphosarcoma of lymph nodes of head, face, and neck"
#           },
#           {
#             "code": "94704006",
#             "display": "Multiple myeloma in remission"
#           },
#           {
#             "code": "94707004",
#             "display": "Mycosis fungoides of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94708009",
#             "display": "Mycosis fungoides of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94709001",
#             "display": "Mycosis fungoides of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94710006",
#             "display": "Mycosis fungoides of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "94711005",
#             "display": "Mycosis fungoides of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "94712003",
#             "display": "Mycosis fungoides of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "94714002",
#             "display": "Mycosis fungoides of spleen"
#           },
#           {
#             "code": "94715001",
#             "display": "Mycosis fungoides of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94719007",
#             "display": "Myeloid sarcoma, disease"
#           },
#           {
#             "code": "95186006",
#             "display": "Nodular lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95187002",
#             "display": "Nodular lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95188007",
#             "display": "Nodular lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95192000",
#             "display": "Nodular lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95193005",
#             "display": "Nodular lymphoma of spleen"
#           },
#           {
#             "code": "95194004",
#             "display": "Nodular lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "95209008",
#             "display": "Plasma cell leukemia in remission"
#           },
#           {
#             "code": "95210003",
#             "display": "Plasma cell leukemia, disease"
#           },
#           {
#             "code": "95224004",
#             "display": "Reticulosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95225003",
#             "display": "Reticulosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95226002",
#             "display": "Reticulosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95230004",
#             "display": "Reticulosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95231000",
#             "display": "Reticulosarcoma of spleen"
#           },
#           {
#             "code": "95260009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "95261008",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "95263006",
#             "display": "S\u00e9zary's disease of spleen"
#           },
#           {
#             "code": "95264000",
#             "display": "S\u00e9zary's disease of extranodal AND/OR solid organ site"
#           }
#         ]
#       }
#     ]
#   },
#   "id": "nhsd-primary-care-domain-refsets-c19haemcan-cod"
# }
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_41548/1837258088.py:1: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(str(table[3]))

# %%
#soup = BeautifulSoup(r.text,'html.parser')
table = soup.find_all('h1','h3')
mystring = table[0].text
mystring = mystring.replace('\n', ' ').replace('\r', '').strip()
print(mystring)
valueSetJson['title']=mystring
print(json.dumps(valueSetJson, indent=2))
valueSet = ValueSet(**valueSetJson)
# Out:
# Haematological cancer codes
# {
#   "resourceType": "ValueSet",
#   "status": "active",
#   "compose": {
#     "include": [
#       {
#         "system": "http://snomed.info/sct",
#         "concept": [
#           {
#             "code": "103077004",
#             "display": "Immunodeficiency secondary to neoplasm"
#           },
#           {
#             "code": "108521000119103",
#             "display": "History of reticulosarcoma"
#           },
#           {
#             "code": "1090241000000107",
#             "display": "Angioimmunoblastic T-cell lymphoma with dysproteinaemia"
#           },
#           {
#             "code": "1091861000000100",
#             "display": "Follicular lymphoma, cutaneous follicle centre"
#           },
#           {
#             "code": "1091891000000106",
#             "display": "B-cell Hodgkin's lymphoma"
#           },
#           {
#             "code": "1091921000000103",
#             "display": "B-cell non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109962001",
#             "display": "Diffuse non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "109964000",
#             "display": "Diffuse non-Hodgkin's lymphoma, undifferentiated"
#           },
#           {
#             "code": "109965004",
#             "display": "Diffuse non-Hodgkin's lymphoma, lymphoblastic"
#           },
#           {
#             "code": "109966003",
#             "display": "Diffuse non-Hodgkin's lymphoma, immunoblastic"
#           },
#           {
#             "code": "109967007",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109968002",
#             "display": "Diffuse non-Hodgkin's lymphoma, small cell"
#           },
#           {
#             "code": "109969005",
#             "display": "Diffuse large B-cell malignant lymphoma"
#           },
#           {
#             "code": "109970006",
#             "display": "Follicular non-Hodgkin's lymphoma, small cleaved cell"
#           },
#           {
#             "code": "109971005",
#             "display": "Follicular non-Hodgkin's lymphoma, mixed small cleaved cell and large cell"
#           },
#           {
#             "code": "109972003",
#             "display": "Follicular non-Hodgkin's lymphoma, large cell"
#           },
#           {
#             "code": "109975001",
#             "display": "T-zone lymphoma"
#           },
#           {
#             "code": "109976000",
#             "display": "Lymphoepithelioid lymphoma"
#           },
#           {
#             "code": "109977009",
#             "display": "Peripheral T-cell lymphoma"
#           },
#           {
#             "code": "109978004",
#             "display": "T-cell lymphoma"
#           },
#           {
#             "code": "109979007",
#             "display": "B-cell lymphoma"
#           },
#           {
#             "code": "109980005",
#             "display": "Malignant immunoproliferative disease"
#           },
#           {
#             "code": "109981009",
#             "display": "Waldenstr\u00f6m macroglobulinemia"
#           },
#           {
#             "code": "109985000",
#             "display": "Immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "109988003",
#             "display": "Histiocytic sarcoma"
#           },
#           {
#             "code": "109989006",
#             "display": "Multiple myeloma"
#           },
#           {
#             "code": "109991003",
#             "display": "Acute panmyelosis with myelofibrosis"
#           },
#           {
#             "code": "109992005",
#             "display": "Polycythemia vera"
#           },
#           {
#             "code": "110000005",
#             "display": "Refractory anemia with excess blasts in transformation"
#           },
#           {
#             "code": "110002002",
#             "display": "Mast cell leukemia"
#           },
#           {
#             "code": "110004001",
#             "display": "Acute promyelocytic leukemia, FAB M3"
#           },
#           {
#             "code": "110005000",
#             "display": "Acute myelomonocytic leukemia, FAB M4"
#           },
#           {
#             "code": "110006004",
#             "display": "Prolymphocytic leukemia"
#           },
#           {
#             "code": "110007008",
#             "display": "Adult T-cell leukemia/lymphoma"
#           },
#           {
#             "code": "1148845007",
#             "display": "Follicular lymphoma grade 3b"
#           },
#           {
#             "code": "1148851002",
#             "display": "Follicular lymphoma grade 3a"
#           },
#           {
#             "code": "1148888004",
#             "display": "Nodular glomerulosclerosis due to heavy chain deposition disease"
#           },
#           {
#             "code": "1148906001",
#             "display": "Acute myeloid leukemia with t(8;21)(q22;q22) RUNX1-RUNX1T1"
#           },
#           {
#             "code": "1153336009",
#             "display": "Pediatric nodal marginal zone B cell lymphoma"
#           },
#           {
#             "code": "1153341001",
#             "display": "Myeloproliferative hypereosinophilic syndrome"
#           },
#           {
#             "code": "1153346006",
#             "display": "Primary non-Hodgkin malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1153347002",
#             "display": "Primary non-Hodgkin malignant lymphoma of vitreoretinal tract"
#           },
#           {
#             "code": "1153348007",
#             "display": "Primary effusion lymphoma due to human immune deficiency virus infection"
#           },
#           {
#             "code": "1153349004",
#             "display": "Primary familial polycythemia due to erythropoietin receptor mutation"
#           },
#           {
#             "code": "1153354008",
#             "display": "Malignant lymphoma of duodenum"
#           },
#           {
#             "code": "1153355009",
#             "display": "Malignant lymphoma of esophagus"
#           },
#           {
#             "code": "1153356005",
#             "display": "Lymphoma of anus"
#           },
#           {
#             "code": "1153357001",
#             "display": "Lymphoma of appendix"
#           },
#           {
#             "code": "1153377008",
#             "display": "Mixed phenotype acute leukemia with t(9;22) (q34;q11.2); BCR-ABL1"
#           },
#           {
#             "code": "1153379006",
#             "display": "Mixed phenotype acute leukemia with T-cell and myeloid lineage"
#           },
#           {
#             "code": "1153381008",
#             "display": "Mixed phenotype acute leukemia with myeloid and B-cell lymphoid phenotypes"
#           },
#           {
#             "code": "1153382001",
#             "display": "Malignant lymphoma of lacrimal gland"
#           },
#           {
#             "code": "1153383006",
#             "display": "Malignant lymphoma of liver"
#           },
#           {
#             "code": "1153397003",
#             "display": "Hydroa vacciniforme-like cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "1156403002",
#             "display": "Composite Hodgkin and non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1157157006",
#             "display": "Acute myeloid leukemia with 11q23 abnormality"
#           },
#           {
#             "code": "1157162007",
#             "display": "Intravascular large B-cell lymphoma"
#           },
#           {
#             "code": "1162264008",
#             "display": "Malignant lymphoma of uveal tract"
#           },
#           {
#             "code": "1162531007",
#             "display": "Acute myeloid leukemia in complete remission"
#           },
#           {
#             "code": "116691000119101",
#             "display": "Marginal zone lymphoma of spleen"
#           },
#           {
#             "code": "116811000119106",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of lower limb"
#           },
#           {
#             "code": "116821000119104",
#             "display": "Non-Hodgkin lymphoma of central nervous system metastatic to lymph node of upper limb"
#           },
#           {
#             "code": "116841000119105",
#             "display": "Marginal zone lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "116871000119103",
#             "display": "Mantle cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "117211000119105",
#             "display": "Peripheral T-cell lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "1172516002",
#             "display": "High-dose chemotherapy with stem cell transplant"
#           },
#           {
#             "code": "1172704005",
#             "display": "High grade B-cell lymphoma with MYC and BCL2 and/or BCL6 rearrangements"
#           },
#           {
#             "code": "118599009",
#             "display": "Hodgkin's disease"
#           },
#           {
#             "code": "118600007",
#             "display": "Malignant lymphoma"
#           },
#           {
#             "code": "118601006",
#             "display": "Non-Hodgkin's lymphoma"
#           },
#           {
#             "code": "118602004",
#             "display": "Hodgkin's granuloma"
#           },
#           {
#             "code": "118605002",
#             "display": "Hodgkin lymphoma, nodular lymphocyte predominance"
#           },
#           {
#             "code": "118606001",
#             "display": "Hodgkin's sarcoma"
#           },
#           {
#             "code": "118607005",
#             "display": "Hodgkin lymphoma, lymphocyte-rich"
#           },
#           {
#             "code": "118608000",
#             "display": "Hodgkin's disease, nodular sclerosis"
#           },
#           {
#             "code": "118609008",
#             "display": "Hodgkin's disease, mixed cellularity"
#           },
#           {
#             "code": "118610003",
#             "display": "Hodgkin's disease, lymphocytic depletion"
#           },
#           {
#             "code": "118611004",
#             "display": "S\u00e9zary's disease"
#           },
#           {
#             "code": "118612006",
#             "display": "Malignant histiocytosis"
#           },
#           {
#             "code": "118613001",
#             "display": "Hairy cell leukemia"
#           },
#           {
#             "code": "118614007",
#             "display": "Langerhans cell histiocytosis, disseminated"
#           },
#           {
#             "code": "118615008",
#             "display": "Malignant mast cell tumor"
#           },
#           {
#             "code": "118617000",
#             "display": "Burkitt's lymphoma"
#           },
#           {
#             "code": "118618005",
#             "display": "Mycosis fungoides"
#           },
#           {
#             "code": "1187123005",
#             "display": "Mixed phenotype acute leukemia"
#           },
#           {
#             "code": "1196900003",
#             "display": "B cell lymphoma of small intestine"
#           },
#           {
#             "code": "1197344000",
#             "display": "T-cell lymphoma of small intestine"
#           },
#           {
#             "code": "120481000119109",
#             "display": "History of multiple myeloma"
#           },
#           {
#             "code": "12149006",
#             "display": "Chemotherapy administration, subcutaneous, with local anesthesia"
#           },
#           {
#             "code": "1217301006",
#             "display": "Precursor cell lymphoblastic lymphoma"
#           },
#           {
#             "code": "122571000119106",
#             "display": "History of malignant cutaneous T-cell lymphoma"
#           },
#           {
#             "code": "12281000132104",
#             "display": "Relapsing acute myeloid leukemia"
#           },
#           {
#             "code": "1228842003",
#             "display": "Primary cutaneous plasmacytosis"
#           },
#           {
#             "code": "12291000132102",
#             "display": "Refractory acute myeloid leukemia"
#           },
#           {
#             "code": "1229988003",
#             "display": "Myeloid and/or lymphoid neoplasm with pericentriolar material 1-janus kinase 2"
#           },
#           {
#             "code": "12301000132103",
#             "display": "Acute lymphoid leukemia relapse"
#           },
#           {
#             "code": "12311000132101",
#             "display": "Refractory acute lymphoid leukemia"
#           },
#           {
#             "code": "1231732006",
#             "display": "Smoldering systemic mastocytosis"
#           },
#           {
#             "code": "12341000132100",
#             "display": "B-cell lymphoma, unclassifiable, with features intermediate between diffuse large B-cell lymphoma and Burkitt lymphoma"
#           },
#           {
#             "code": "1237368006",
#             "display": "Acute myeloid leukemia with BCR-ABL1"
#           },
#           {
#             "code": "1237578005",
#             "display": "Primary oculocerebral non-Hodgkin lymphoma"
#           },
#           {
#             "code": "1237617004",
#             "display": "Hypereosinophilic syndrome due to disease"
#           },
#           {
#             "code": "1254741007",
#             "display": "Intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1254742000",
#             "display": "Delayed intensification antineoplastic therapy regimen"
#           },
#           {
#             "code": "1255270006",
#             "display": "Lymphoplasmacytic lymphoma without immunoglobulin M production"
#           },
#           {
#             "code": "1255666008",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of neck"
#           },
#           {
#             "code": "1255687003",
#             "display": "Hodgkin lymphoma, lymphocyte depletion of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255726001",
#             "display": "Hodgkin granuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255727005",
#             "display": "Hodgkin granuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255728000",
#             "display": "Hodgkin granuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255729008",
#             "display": "Mast cell malignancy of lymph nodes of head"
#           },
#           {
#             "code": "1255730003",
#             "display": "Mast cell malignancy of lymph nodes of neck"
#           },
#           {
#             "code": "1255737000",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head"
#           },
#           {
#             "code": "1255738005",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of neck"
#           },
#           {
#             "code": "1255739002",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255740000",
#             "display": "Letterer-Siwe disease of lymph nodes of head"
#           },
#           {
#             "code": "1255741001",
#             "display": "Letterer-Siwe disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255742008",
#             "display": "Letterer-Siwe disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255743003",
#             "display": "Hodgkin sarcoma of lymph nodes of head"
#           },
#           {
#             "code": "1255744009",
#             "display": "Hodgkin sarcoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255745005",
#             "display": "Hodgkin sarcoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255746006",
#             "display": "Malignant histiocytosis of lymph nodes of head"
#           },
#           {
#             "code": "1255747002",
#             "display": "Malignant histiocytosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255748007",
#             "display": "Malignant histiocytosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255749004",
#             "display": "Burkitt tumor of lymph nodes of head"
#           },
#           {
#             "code": "1255750004",
#             "display": "Burkitt tumor of lymph nodes of neck"
#           },
#           {
#             "code": "1255751000",
#             "display": "Burkitt tumor of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255752007",
#             "display": "Mycosis fungoides of lymph nodes of head"
#           },
#           {
#             "code": "1255753002",
#             "display": "Mycosis fungoides of lymph nodes of neck"
#           },
#           {
#             "code": "1255754008",
#             "display": "Mycosis fungoides of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255784000",
#             "display": "Hodgkin paragranuloma of lymph nodes of head"
#           },
#           {
#             "code": "1255785004",
#             "display": "Hodgkin paragranuloma of lymph nodes of neck"
#           },
#           {
#             "code": "1255786003",
#             "display": "Hodgkin paragranuloma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255788002",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head"
#           },
#           {
#             "code": "1255789005",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of neck"
#           },
#           {
#             "code": "1255790001",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255791002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255792009",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of head"
#           },
#           {
#             "code": "1255793004",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of neck"
#           },
#           {
#             "code": "1255795006",
#             "display": "Malignant histiocytosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255796007",
#             "display": "Burkitt lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255797003",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255798008",
#             "display": "Hodgkin granuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255799000",
#             "display": "S\u00e9zary disease of lymph nodes of head"
#           },
#           {
#             "code": "1255800001",
#             "display": "S\u00e9zary disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255801002",
#             "display": "S\u00e9zary disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255802009",
#             "display": "Hodgkin disease of lymph nodes of head"
#           },
#           {
#             "code": "1255803004",
#             "display": "Hodgkin disease of lymph nodes of neck"
#           },
#           {
#             "code": "1255804005",
#             "display": "Hodgkin disease of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255805006",
#             "display": "Malignant lymphoma of lymph nodes of head"
#           },
#           {
#             "code": "1255806007",
#             "display": "Malignant lymphoma of lymph nodes of neck"
#           },
#           {
#             "code": "1255807003",
#             "display": "Malignant lymphoma of lymph nodes of head and neck"
#           },
#           {
#             "code": "1255808008",
#             "display": "Hodgkin sarcoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255809000",
#             "display": "Malignant mast cell tumor of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255811009",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255812002",
#             "display": "Hodgkin disease, nodular sclerosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255813007",
#             "display": "Letterer-Siwe disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255814001",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255815000",
#             "display": "Malignant histiocytosis of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255831008",
#             "display": "Chemotherapy for malignant neoplastic disease using targeted agent"
#           },
#           {
#             "code": "1255834000",
#             "display": "Administration of antineoplastic chemotherapy into peritoneal cavity"
#           },
#           {
#             "code": "1255883001",
#             "display": "Hodgkin sarcoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255885008",
#             "display": "Letterer-Siwe disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255886009",
#             "display": "Mycosis fungoides of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255887000",
#             "display": "Hodgkin's paragranuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255888005",
#             "display": "Hodgkin paragranuloma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255890006",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255892003",
#             "display": "Hodgkin disease, lymphocytic depletion of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255894002",
#             "display": "Hodgkin granuloma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255895001",
#             "display": "Burkitt lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255897009",
#             "display": "Hodgkin disease, lymphocytic-histiocytic predominance of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255898004",
#             "display": "Hodgkin disease, mixed cellularity of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255899007",
#             "display": "Malignant mast cell tumor of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255902005",
#             "display": "Hodgkin disease of lymph nodes of lower limb"
#           },
#           {
#             "code": "1255904006",
#             "display": "Administration of palliative antineoplastic agent"
#           },
#           {
#             "code": "1255905007",
#             "display": "Hodgkin disease of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255906008",
#             "display": "Malignant lymphoma of lymph nodes of upper limb"
#           },
#           {
#             "code": "1255907004",
#             "display": "Malignant lymphoma of lymph nodes of lower limb"
#           },
#           {
#             "code": "1258932003",
#             "display": "Natural killer-lymphoblastic leukemia/lymphoma"
#           },
#           {
#             "code": "1259200004",
#             "display": "Neoadjuvant antineoplastic chemotherapy"
#           },
#           {
#             "code": "1260268001",
#             "display": "Myelodysplastic syndrome with low blasts"
#           },
#           {
#             "code": "1260406003",
#             "display": "Myelodysplastic neoplasm with biallelic TP53 inactivation"
#           },
#           {
#             "code": "1264416003",
#             "display": "Unclassifiable myelodysplastic syndrome"
#           },
#           {
#             "code": "1264458000",
#             "display": "Acute undifferentiated leukemia"
#           },
#           {
#             "code": "127066000",
#             "display": "Familial polycythemia vera"
#           },
#           {
#             "code": "127070008",
#             "display": "Malignant histiocytic disorder"
#           },
#           {
#             "code": "127220001",
#             "display": "Malignant lymphoma of lymph nodes"
#           },
#           {
#             "code": "127225006",
#             "display": "Chronic myelomonocytic leukemia"
#           },
#           {
#             "code": "127911000119105",
#             "display": "Light chain nephropathy due to multiple myeloma"
#           },
#           {
#             "code": "1286863002",
#             "display": "Metastatic malignant neoplasm to cecum and/or colon and/or rectum"
#           },
#           {
#             "code": "128874001",
#             "display": "Cutaneous CD30+ lymphoproliferative disorder"
#           },
#           {
#             "code": "128875000",
#             "display": "Primary cutaneous CD30 antigen positive large T-cell lymphoma"
#           },
#           {
#             "code": "129000002",
#             "display": "Eosinophilic granuloma"
#           },
#           {
#             "code": "13048006",
#             "display": "Orbital lymphoma"
#           },
#           {
#             "code": "133751000119102",
#             "display": "Lymphoma of colon"
#           },
#           {
#             "code": "152451000119104",
#             "display": "History of lymphosarcoma"
#           },
#           {
#             "code": "152861000119104",
#             "display": "History of myeloid leukemia"
#           },
#           {
#             "code": "161436008",
#             "display": "History of leukemia"
#           },
#           {
#             "code": "1659461000000103",
#             "display": "Janus kinase 2 positive polycythaemia vera"
#           },
#           {
#             "code": "1659471000000105",
#             "display": "Janus kinase 2 negative polycythaemia vera"
#           },
#           {
#             "code": "16775311000119107",
#             "display": "Mycosis fungoides of facial lymph node"
#           },
#           {
#             "code": "16894711000119103",
#             "display": "Immunoglobulin G deficiency due to multiple myeloma"
#           },
#           {
#             "code": "169396008",
#             "display": "Radiomimetic chemotherapy"
#           },
#           {
#             "code": "169397004",
#             "display": "Radiochemotherapy: local infiltration"
#           },
#           {
#             "code": "169398009",
#             "display": "Radiochemotherapy: to stop spread"
#           },
#           {
#             "code": "169399001",
#             "display": "Radiochemotherapy via oral route"
#           },
#           {
#             "code": "169400008",
#             "display": "Radiochemotherapy via intravenous route"
#           },
#           {
#             "code": "169401007",
#             "display": "Radiochemotherapy: for immunosuppression"
#           },
#           {
#             "code": "169402000",
#             "display": "Radiochemotherapy: local artery"
#           },
#           {
#             "code": "169403005",
#             "display": "Radiochemotherapy: into cavity"
#           },
#           {
#             "code": "171765004",
#             "display": "Intrathecal injection of chemotherapeutic agent"
#           },
#           {
#             "code": "1881000119103",
#             "display": "History of plasmacytoma"
#           },
#           {
#             "code": "188487008",
#             "display": "Lymphosarcoma and reticulosarcoma"
#           },
#           {
#             "code": "188489006",
#             "display": "Reticulosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188492005",
#             "display": "Reticulosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188493000",
#             "display": "Reticulosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188498009",
#             "display": "Lymphosarcoma"
#           },
#           {
#             "code": "188500005",
#             "display": "Lymphosarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188501009",
#             "display": "Lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188502002",
#             "display": "Lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188503007",
#             "display": "Lymphosarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188504001",
#             "display": "Lymphosarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188505000",
#             "display": "Lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188506004",
#             "display": "Lymphosarcoma of spleen"
#           },
#           {
#             "code": "188507008",
#             "display": "Lymphosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188510001",
#             "display": "Burkitt's lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188511002",
#             "display": "Burkitt's lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188512009",
#             "display": "Burkitt's lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188513004",
#             "display": "Burkitt lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188514005",
#             "display": "Burkitt lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188515006",
#             "display": "Burkitt's lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188516007",
#             "display": "Burkitt's lymphoma of spleen"
#           },
#           {
#             "code": "188517003",
#             "display": "Burkitt's lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188524002",
#             "display": "Hodgkin's paragranuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188526000",
#             "display": "Hodgkin's paragranuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188529007",
#             "display": "Hodgkin's paragranuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188531003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188534006",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188536008",
#             "display": "Hodgkin's granuloma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188537004",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188538009",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188541000",
#             "display": "Hodgkin's granuloma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188544008",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188547001",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188548006",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188551004",
#             "display": "Hodgkin's sarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188554007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188558005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188559002",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188562004",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188565002",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188566001",
#             "display": "Hodgkin's disease, nodular sclerosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188567005",
#             "display": "Hodgkin's disease, nodular sclerosis of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188568000",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188569008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188570009",
#             "display": "Hodgkin's disease, nodular sclerosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188572001",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188575004",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188576003",
#             "display": "Hodgkin's disease, mixed cellularity of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188577007",
#             "display": "Hodgkin's disease, mixed cellularity of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188578002",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188579005",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188580008",
#             "display": "Hodgkin's disease, mixed cellularity of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188582000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188585003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188586002",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188587006",
#             "display": "Hodgkin's disease, lymphocytic depletion of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188589009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188590000",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188591001",
#             "display": "Hodgkin's disease, lymphocytic depletion of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188592008",
#             "display": "Hodgkin's disease, lymphocytic depletion of spleen"
#           },
#           {
#             "code": "188593003",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188609000",
#             "display": "Nodular lymphoma of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188612002",
#             "display": "Nodular lymphoma of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188613007",
#             "display": "Nodular lymphoma of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188627002",
#             "display": "Mycosis fungoides of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188630009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188631008",
#             "display": "S\u00e9zary's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188632001",
#             "display": "S\u00e9zary's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188633006",
#             "display": "S\u00e9zary's disease of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188634000",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188635004",
#             "display": "S\u00e9zary's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188637007",
#             "display": "S\u00e9zary's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188640007",
#             "display": "Malignant histiocytosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188641006",
#             "display": "Malignant histiocytosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188642004",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188645002",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of head, face and neck"
#           },
#           {
#             "code": "188648000",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188649008",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188660004",
#             "display": "Malignant mast cell tumors"
#           },
#           {
#             "code": "188662007",
#             "display": "Mast cell malignancy of lymph nodes of head and neck"
#           },
#           {
#             "code": "188663002",
#             "display": "Mast cell malignancy of intrathoracic lymph nodes"
#           },
#           {
#             "code": "188664008",
#             "display": "Mast cell malignancy of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "188665009",
#             "display": "Mast cell malignancy of lymph nodes of axilla and upper limb"
#           },
#           {
#             "code": "188666005",
#             "display": "Mast cell malignancy of lymph nodes of inguinal region and lower limb"
#           },
#           {
#             "code": "188667001",
#             "display": "Mast cell malignancy of intrapelvic lymph nodes"
#           },
#           {
#             "code": "188668006",
#             "display": "Malignant mast cell sarcoma of spleen"
#           },
#           {
#             "code": "188669003",
#             "display": "Mast cell malignancy of lymph nodes of multiple sites"
#           },
#           {
#             "code": "188672005",
#             "display": "Follicular non-Hodgkin's mixed small cleaved and large cell lymphoma"
#           },
#           {
#             "code": "188674006",
#             "display": "Diffuse malignant lymphoma - small non-cleaved cell"
#           },
#           {
#             "code": "188675007",
#             "display": "Malignant lymphoma - small cleaved cell"
#           },
#           {
#             "code": "188676008",
#             "display": "Malignant lymphoma - mixed small and large cell"
#           },
#           {
#             "code": "188679001",
#             "display": "Diffuse non-Hodgkin's lymphoma undifferentiated (diffuse)"
#           },
#           {
#             "code": "188691005",
#             "display": "Malignant immunoproliferative small intestinal disease"
#           },
#           {
#             "code": "188718006",
#             "display": "Malignant plasma cell neoplasm, extramedullary plasmacytoma"
#           },
#           {
#             "code": "188725004",
#             "display": "Lymphoid leukemia"
#           },
#           {
#             "code": "188726003",
#             "display": "Subacute lymphoid leukemia"
#           },
#           {
#             "code": "188728002",
#             "display": "Aleukemic lymphoid leukemia"
#           },
#           {
#             "code": "188729005",
#             "display": "Adult T-cell leukemia"
#           },
#           {
#             "code": "188732008",
#             "display": "Myeloid leukemia"
#           },
#           {
#             "code": "188733003",
#             "display": "Chronic eosinophilic leukemia"
#           },
#           {
#             "code": "188734009",
#             "display": "Chronic neutrophilic leukemia"
#           },
#           {
#             "code": "188736006",
#             "display": "Subacute myeloid leukemia"
#           },
#           {
#             "code": "188737002",
#             "display": "Chloroma"
#           },
#           {
#             "code": "188738007",
#             "display": "Granulocytic sarcoma"
#           },
#           {
#             "code": "188741003",
#             "display": "Aleukemic myeloid leukemia"
#           },
#           {
#             "code": "188744006",
#             "display": "Monocytic leukemia"
#           },
#           {
#             "code": "188745007",
#             "display": "Chronic monocytic leukemia"
#           },
#           {
#             "code": "188746008",
#             "display": "Subacute monocytic leukemia"
#           },
#           {
#             "code": "188748009",
#             "display": "Aleukemic monocytic leukemia"
#           },
#           {
#             "code": "188754005",
#             "display": "Megakaryocytic leukemia"
#           },
#           {
#             "code": "188768003",
#             "display": "Myelomonocytic leukemia"
#           },
#           {
#             "code": "188770007",
#             "display": "Subacute myelomonocytic leukemia"
#           },
#           {
#             "code": "190030009",
#             "display": "Compound leukemias"
#           },
#           {
#             "code": "190955000",
#             "display": "Histiocytosis X syndrome"
#           },
#           {
#             "code": "203436008",
#             "display": "Osteoporosis in multiple myelomatosis"
#           },
#           {
#             "code": "209962000",
#             "display": "Myeloma-associated amyloidosis"
#           },
#           {
#             "code": "22733003",
#             "display": "Chemotherapy for non-malignant neoplasm"
#           },
#           {
#             "code": "230586003",
#             "display": "Neuropathy due to multiple myeloma"
#           },
#           {
#             "code": "230857009",
#             "display": "Injection of chemotherapeutic substance into subcutaneous reservoir"
#           },
#           {
#             "code": "232075002",
#             "display": "Lymphoma of retina"
#           },
#           {
#             "code": "232681000000103",
#             "display": "Chemotherapy delivery"
#           },
#           {
#             "code": "235331000000103",
#             "display": "Delivery of oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "235391000000102",
#             "display": "Delivery of chemotherapy for neoplasm"
#           },
#           {
#             "code": "236512004",
#             "display": "Leukemic infiltrate of kidney"
#           },
#           {
#             "code": "236513009",
#             "display": "Lymphoma of kidney"
#           },
#           {
#             "code": "238831000000103",
#             "display": "Delivery of exclusively oral chemotherapy for neoplasm"
#           },
#           {
#             "code": "238841000000107",
#             "display": "Delivery of complex chemotherapy for neoplasm including prolonged infusional treatment at first attendance"
#           },
#           {
#             "code": "238851000000105",
#             "display": "Delivery of complex parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "238861000000108",
#             "display": "Delivery of simple parenteral chemotherapy for neoplasm at first attendance"
#           },
#           {
#             "code": "239071000000100",
#             "display": "Delivery of subsequent element of cycle of chemotherapy for neoplasm"
#           },
#           {
#             "code": "240531002",
#             "display": "African Burkitt's lymphoma"
#           },
#           {
#             "code": "240794006",
#             "display": "Splenic schistosomal giant cell lymphoma"
#           },
#           {
#             "code": "254792006",
#             "display": "Proliferating angioendotheliomatosis"
#           },
#           {
#             "code": "255101006",
#             "display": "S\u00e9zary disease of skin"
#           },
#           {
#             "code": "255102004",
#             "display": "Angioendotheliomatosis"
#           },
#           {
#             "code": "255191003",
#             "display": "Localized malignant reticulohistiocytoma"
#           },
#           {
#             "code": "265760000",
#             "display": "Intravenous chemotherapy"
#           },
#           {
#             "code": "265761001",
#             "display": "Intramuscular chemotherapy"
#           },
#           {
#             "code": "265762008",
#             "display": "Subcutaneous chemotherapy"
#           },
#           {
#             "code": "266719004",
#             "display": "Oral chemotherapy"
#           },
#           {
#             "code": "267540007",
#             "display": "Neutropenia caused by ionizing radiation"
#           },
#           {
#             "code": "268500004",
#             "display": "Administration of prophylactic chemotherapy"
#           },
#           {
#             "code": "269475001",
#             "display": "Malignant tumor of lymphoid, hemopoietic AND/OR related tissue"
#           },
#           {
#             "code": "269476000",
#             "display": "Nodular lymphoma"
#           },
#           {
#             "code": "274905008",
#             "display": "Malignant lymphoma - lymphocytic, intermediate differentiation"
#           },
#           {
#             "code": "276811008",
#             "display": "Gastric lymphoma"
#           },
#           {
#             "code": "276815004",
#             "display": "Lymphoma of intestine"
#           },
#           {
#             "code": "276836002",
#             "display": "Primary cerebral lymphoma"
#           },
#           {
#             "code": "277473004",
#             "display": "B-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277474005",
#             "display": "B-cell chronic lymphocytic leukemia variant"
#           },
#           {
#             "code": "277543005",
#             "display": "Malignant white blood cell disorder"
#           },
#           {
#             "code": "277545003",
#             "display": "T-cell chronic lymphocytic leukemia"
#           },
#           {
#             "code": "277549009",
#             "display": "Chronic lymphocytic prolymphocytic leukemia syndrome"
#           },
#           {
#             "code": "277550009",
#             "display": "Richter's syndrome"
#           },
#           {
#             "code": "277551008",
# ...
#           },
#           {
#             "code": "93150008",
#             "display": "Leukemic reticuloendotheliosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93151007",
#             "display": "Hairy cell leukemia of spleen"
#           },
#           {
#             "code": "93152000",
#             "display": "Leukemic reticuloendotheliosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93182006",
#             "display": "Malignant histiocytosis of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93183001",
#             "display": "Malignant histiocytosis of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93184007",
#             "display": "Malignant histiocytosis of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93185008",
#             "display": "Malignant histiocytosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93186009",
#             "display": "Malignant histiocytosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93187000",
#             "display": "Malignant histiocytosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93188005",
#             "display": "Malignant histiocytosis of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93189002",
#             "display": "Malignant histiocytosis of spleen"
#           },
#           {
#             "code": "93190006",
#             "display": "Malignant histiocytosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93191005",
#             "display": "Malignant lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93192003",
#             "display": "Malignant lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93193008",
#             "display": "Malignant lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93194002",
#             "display": "Malignant lymphoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93195001",
#             "display": "Malignant lymphoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93196000",
#             "display": "Malignant lymphoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93197009",
#             "display": "Malignant lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93198004",
#             "display": "Malignant lymphoma of spleen"
#           },
#           {
#             "code": "93199007",
#             "display": "Malignant lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93200005",
#             "display": "Malignant mast cell tumor of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93201009",
#             "display": "Malignant mast cell tumor of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93202002",
#             "display": "Malignant mast cell tumor of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93203007",
#             "display": "Malignant mast cell tumor of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93204001",
#             "display": "Malignant mast cell tumor of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93205000",
#             "display": "Malignant mast cell tumor of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93206004",
#             "display": "Malignant mast cell tumor of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93207008",
#             "display": "Malignant mast cell tumor of spleen"
#           },
#           {
#             "code": "93208003",
#             "display": "Malignant mast cell tumor of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93451002",
#             "display": "Erythroleukemia, FAB M6"
#           },
#           {
#             "code": "93487009",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93488004",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93489007",
#             "display": "Hodgkin's disease, lymphocytic depletion of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93492006",
#             "display": "Hodgkin's disease, lymphocytic depletion of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93493001",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93494007",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93495008",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93496009",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93497000",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93498005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93500006",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of spleen"
#           },
#           {
#             "code": "93501005",
#             "display": "Hodgkin's disease, lymphocytic-histiocytic predominance of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93505001",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93506000",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93507009",
#             "display": "Hodgkin's disease, mixed cellularity of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93509007",
#             "display": "Hodgkin's disease, mixed cellularity of spleen"
#           },
#           {
#             "code": "93510002",
#             "display": "Hodgkin's disease, mixed cellularity of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93514006",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93515007",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93516008",
#             "display": "Hodgkin's disease, nodular sclerosis of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93518009",
#             "display": "Hodgkin's disease, nodular sclerosis of spleen"
#           },
#           {
#             "code": "93519001",
#             "display": "Hodgkin's disease, nodular sclerosis of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93520007",
#             "display": "Hodgkin's disease of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93521006",
#             "display": "Hodgkin's disease of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93522004",
#             "display": "Hodgkin's disease of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93523009",
#             "display": "Hodgkin's disease of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93524003",
#             "display": "Hodgkin's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93525002",
#             "display": "Hodgkin's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93526001",
#             "display": "Hodgkin's disease of lymph nodes of multiple sites"
#           },
#           {
#             "code": "93527005",
#             "display": "Hodgkin's disease of spleen"
#           },
#           {
#             "code": "93528000",
#             "display": "Hodgkin's disease of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93530003",
#             "display": "Hodgkin's granuloma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93531004",
#             "display": "Hodgkin's granuloma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93532006",
#             "display": "Hodgkin's granuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93533001",
#             "display": "Hodgkin's granuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93534007",
#             "display": "Hodgkin's granuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93536009",
#             "display": "Hodgkin's granuloma of spleen"
#           },
#           {
#             "code": "93537000",
#             "display": "Hodgkin's granuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93541001",
#             "display": "Hodgkin's paragranuloma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93542008",
#             "display": "Hodgkin's paragranuloma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93543003",
#             "display": "Hodgkin's paragranuloma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93545005",
#             "display": "Hodgkin's paragranuloma of spleen"
#           },
#           {
#             "code": "93546006",
#             "display": "Hodgkin's paragranuloma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "93547002",
#             "display": "Hodgkin's sarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "93548007",
#             "display": "Hodgkin's sarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "93549004",
#             "display": "Hodgkin's sarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "93550004",
#             "display": "Hodgkin's sarcoma of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "93551000",
#             "display": "Hodgkin's sarcoma of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "93552007",
#             "display": "Hodgkin's sarcoma of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "93554008",
#             "display": "Hodgkin's sarcoma of spleen"
#           },
#           {
#             "code": "93555009",
#             "display": "Hodgkin's sarcoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94686001",
#             "display": "Mixed cell type lymphosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94687005",
#             "display": "Mixed cell type lymphosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94688000",
#             "display": "Mixed cell type lymphosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94690004",
#             "display": "Mixed cell type lymphosarcoma of lymph nodes of head, face, and neck"
#           },
#           {
#             "code": "94704006",
#             "display": "Multiple myeloma in remission"
#           },
#           {
#             "code": "94707004",
#             "display": "Mycosis fungoides of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "94708009",
#             "display": "Mycosis fungoides of intrapelvic lymph nodes"
#           },
#           {
#             "code": "94709001",
#             "display": "Mycosis fungoides of intrathoracic lymph nodes"
#           },
#           {
#             "code": "94710006",
#             "display": "Mycosis fungoides of lymph nodes of axilla AND/OR upper limb"
#           },
#           {
#             "code": "94711005",
#             "display": "Mycosis fungoides of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "94712003",
#             "display": "Mycosis fungoides of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "94714002",
#             "display": "Mycosis fungoides of spleen"
#           },
#           {
#             "code": "94715001",
#             "display": "Mycosis fungoides of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "94719007",
#             "display": "Myeloid sarcoma, disease"
#           },
#           {
#             "code": "95186006",
#             "display": "Nodular lymphoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95187002",
#             "display": "Nodular lymphoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95188007",
#             "display": "Nodular lymphoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95192000",
#             "display": "Nodular lymphoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95193005",
#             "display": "Nodular lymphoma of spleen"
#           },
#           {
#             "code": "95194004",
#             "display": "Nodular lymphoma of extranodal AND/OR solid organ site"
#           },
#           {
#             "code": "95209008",
#             "display": "Plasma cell leukemia in remission"
#           },
#           {
#             "code": "95210003",
#             "display": "Plasma cell leukemia, disease"
#           },
#           {
#             "code": "95224004",
#             "display": "Reticulosarcoma of intra-abdominal lymph nodes"
#           },
#           {
#             "code": "95225003",
#             "display": "Reticulosarcoma of intrapelvic lymph nodes"
#           },
#           {
#             "code": "95226002",
#             "display": "Reticulosarcoma of intrathoracic lymph nodes"
#           },
#           {
#             "code": "95230004",
#             "display": "Reticulosarcoma of lymph nodes of multiple sites"
#           },
#           {
#             "code": "95231000",
#             "display": "Reticulosarcoma of spleen"
#           },
#           {
#             "code": "95260009",
#             "display": "S\u00e9zary's disease of lymph nodes of head, face AND/OR neck"
#           },
#           {
#             "code": "95261008",
#             "display": "S\u00e9zary's disease of lymph nodes of inguinal region AND/OR lower limb"
#           },
#           {
#             "code": "95263006",
#             "display": "S\u00e9zary's disease of spleen"
#           },
#           {
#             "code": "95264000",
#             "display": "S\u00e9zary's disease of extranodal AND/OR solid organ site"
#           }
#         ]
#       }
#     ]
#   },
#   "id": "nhsd-primary-care-domain-refsets-c19haemcan-cod",
#   "title": "Haematological cancer codes"
# }
