# %%
import tabula

#pdf_file = "PDF/Genomics.pdf"
pdf_file = "PDF/genome-report-example.pdf"
# Read pdf into list of DataFrame


#dfs = tabula.read_pdf(pdf_file, pages='all')
dfs = tabula.read_pdf(pdf_file, pages=0, stream=True, encoding='cp1252')

tabula.environment_info()
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Python version:
#     3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
# Java version:
#     openjdk version "21.0.1" 2023-10-17 LTS
# OpenJDK Runtime Environment Microsoft-8526870 (build 21.0.1+12-LTS)
# OpenJDK 64-Bit Server VM Microsoft-8526870 (build 21.0.1+12-LTS, mixed mode, sharing)
# tabula-py version: 2.10.0
# platform: Windows-11-10.0.26100-SP0
# uname:
#     uname_result(system='Windows', node='DESKTOP-4A7A8NJ', release='11', version='10.0.26100', machine='AMD64')
# linux_distribution: ('', '', '')
# mac_ver: ('', ('', '', ''), '')

# %%
print(len(dfs))
# Out:
# 1

# %%
dfs[0]
# Out:
#       Unnamed: 0                  Unnamed: 1                Disease,  \
# 0            NaN              REPORT SECTION                     NaN
# 1            NaN                         NaN             Inheritance
# 2             A.  MONOGENIC DISEASE FINDINGS                     NaN
# 3             B.                RISK ALLELES                     NaN
# 4            NaN                         NaN         Primary ciliary
# 5            NaN                         NaN                     NaN
# 6            NaN                         NaN             dyskinesia,
# 7            NaN                         NaN                     NaN
# 8            NaN                         NaN     Autosomal Recessive
# 9            NaN                         NaN         Primary ciliary
# 10           NaN                         NaN                     NaN
# 11           NaN                         NaN             dyskinesia,
# 12            C.     CARRIER STATUS VARIANTS                     NaN
# ...

# %%
tabula.convert_into(pdf_file, "output.csv", output_format="csv", pages=3)
# Out:
# Got stderr: Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font AAAAAC+*Verdana-8620
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Using predefined identity CMap instead
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font AAAAAE+*Lucida-Grande-Bold-8613
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Using predefined identity CMap instead
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font AAAAAF+*Monaco-8616
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Using predefined identity CMap instead
# Jun 05, 2025 11:44:57 AM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font AAAAAG+*Monaco
# ...
